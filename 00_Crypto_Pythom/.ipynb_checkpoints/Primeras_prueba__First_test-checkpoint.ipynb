# %%
# Para poder trabajar con las API de las exchanges siempre hay importar requests que es la libreria para solicitar informacion via http
# la documentacion se encuentra en: https://requests.readthedocs.io/en/latest/user/quickstart/
# -----------------------------------------------------------------------------
# To be able to work with these kind of APIs (Exchange Apis are curls apis) you must import requests, this extension will help you to manage
# the https requests
# for more details you can consult the next webpage: https://requests.readthedocs.io/en/latest/user/quickstart/

import requests

# Tambien sera neceario importar la libreria json para generar o leer informacion en esta estructuracion de datos
# -----------------------------------------------------------------------------
# Also... It could be neccesary to import json, to manage json data/structure

import json

# %%
# se usa la funcion get para conseguir la informacion del url/servidor en cuestion
# para esta etapa del ejemplo se usa /price que es para obtener la tabla de precios
# para mas detalles de la api/url de poloniex: https://api-docs.poloniex.com/
# -----------------------------------------------------------------------------
# the function get makes a GET request to the pointed url/server
# In this particular case we are using the poloniex url with the ending /prices, that will responde with the current prices table
# for more details: https://api-docs.poloniex.com/

precios = requests.get("https://api.poloniex.com/markets/price")

# lo que se recicbe es el codigo de estatus de la comunicacion con el servidor
# -----------------------------------------------------------------------------
# if you print directly the response you will printe just the response code of the url

print(precios)
# Out:
# <Response [200]>

# %%
# Para tener un mejor entendimiento de los codigos hay que conocer el protocolo http
# para mas informacion: https://developer.mozilla.org/es/docs/Web/HTTP/Status
# -----------------------------------------------------------------------------
# to get a better understanding of this codes you need to read a little bit more about the http protocol
# more info in: https://developer.mozilla.org/es/docs/Web/HTTP/Status

# el codigo 200 significa comunicacion exitosa
# -----------------------------------------------------------------------------
# for example the code 200 means success in the comunication with the url/server

if precios.status_code == 200:
    print("¡Exito!")

# un codigo 404 significaria un error en la comunicacion o en el propio servidor
# -----------------------------------------------------------------------------
# and a code 404 means that the url/server was not find (no comunnication)

elif precios.status_code == 404:
    print("Error 404, ¡Pagina no encontrada!")
# Out:
# Success!

# %%
# siempre se recomienda antes de continuar el proceso es confirmar el codigo de comunicacion exitosa (200)
# nota: los datos que se obtengan van a estar en forma de bytes (usando content,- informacion original)
# -----------------------------------------------------------------------------
# you should evaluate the code before to continue with all the process
# note: the base content will be always in bytes and not in text

if precios.status_code == 200:
    print(precios.content)
# Out:
# b'[ {\n  "symbol" : "BTS_BTC",\n  "price" : "0.0000000555",\n  "time" : 1711828123446,\n  "dailyChange" : "0.0571",\n  "ts" : 1711828123454\n}, {\n  "symbol" : "DASH_BTC",\n  "price" : "0.000558",\n  "time" : 1711841761858,\n  "dailyChange" : "-0.0211",\n  "ts" : 1711841761869\n}, {\n  "symbol" : "DOGE_BTC",\n  "price" : "0.000002906",\n  "time" : 1711847679793,\n  "dailyChange" : "-0.0583",\n  "ts" : 1711847679803\n}, {\n  "symbol" : "LTC_BTC",\n  "price" : "0.001477",\n  "time" : 1711848829338,\n  "dailyChange" : "-0.0244",\n  "ts" : 1711848829344\n}, {\n  "symbol" : "XLM_BTC",\n  "price" : "0.000001972",\n  "time" : 1711826604421,\n  "dailyChange" : "-0.0179",\n  "ts" : 1711826604429\n}, {\n  "symbol" : "XEM_BTC",\n  "price" : "0.000000727",\n  "time" : 1711837304413,\n  "dailyChange" : "-0.0109",\n  "ts" : 1711837304428\n}, {\n  "symbol" : "XMR_BTC",\n  "price" : "0.001706",\n  "time" : 1711849672592,\n  "dailyChange" : "-0.041",\n  "ts" : 1711849672604\n}, {\n  "symbol" : "XRP_BTC",\n  "price" : "0.00000892",\n  "time" : 1711844879964,\n  "dailyChange" : "-0.0089",\n  "ts" : 1711844879973\n}, {\n  "symbol" : "BTC_USDT",\n  "price" : "69965.01",\n  "time" : 1711849800468,\n  "dailyChange" : "-0.0001",\n  "ts" : 1711849800482\n}, {\n  "symbol" : "DASH_USDT",\n  "price" : "38.76",\n  "time" : 1711841761848,\n  "dailyChange" : "-0.0404",\n  "ts" : 1711841761860\n}, {\n  "symbol" : "LTC_USDT",\n  "price" : "103.743",\n  "time" : 1711849804529,\n  "dailyChange" : "-0.02",\n  "ts" : 1711849804538\n}, {\n  "symbol" : "XLM_USDT",\n  "price" : "0.141",\n  "time" : 1711849457834,\n  "dailyChange" : "0.0203",\n  "ts" : 1711849457844\n}, {\n  "symbol" : "XMR_USDT",\n  "price" : "117.02",\n  "time" : 1711849806309,\n  "dailyChange" : "-0.0507",\n  "ts" : 1711849806319\n}, {\n  "symbol" : "XRP_USDT",\n  "price" : "0.6238",\n  "time" : 1711849788525,\n  "dailyChange" : "-0.0051",\n  "ts" : 1711849788531\n}, {\n  "symbol" : "ETH_BTC",\n  "price" : "0.05045",\n  "time" : 1711848724026,\n  "dailyChange" : "0.0056",\n  "ts" : 1711848724035\n}, {\n  "symbol" : "ETH_USDT",\n  "price" : "3519.15",\n  "time" : 1711849804951,\n  "dailyChange" : "0.0018",\n  "ts" : 1711849804961\n}, {\n  "symbol" : "SC_BTC",\n  "price" : "0.0000001425",\n  "time" : 1711847054134,\n  "dailyChange" : "-0.0253",\n  "ts" : 1711847054142\n}, {\n  "symbol" : "DCR_BTC",\n  "price" : "0.000391",\n  "time" : 1711752776515,\n  "dailyChange" : "0.00",\n  "ts" : 1711752776527\n}, {\n  "symbol" : "LSK_BTC",\n  "price" : "0.00001314",\n  "time" : 1711833927515,\n  "dailyChange" : "0.0008",\n  "ts" : 1711833927526\n}, {\n  "symbol" : "STEEM_BTC",\n  "price" : "0.00000524",\n  "time" : 1711719124087,\n  "dailyChange" : "0.00",\n  "ts" : 1711719124096\n}, {\n  "symbol" : "ETC_BTC",\n  "price" : "0.000474",\n  "time" : 1711849729886,\n  "dailyChange" : "-0.0366",\n  "ts" : 1711849729896\n}, {\n  "symbol" : "ETC_ETH",\n  "price" : "0.00949",\n  "time" : 1711799705200,\n  "dailyChange" : "-0.0267",\n  "ts" : 1711799705213\n}, {\n  "symbol" : "ETC_USDT",\n  "price" : "33.284",\n  "time" : 1711849807536,\n  "dailyChange" : "-0.022",\n  "ts" : 1711849807546\n}, {\n  "symbol" : "ARDR_BTC",\n  "price" : "0.000001877",\n  "time" : 1711812127075,\n  "dailyChange" : "-0.0652",\n  "ts" : 1711812127081\n}, {\n  "symbol" : "ZEC_BTC",\n  "price" : "0.000432",\n  "time" : 1711826470455,\n  "dailyChange" : "-0.0137",\n  "ts" : 1711826470466\n}, {\n  "symbol" : "ZEC_ETH",\n  "price" : "0.00889",\n  "time" : 1711570095041,\n  "dailyChange" : "0.00",\n  "ts" : 1711570095053\n}, {\n  "symbol" : "ZEC_USDT",\n  "price" : "30.2",\n  "time" : 1711849798470,\n  "dailyChange" : "-0.0131",\n  "ts" : 1711849798480\n}, {\n  "symbol" : "ZRX_BTC",\n  "price" : "0.00001101",\n  "time" : 1711843430220,\n  "dailyChange" : "-0.0802",\n  "ts" : 1711843430235\n}, {\n  "symbol" : "ZRX_ETH",\n  "price" : "0.000232",\n  "time" : 1711804803474,\n  "dailyChange" : "-0.1255",\n  "ts" : 1711804803485\n}, {\n  "symbol" : "CVC ...

# %%
# si se desea que estos esten en forma de texto se puede usar (usando text)
# -----------------------------------------------------------------------------
# we can soulve this issue using the .text instead of the original .content

if precios.status_code == 200:
    print(precios.text)
# Out:
# [ {
#   "symbol" : "BTS_BTC",
#   "price" : "0.0000000555",
#   "time" : 1711828123446,
#   "dailyChange" : "0.0571",
#   "ts" : 1711828123454
# }, {
#   "symbol" : "DASH_BTC",
#   "price" : "0.000558",
#   "time" : 1711841761858,
#   "dailyChange" : "-0.0211",
#   "ts" : 1711841761869
# }, {
#   "symbol" : "DOGE_BTC",
#   "price" : "0.000002906",
#   "time" : 1711847679793,
#   "dailyChange" : "-0.0583",
#   "ts" : 1711847679803
# }, {
#   "symbol" : "LTC_BTC",
#   "price" : "0.001477",
#   "time" : 1711848829338,
#   "dailyChange" : "-0.0244",
#   "ts" : 1711848829344
# }, {
#   "symbol" : "XLM_BTC",
#   "price" : "0.000001972",
#   "time" : 1711826604421,
#   "dailyChange" : "-0.0179",
#   "ts" : 1711826604429
# }, {
#   "symbol" : "XEM_BTC",
#   "price" : "0.000000727",
#   "time" : 1711837304413,
#   "dailyChange" : "-0.0109",
#   "ts" : 1711837304428
# }, {
#   "symbol" : "XMR_BTC",
#   "price" : "0.001706",
#   "time" : 1711849672592,
#   "dailyChange" : "-0.041",
#   "ts" : 1711849672604
# }, {
#   "symbol" : "XRP_BTC",
#   "price" : "0.00000892",
#   "time" : 1711844879964,
#   "dailyChange" : "-0.0089",
#   "ts" : 1711844879973
# }, {
#   "symbol" : "BTC_USDT",
#   "price" : "69965.01",
#   "time" : 1711849800468,
#   "dailyChange" : "-0.0001",
#   "ts" : 1711849800482
# }, {
#   "symbol" : "DASH_USDT",
#   "price" : "38.76",
#   "time" : 1711841761848,
#   "dailyChange" : "-0.0404",
#   "ts" : 1711841761860
# }, {
#   "symbol" : "LTC_USDT",
#   "price" : "103.743",
#   "time" : 1711849804529,
#   "dailyChange" : "-0.02",
#   "ts" : 1711849804538
# }, {
#   "symbol" : "XLM_USDT",
#   "price" : "0.141",
#   "time" : 1711849457834,
#   "dailyChange" : "0.0203",
#   "ts" : 1711849457844
# }, {
#   "symbol" : "XMR_USDT",
#   "price" : "117.02",
#   "time" : 1711849806309,
#   "dailyChange" : "-0.0507",
#   "ts" : 1711849806319
# }, {
#   "symbol" : "XRP_USDT",
#   "price" : "0.6238",
#   "time" : 1711849788525,
#   "dailyChange" : "-0.0051",
#   "ts" : 1711849788531
# }, {
#   "symbol" : "ETH_BTC",
#   "price" : "0.05045",
#   "time" : 1711848724026,
#   "dailyChange" : "0.0056",
#   "ts" : 1711848724035
# }, {
#   "symbol" : "ETH_USDT",
#   "price" : "3519.15",
#   "time" : 1711849804951,
#   "dailyChange" : "0.0018",
#   "ts" : 1711849804961
# }, {
#   "symbol" : "SC_BTC",
#   "price" : "0.0000001425",
#   "time" : 1711847054134,
#   "dailyChange" : "-0.0253",
#   "ts" : 1711847054142
# }, {
#   "symbol" : "DCR_BTC",
#   "price" : "0.000391",
#   "time" : 1711752776515,
#   "dailyChange" : "0.00",
#   "ts" : 1711752776527
# }, {
#   "symbol" : "LSK_BTC",
#   "price" : "0.00001314",
#   "time" : 1711833927515,
#   "dailyChange" : "0.0008",
#   "ts" : 1711833927526
# }, {
#   "symbol" : "STEEM_BTC",
#   "price" : "0.00000524",
#   "time" : 1711719124087,
#   "dailyChange" : "0.00",
#   "ts" : 1711719124096
# }, {
#   "symbol" : "ETC_BTC",
#   "price" : "0.000474",
#   "time" : 1711849729886,
#   "dailyChange" : "-0.0366",
#   "ts" : 1711849729896
# }, {
#   "symbol" : "ETC_ETH",
#   "price" : "0.00949",
#   "time" : 1711799705200,
#   "dailyChange" : "-0.0267",
#   "ts" : 1711799705213
# }, {
#   "symbol" : "ETC_USDT",
#   "price" : "33.284",
#   "time" : 1711849807536,
#   "dailyChange" : "-0.022",
#   "ts" : 1711849807546
# }, {
#   "symbol" : "ARDR_BTC",
#   "price" : "0.000001877",
#   "time" : 1711812127075,
#   "dailyChange" : "-0.0652",
#   "ts" : 1711812127081
# }, {
#   "symbol" : "ZEC_BTC",
#   "price" : "0.000432",
#   "time" : 1711826470455,
#   "dailyChange" : "-0.0137",
#   "ts" : 1711826470466
# }, {
#   "symbol" : "ZEC_ETH",
#   "price" : "0.00889",
#   "time" : 1711570095041,
#   "dailyChange" : "0.00",
#   "ts" : 1711570095053
# }, {
#   "symbol" : "ZEC_USDT",
#   "price" : "30.2",
#   "time" : 1711849798470,
#   "dailyChange" : "-0.0131",
#   "ts" : 1711849798480
# }, {
#   "symbol" : "ZRX_BTC",
#   "price" : "0.00001101",
#   "time" : 1711843430220,
#   "dailyChange" : "-0.0802",
#   "ts" : 1711843430235
# }, {
#   "symbol" : "ZRX_ETH",
#   "price" : "0.000232",
#   "time" : 1711804803474,
#   "dailyChange" : "-0.1255",
#   "ts" : 1711804803485
# }, {
#   "symbol" : "CVC_BTC",
#   "price" : "0.000003176",
#   "time" : 1711756951382,
#   "dailyChange" : "0.00",
#   "ts" : 1711756951395
# }, {
#   "symbol" : "OMG_BTC",
#   "price" : "0.00001258",
#   "time" : 1711841441615,
#   "dailyChange" : "-0.2254",
#   "ts" : 1711841441628
# }, {
#   "symbol" : "GAS_BTC",
#   "price" : "0.0001",
#   "time" : 1711737864785,
#   "dailyChange" : "0.00",
#   "ts" : 1711737864794
# }, {
#   "symbol" : "STORJ_BTC",
#   "price" : "0.00001063",
#   "time" : 1711826452456,
#   "dailyChange" : "0.0047",
#   "ts" : 1711826452472
# }, {
#   "symbol" : "EOS_BTC",
#   "price" : "0.00001553",
#   "time" : 1711848409132,
#   "dailyChange" : "-0.007",
#   "ts" : 1711848409141
# }, {
#   "symbol" : "EOS_ETH",
#   "price" : "0.0003188",
#   "time" : 1711690926672,
#   "dailyChange" : "0.00",
#   "ts" : 1711690926683
# }, {
#   "symbol" : "EOS_USDT",
#   "price" : "1.0868",
#   "time" : 1711849806613,
#   "dailyChange" : "-0.0088",
#   "ts" : 1711849806619
# }, {
#   "symbol" : "SNT_BTC",
#   "price" : "0.000000574",
#   "time" : 1711826470824,
#   "dailyChange" : "-0.1881",
#   "ts" : 1711826470836
# }, {
#   "symbol" : "KNC_BTC",
#   "price" : "0.00001243",
#   "time" : 1711559354742,
#   "dailyChange" : "0.00",
#   "ts" : 1711559354749
# }, {
#   "symbol" : "BAT_BTC",
#   "price" : "0.00000431",
#   "time" : 1711686871880,
#   "dailyChange" : "0.00",
#   "ts" : 1711686871888
# }, {
#   "symbol" : "BAT_USDT",
#   "price" : "0.3269",
#   "time" : 1711834050935,
#   "dailyChange" : "0.0461",
#   "ts" : 1711834050943
# }, {
#   "symbol" : "LOOM_BTC",
#   "price" : "0.000001506",
#   "time" : 1711637510184,
#   "dailyChange" : "0.00",
#   "ts" : 1711637510191
# }, {
#   "symbol" : "DOGE_USDT",
#   "price" : "0.204144",
#   "time" : 1711849803050,
#   "dailyChange" : "-0.0551",
#   "ts" : 1711849803063
# }, {
#   "symbol" : "LSK_USDT",
#   "price" : "0.8481",
#   "time" : 1711833926675,
#   "dailyChange" : "-0.1006",
#   "ts" : 1711833926682
# }, {
#   "symbol" : "SC_USDT",
#   "price" : "0.00995",
#   "time" : 1711847054198,
#   "dailyChange" : "-0.0285",
#   "ts" : 1711847054205
# }, {
#   "symbol" : "ZRX_USDT",
#   "price" : "0.7654",
#   "time" : 1711843430249,
#   "dailyChange" : "-0.0818",
#   "ts" : 1711843430254
# }, {
#   "symbol" : "QTUM_BTC",
#   "price" : "0.0000673",
#   "time" : 1711826628905,
#   "dailyChange" : "0.0751",
#   "ts" : 1711826628918
# }, {
#   "symbol" : "QTUM_USDT",
#   "price" : "4.629",
#   "time" : 1711796404742,
#   "dailyChange" : "0.0214",
#   "ts" : 1711796404750
# }, {
#   "symbol" : "BTC_USDC",
#   "price" : "69813.89",
#   "time" : 1711844576277,
#   "dailyChange" : "-0.0081",
#   "ts" : 1711844576287
# }, {
#   "symbol" : "ETH_USDC",
#   "price" : "3514.51",
#   "time" : 1711837189886,
#   "dailyChange" : "-0.0042",
#   "ts" : 1711837189900
# }, {
#   "symbol" : "USDT_USDC",
#   "price" : "1.00219",
#   "time" : 1711847204864,
#   "dailyChange" : "0.001",
#   "ts" : 1711847204870
# }, {
#   "symbol" : "MANA_BTC",
#   "price" : "0.00000951",
#   "time" : 1711844672456,
#   "dailyChange" : "-0.1037",
#   "ts" : 1711844672467
# }, {
#   "symbol" : "MANA_USDT",
#   "price" : "0.6634",
#   "time" : 1711849803312,
#   "dailyChange" : "-0.0267",
#   "ts" : 1711849803317
# }, {
#   "symbol" : "BNT_BTC",
#   "price" : "0.00001151",
#   "time" : 1711826452875,
#   "dailyChange" : "-0.0017",
#   "ts" : 1711826452884
# }, {
#   "symbol" : "BCHSV_BTC",
#   "price" : "0.00142",
#   "time" : 1711846879929,
#   "dailyChange" : "0.0472",
#   "ts" : 1711846879938
# }, {
#   "symbol" : "BCHSV_USDC",
#   "price" : "98.52",
#   "time" : 1711846883455,
#   "dailyChange" : "0.0264",
#   "ts" : 1711846883466
# }, {
#   "symbol" : "XRP_USDC",
#   "price" : "0.6377",
#   "time" : 1711799266389,
#   "dailyChange" : "0.00",
#   "ts" : 1711799266401
# }, {
#   "symbol" : "XMR_USDC",
#   "price" : "116",
#   "time" : 1711844285303,
#   "dailyChange" : "-0.0938",
#   "ts" : 1711844285317
# }, {
#   "symbol" : "XLM_USDC",
#   "price" : "0.1272",
#   "time" : 1711802233892,
#   "dailyChange" : "-0.0979",
#   "ts" : 1711802233907
# }, {
#   "symbol" : "DOGE_USDC",
#   "price" : "0.2",
#   "time" : 1711835577172,
#   "dailyChange" : "-0.0476",
#   "ts" : 1711835577181
# }, {
#   "symbol" : "LTC_USDC",
#   "price" : "105.68",
#   "time" : 1711838404332,
#   "dailyChange" : "-0.0046",
#   "ts" : 1711838404344
# }, {
#   "symbol" : "ZEC_USDC",
#   "price" : "26.82",
#   "time" : 1711603290370,
#   "dailyChange" : "0.00",
#   "ts" : 1711603290385
# }, {
#   "symbol" : "NMR_BTC",
#   "price" : "0.000463",
#   "time" : 1711652065843,
#   "dailyChange" : "0.00",
#   "ts" : 1711652065850
# }, {
#   "symbol" : "POLY_BTC",
#   "price" : "0.000000753",
#   "time" : 1711833872516,
#   "dailyChange" : "0.0757",
#   "ts" : 1711833872525
# }, {
#   "symbol" : "LPT_BTC",
#   "price" : "0.0003031",
#   "time" : 1711314847646,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659243
# }, {
#   "symbol" : "ATOM_BTC",
#   "price" : "0.0001767",
#   "time" : 1711835530189,
#   "dailyChange" : "-0.0039",
#   "ts" : 1711835530201
# }, {
#   "symbol" : "ATOM_USDC",
#   "price" : "10.97",
#   "time" : 1710788766030,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659248
# }, {
#   "symbol" : "ATOM_USDT",
#   "price" : "12.335",
#   "time" : 1711849802677,
#   "dailyChange" : "-0.0116",
#   "ts" : 1711849802693
# }, {
#   "symbol" : "DASH_USDC",
#   "price" : "39.6",
#   "time" : 1711744691088,
#   "dailyChange" : "0.00",
#   "ts" : 1711744691098
# }, {
#   "symbol" : "EOS_USDC",
#   "price" : "1.5474",
#   "time" : 1711592989864,
#   "dailyChange" : "0.00",
#   "ts" : 1711592989875
# }, {
#   "symbol" : "ETC_USDC",
#   "price" : "24.88",
#   "time" : 1711629059522,
#   "dailyChange" : "0.00",
#   "ts" : 1711629059536
# }, {
#   "symbol" : "BCHSV_USDT",
#   "price" : "100.16",
#   "time" : 1711848413461,
#   "dailyChange" : "0.0432",
#   "ts" : 1711848413473
# }, {
#   "symbol" : "TRX_BTC",
#   "price" : "0.000001751",
#   "time" : 1711848821115,
#   "dailyChange" : "0.021",
#   "ts" : 1711848821131
# }, {
#   "symbol" : "TRX_USDC",
#   "price" : "0.12573",
#   "time" : 1711848176073,
#   "dailyChange" : "-0.0286",
#   "ts" : 1711848176087
# }, {
#   "symbol" : "TRX_USDT",
#   "price" : "0.12243",
#   "time" : 1711849800623,
#   "dailyChange" : "0.0195",
#   "ts" : 1711849800637
# }, {
#   "symbol" : "ETH_TRX",
#   "price" : "28709.87",
#   "time" : 1711846812114,
#   "dailyChange" : "-0.0276",
#   "ts" : 1711846812129
# }, {
#   "symbol" : "XRP_TRX",
#   "price" : "5.049",
#   "time" : 1711838700785,
#   "dailyChange" : "-0.037",
#   "ts" : 1711838700799
# }, {
#   "symbol" : "BTT_USDT",
#   "price" : "0.0000015944",
#   "time" : 1711849804414,
#   "dailyChange" : "-0.0008",
#   "ts" : 1711849804430
# }, {
#   "symbol" : "BTT_TRX",
#   "price" : "0.00001251",
#   "time" : 1711848509127,
#   "dailyChange" : "-0.0594",
#   "ts" : 1711848509139
# }, {
#   "symbol" : "WIN_USDT",
#   "price" : "0.00017009",
#   "time" : 1711849800882,
#   "dailyChange" : "0.0427",
#   "ts" : 1711849800889
# }, {
#   "symbol" : "WIN_TRX",
#   "price" : "0.001183",
#   "time" : 1711556352963,
#   "dailyChange" : "0.00",
#   "ts" : 1711556352974
# }, {
#   "symbol" : "STEEM_TRX",
#   "price" : "2.5",
#   "time" : 1711805118982,
#   "dailyChange" : "-0.1611",
#   "ts" : 1711805118990
# }, {
#   "symbol" : "LINK_BTC",
#   "price" : "0.0002673",
#   "time" : 1711826418197,
#   "dailyChange" : "-0.0037",
#   "ts" : 1711826418206
# }, {
#   "symbol" : "LINK_TRX",
#   "price" : "146.03",
#   "time" : 1711052964112,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659324
# }, {
#   "symbol" : "XTZ_BTC",
#   "price" : "0.00001851",
#   "time" : 1711826418601,
#   "dailyChange" : "-0.0299",
#   "ts" : 1711826418614
# }, {
#   "symbol" : "XTZ_USDT",
#   "price" : "1.37",
#   "time" : 1711837801147,
#   "dailyChange" : "-0.0358",
#   "ts" : 1711837801156
# }, {
#   "symbol" : "XTZ_TRX",
#   "price" : "11.7",
#   "time" : 1711497774587,
#   "dailyChange" : "0.00",
#   "ts" : 1711497774596
# }, {
#   "symbol" : "USDJ_USDT",
#   "price" : "1.1197",
#   "time" : 1711782278433,
#   "dailyChange" : "-0.0003",
#   "ts" : 1711782278448
# }, {
#   "symbol" : "SNX_BTC",
#   "price" : "0.0000637",
#   "time" : 1711826418404,
#   "dailyChange" : "-0.0619",
#   "ts" : 1711826418410
# }, {
#   "symbol" : "SNX_USDT",
#   "price" : "4.562",
#   "time" : 1711844199935,
#   "dailyChange" : "-0.0512",
#   "ts" : 1711844199940
# }, {
#   "symbol" : "SNX_TRX",
#   "price" : "39.48",
#   "time" : 1711357100577,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659383
# }, {
#   "symbol" : "MATIC_BTC",
#   "price" : "0.00001364",
#   "time" : 1711826418827,
#   "dailyChange" : "-0.0435",
#   "ts" : 1711826418846
# }, {
#   "symbol" : "MATIC_USDT",
#   "price" : "0.98151",
#   "time" : 1711849805793,
#   "dailyChange" : "-0.0091",
#   "ts" : 1711849805804
# }, {
#   "symbol" : "MATIC_TRX",
#   "price" : "8.41",
#   "time" : 1711568608242,
#   "dailyChange" : "0.00",
#   "ts" : 1711568608253
# }, {
#   "symbol" : "MKR_BTC",
#   "price" : "0.05312",
#   "time" : 1711844141442,
#   "dailyChange" : "0.0571",
#   "ts" : 1711844141450
# }, {
#   "symbol" : "MKR_USDT",
#   "price" : "3754.46",
#   "time" : 1711849804524,
#   "dailyChange" : "0.0173",
#   "ts" : 1711849804535
# }, {
#   "symbol" : "DAI_USDT",
#   "price" : "0.971",
#   "time" : 1711835500106,
#   "dailyChange" : "-0.0269",
#   "ts" : 1711835500121
# }, {
#   "symbol" : "NEO_BTC",
#   "price" : "0.0002248",
#   "time" : 1711826419313,
#   "dailyChange" : "-0.0699",
#   "ts" : 1711826419328
# }, {
#   "symbol" : "NEO_USDT",
#   "price" : "16.48",
#   "time" : 1711768650821,
#   "dailyChange" : "-0.0237",
#   "ts" : 1711768650827
# }, {
#   "symbol" : "NEO_TRX",
#   "price" : "112",
#   "time" : 1711740026008,
#   "dailyChange" : "0.00",
#   "ts" : 1711740026017
# }, {
#   "symbol" : "SWFTC_BTC",
#   "price" : "0.0000000313",
#   "time" : 1711788211205,
#   "dailyChange" : "-0.133",
#   "ts" : 1711788211210
# }, {
#   "symbol" : "SWFTC_USDT",
#   "price" : "0.002112",
#   "time" : 1711825520914,
#   "dailyChange" : "-0.0529",
#   "ts" : 1711825520941
# }, {
#   "symbol" : "SWFTC_TRX",
#   "price" : "0.02605",
#   "time" : 1711616004451,
#   "dailyChange" : "0.00",
#   "ts" : 1711616004464
# }, {
#   "symbol" : "JST_USDT",
#   "price" : "0.040402",
#   "time" : 1711849797519,
#   "dailyChange" : "0.0207",
#   "ts" : 1711849797529
# }, {
#   "symbol" : "JST_TRX",
#   "price" : "0.3329",
#   "time" : 1711472105381,
#   "dailyChange" : "0.00",
#   "ts" : 1711472105388
# }, {
#   "symbol" : "STEEM_USDT",
#   "price" : "0.34145",
#   "time" : 1711834675939,
#   "dailyChange" : "-0.0088",
#   "ts" : 1711834675951
# }, {
#   "symbol" : "LINK_USDT",
#   "price" : "19.0084",
#   "time" : 1711849804781,
#   "dailyChange" : "0.0047",
#   "ts" : 1711849804791
# }, {
#   "symbol" : "AVA_BTC",
#   "price" : "0.0000122",
#   "time" : 1711827467458,
#   "dailyChange" : "-0.0694",
#   "ts" : 1711827467466
# }, {
#   "symbol" : "AVA_USDT",
#   "price" : "0.8464",
#   "time" : 1711842971115,
#   "dailyChange" : "-0.0735",
#   "ts" : 1711842971130
# }, {
#   "symbol" : "AVA_TRX",
#   "price" : "6.84",
#   "time" : 1711841009189,
#   "dailyChange" : "-0.088",
#   "ts" : 1711841009202
# }, {
#   "symbol" : "XRPBULL_USDT",
#   "price" : "0.00000323",
#   "time" : 1668730134574,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659496
# }, {
#   "symbol" : "CHR_BTC",
#   "price" : "0.00000708",
#   "time" : 1711826450286,
#   "dailyChange" : "-0.115",
#   "ts" : 1711826450297
# }, {
#   "symbol" : "CHR_USDT",
#   "price" : "0.4641",
#   "time" : 1711764722731,
#   "dailyChange" : "-0.0064",
#   "ts" : 1711764722740
# }, {
#   "symbol" : "CHR_TRX",
#   "price" : "4.5",
#   "time" : 1711342913648,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659521
# }, {
#   "symbol" : "BTC_BNB",
#   "price" : "114.67",
#   "time" : 1711832555394,
#   "dailyChange" : "0.0033",
#   "ts" : 1711832555400
# }, {
#   "symbol" : "BNB_USDT",
#   "price" : "604.85",
#   "time" : 1711849796880,
#   "dailyChange" : "-0.0065",
#   "ts" : 1711849796887
# }, {
#   "symbol" : "BNB_TRX",
#   "price" : "4942.79",
#   "time" : 1711804088333,
#   "dailyChange" : "-0.0618",
#   "ts" : 1711804088344
# }, {
#   "symbol" : "MDT_BTC",
#   "price" : "0.000001551",
#   "time" : 1711729869394,
#   "dailyChange" : "0.00",
#   "ts" : 1711729869406
# }, {
#   "symbol" : "MDT_USDT",
#   "price" : "0.09009",
#   "time" : 1711801506493,
#   "dailyChange" : "-0.1629",
#   "ts" : 1711801506514
# }, {
#   "symbol" : "MDT_TRX",
#   "price" : "0.8",
#   "time" : 1711478146975,
#   "dailyChange" : "0.00",
#   "ts" : 1711478146987
# }, {
#   "symbol" : "COMP_USDT",
#   "price" : "79.98",
#   "time" : 1711771932061,
#   "dailyChange" : "-0.0536",
#   "ts" : 1711771932072
# }, {
#   "symbol" : "COMP_ETH",
#   "price" : "0.0229",
#   "time" : 1711725985008,
#   "dailyChange" : "0.00",
#   "ts" : 1711725985020
# }, {
#   "symbol" : "REN_BTC",
#   "price" : "0.0000015",
#   "time" : 1711442345684,
#   "dailyChange" : "0.00",
#   "ts" : 1711442345698
# }, {
#   "symbol" : "REN_USDT",
#   "price" : "0.0993",
#   "time" : 1711826243705,
#   "dailyChange" : "0.003",
#   "ts" : 1711826243715
# }, {
#   "symbol" : "LRC_BTC",
#   "price" : "0.00000539",
#   "time" : 1711838298915,
#   "dailyChange" : "-0.0849",
#   "ts" : 1711838298921
# }, {
#   "symbol" : "LRC_USDT",
#   "price" : "0.3731",
#   "time" : 1711787401311,
#   "dailyChange" : "-0.0182",
#   "ts" : 1711787401324
# }, {
#   "symbol" : "BAL_USDT",
#   "price" : "4.502",
#   "time" : 1711815720747,
#   "dailyChange" : "0.0009",
#   "ts" : 1711815720751
# }, {
#   "symbol" : "WRX_BTC",
#   "price" : "0.00000231",
#   "time" : 1711826419691,
#   "dailyChange" : "-0.3186",
#   "ts" : 1711826419705
# }, {
#   "symbol" : "WRX_USDT",
#   "price" : "0.2338",
#   "time" : 1711825520923,
#   "dailyChange" : "0.0108",
#   "ts" : 1711825520939
# }, {
#   "symbol" : "WRX_TRX",
#   "price" : "2.894",
#   "time" : 1711446135869,
#   "dailyChange" : "0.00",
#   "ts" : 1711446135884
# }, {
#   "symbol" : "SXP_BTC",
#   "price" : "0.00000762",
#   "time" : 1711826435083,
#   "dailyChange" : "-0.115",
#   "ts" : 1711826435099
# }, {
#   "symbol" : "SXP_USDT",
#   "price" : "0.4463",
#   "time" : 1711844648815,
#   "dailyChange" : "-0.1658",
#   "ts" : 1711844648829
# }, {
#   "symbol" : "SXP_TRX",
#   "price" : "3.3",
#   "time" : 1710690917239,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659090
# }, {
#   "symbol" : "YFI_USDT",
#   "price" : "8798.23",
#   "time" : 1711841284750,
#   "dailyChange" : "-0.0214",
#   "ts" : 1711841284773
# }, {
#   "symbol" : "STPT_BTC",
#   "price" : "0.000001001",
#   "time" : 1711849298226,
#   "dailyChange" : "-0.1142",
#   "ts" : 1711849298234
# }, {
#   "symbol" : "STPT_USDT",
#   "price" : "0.06978",
#   "time" : 1711849298209,
#   "dailyChange" : "-0.0696",
#   "ts" : 1711849298222
# }, {
#   "symbol" : "UMA_USDT",
#   "price" : "4.27",
#   "time" : 1711761939347,
#   "dailyChange" : "0.00",
#   "ts" : 1711761939356
# }, {
#   "symbol" : "RING_USDT",
#   "price" : "0.004182",
#   "time" : 1711647039876,
#   "dailyChange" : "0.00",
#   "ts" : 1711647039882
# }, {
#   "symbol" : "SWAP_BTC",
#   "price" : "0.000001554",
#   "time" : 1711826420348,
#   "dailyChange" : "0.0006",
#   "ts" : 1711826420355
# }, {
#   "symbol" : "SWAP_USDT",
#   "price" : "0.1107",
#   "time" : 1711825520981,
#   "dailyChange" : "0.00",
#   "ts" : 1711825520995
# }, {
#   "symbol" : "GEEQ_USDT",
#   "price" : "0.0902",
#   "time" : 1711842058757,
#   "dailyChange" : "-0.2953",
#   "ts" : 1711842058771
# }, {
#   "symbol" : "BAND_USDT",
#   "price" : "1.6822",
#   "time" : 1711815444010,
#   "dailyChange" : "-0.0731",
#   "ts" : 1711815444019
# }, {
#   "symbol" : "DOS_USDT",
#   "price" : "0.001011",
#   "time" : 1673517490627,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659164
# }, {
#   "symbol" : "DIA_USDT",
#   "price" : "0.607",
#   "time" : 1711807943627,
#   "dailyChange" : "0.166",
#   "ts" : 1711807943632
# }, {
#   "symbol" : "TRB_USDT",
#   "price" : "95.3",
#   "time" : 1711812960059,
#   "dailyChange" : "-0.0233",
#   "ts" : 1711812960073
# }, {
#   "symbol" : "CRV_USDT",
#   "price" : "0.59",
#   "time" : 1711830262675,
#   "dailyChange" : "-0.0326",
#   "ts" : 1711830262682
# }, {
#   "symbol" : "OM_USDT",
#   "price" : "0.6919",
#   "time" : 1711848949618,
#   "dailyChange" : "-0.0227",
#   "ts" : 1711848949627
# }, {
#   "symbol" : "OCEAN_USDT",
#   "price" : "1.3593",
#   "time" : 1711843197087,
#   "dailyChange" : "-0.0032",
#   "ts" : 1711843197100
# }, {
#   "symbol" : "BLY_USDT",
#   "price" : "0.004515",
#   "time" : 1711343898397,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659201
# }, {
#   "symbol" : "SWINGBY_BTC",
#   "price" : "0.00000000834",
#   "time" : 1711552905914,
#   "dailyChange" : "0.00",
#   "ts" : 1711552905921
# }, {
#   "symbol" : "SWINGBY_USDT",
#   "price" : "0.00028",
#   "time" : 1711825521021,
#   "dailyChange" : "-0.49",
#   "ts" : 1711825521028
# }, {
#   "symbol" : "SWINGBY_TRX",
#   "price" : "0.02637",
#   "time" : 1710874883919,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659212
# }, {
#   "symbol" : "PRQ_USDT",
#   "price" : "0.1519",
#   "time" : 1711747801273,
#   "dailyChange" : "0.00",
#   "ts" : 1711747801288
# }, {
#   "symbol" : "DOT_USDT",
#   "price" : "9.488",
#   "time" : 1711849806168,
#   "dailyChange" : "-0.0138",
#   "ts" : 1711849806180
# }, {
#   "symbol" : "RSR_USDT",
#   "price" : "0.009342",
#   "time" : 1711825521006,
#   "dailyChange" : "-0.1127",
#   "ts" : 1711825521020
# }, {
#   "symbol" : "WNXM_USDT",
#   "price" : "72.81",
#   "time" : 1711689957801,
#   "dailyChange" : "0.00",
#   "ts" : 1711689957813
# }, {
#   "symbol" : "FCT2_USDT",
#   "price" : "0.08244",
#   "time" : 1711845245230,
#   "dailyChange" : "0.7714",
#   "ts" : 1711845245239
# }, {
#   "symbol" : "FCT2_BTC",
#   "price" : "0.000003849",
#   "time" : 1711826441957,
#   "dailyChange" : "-0.115",
#   "ts" : 1711826441969
# }, {
#   "symbol" : "SUSHI_USDT",
#   "price" : "1.8487",
#   "time" : 1711849760795,
#   "dailyChange" : "-0.0236",
#   "ts" : 1711849760805
# }, {
#   "symbol" : "YFII_USDT",
#   "price" : "699",
#   "time" : 1711811919677,
#   "dailyChange" : "-0.1252",
#   "ts" : 1711811919684
# }, {
#   "symbol" : "FUND_USDT",
#   "price" : "0.18306",
#   "time" : 1711833568627,
#   "dailyChange" : "-0.0296",
#   "ts" : 1711833568640
# }, {
#   "symbol" : "FUND_TRX",
#   "price" : "1.5212",
#   "time" : 1711833568607,
#   "dailyChange" : "0.0037",
#   "ts" : 1711833568615
# }, {
#   "symbol" : "FUND_BTC",
#   "price" : "0.000002607",
#   "time" : 1711797223120,
#   "dailyChange" : "-0.0426",
#   "ts" : 1711797223135
# }, {
#   "symbol" : "AKRO_USDT",
#   "price" : "0.009555",
#   "time" : 1711838237477,
#   "dailyChange" : "0.5631",
#   "ts" : 1711838237482
# }, {
#   "symbol" : "AKRO_BTC",
#   "price" : "0.0000001286",
#   "time" : 1711829984434,
#   "dailyChange" : "0.468",
#   "ts" : 1711829984447
# }, {
#   "symbol" : "UNI_USDT",
#   "price" : "12.7019",
#   "time" : 1711849802048,
#   "dailyChange" : "0.0006",
#   "ts" : 1711849802056
# }, {
#   "symbol" : "DHT_USDT",
#   "price" : "0.055",
#   "time" : 1711712769167,
#   "dailyChange" : "0.00",
#   "ts" : 1711712769177
# }, {
#   "symbol" : "CVP_USDT",
#   "price" : "0.3014",
#   "time" : 1711825267199,
#   "dailyChange" : "-0.4801",
#   "ts" : 1711825267208
# }, {
#   "symbol" : "GHST_USDT",
#   "price" : "2",
#   "time" : 1711837651488,
#   "dailyChange" : "0.3524",
#   "ts" : 1711837651503
# }, {
#   "symbol" : "REPV2_BTC",
#   "price" : "0.0000121",
#   "time" : 1711786973491,
#   "dailyChange" : "-0.1168",
#   "ts" : 1711786973499
# }, {
#   "symbol" : "REPV2_USDT",
#   "price" : "0.901",
#   "time" : 1711825521101,
#   "dailyChange" : "-0.1876",
#   "ts" : 1711825521113
# }, {
#   "symbol" : "RARI_USDT",
#   "price" : "1.601",
#   "time" : 1711846275130,
#   "dailyChange" : "-0.584",
#   "ts" : 1711846275141
# }, {
#   "symbol" : "AMP_BTC",
#   "price" : "0.0000001405",
#   "time" : 1711732476615,
#   "dailyChange" : "0.00",
#   "ts" : 1711732476629
# }, {
#   "symbol" : "AMP_USDT",
#   "price" : "0.010613",
#   "time" : 1711805902620,
#   "dailyChange" : "0.1792",
#   "ts" : 1711805902636
# }, {
#   "symbol" : "AMP_TRX",
#   "price" : "0.0628",
#   "time" : 1711419833152,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659335
# }, {
#   "symbol" : "SAND_BTC",
#   "price" : "0.00000895",
#   "time" : 1711826420804,
#   "dailyChange" : "-0.1147",
#   "ts" : 1711826420813
# }, {
#   "symbol" : "SAND_USDT",
#   "price" : "0.6954",
#   "time" : 1711849801544,
#   "dailyChange" : "-0.0323",
#   "ts" : 1711849801552
# }, {
#   "symbol" : "POLS_USDT",
#   "price" : "0.8743",
#   "time" : 1711828959841,
#   "dailyChange" : "0.1486",
#   "ts" : 1711828959852
# }, {
#   "symbol" : "AAVE_BTC",
#   "price" : "0.001783",
#   "time" : 1711838248433,
#   "dailyChange" : "-0.0246",
#   "ts" : 1711838248442
# }, {
#   "symbol" : "AAVE_USDT",
#   "price" : "124.55",
#   "time" : 1711849803431,
#   "dailyChange" : "-0.0288",
#   "ts" : 1711849803437
# }, {
#   "symbol" : "CVT_BTC",
#   "price" : "0.00000004874",
#   "time" : 1673465404852,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659373
# }, {
#   "symbol" : "CVT_USDT",
#   "price" : "0.00125",
#   "time" : 1673499435734,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659378
# }, {
#   "symbol" : "INJ_BTC",
#   "price" : "0.00056354",
#   "time" : 1711658796746,
#   "dailyChange" : "0.00",
#   "ts" : 1711658796757
# }, {
#   "symbol" : "INJ_USDT",
#   "price" : "35.6271",
#   "time" : 1711837800990,
#   "dailyChange" : "-0.131",
#   "ts" : 1711837801002
# }, {
#   "symbol" : "BCH_BTC",
#   "price" : "0.008595",
#   "time" : 1711849293691,
#   "dailyChange" : "-0.0338",
#   "ts" : 1711849293706
# }, {
#   "symbol" : "BCH_USDT",
#   "price" : "600.95",
#   "time" : 1711849805384,
#   "dailyChange" : "-0.0268",
#   "ts" : 1711849805395
# }, {
#   "symbol" : "BCH_USDC",
#   "price" : "637",
#   "time" : 1711713559258,
#   "dailyChange" : "0.00",
#   "ts" : 1711713559271
# }, {
#   "symbol" : "SENSO_BTC",
#   "price" : "0.000000869",
#   "time" : 1710424495951,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659400
# }, {
#   "symbol" : "SENSO_USDT",
#   "price" : "0.0605",
#   "time" : 1711825521094,
#   "dailyChange" : "-0.0017",
#   "ts" : 1711825521109
# }, {
#   "symbol" : "KP3R_USDT",
#   "price" : "123.1",
#   "time" : 1711841284114,
#   "dailyChange" : "0.2482",
#   "ts" : 1711841284128
# }, {
#   "symbol" : "GLM_BTC",
#   "price" : "0.00000374",
#   "time" : 1711844111435,
#   "dailyChange" : "0.0904",
#   "ts" : 1711844111446
# }, {
#   "symbol" : "GLM_USDT",
#   "price" : "0.2617",
#   "time" : 1711846839138,
#   "dailyChange" : "0.0909",
#   "ts" : 1711846839150
# }, {
#   "symbol" : "ZLOT_USDT",
#   "price" : "4",
#   "time" : 1687336057442,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659423
# }, {
#   "symbol" : "WBTC_BTC",
#   "price" : "0.800151",
#   "time" : 1711826420902,
#   "dailyChange" : "-0.0803",
#   "ts" : 1711826420908
# }, {
#   "symbol" : "WBTC_USDT",
#   "price" : "59808.23",
#   "time" : 1711849803971,
#   "dailyChange" : "0.00",
#   "ts" : 1711849803979
# }, {
#   "symbol" : "FRONT_BTC",
#   "price" : "0.00001778",
#   "time" : 1711826453786,
#   "dailyChange" : "-0.0441",
#   "ts" : 1711826453805
# }, {
#   "symbol" : "FRONT_USDT",
#   "price" : "1.259",
#   "time" : 1711826454045,
#   "dailyChange" : "0.0771",
#   "ts" : 1711826454055
# }, {
#   "symbol" : "API3_USDT",
#   "price" : "3.7276",
#   "time" : 1711829289534,
#   "dailyChange" : "-0.017",
#   "ts" : 1711829289547
# }, {
#   "symbol" : "BADGER_USDT",
#   "price" : "5.999",
#   "time" : 1711646931858,
#   "dailyChange" : "0.00",
#   "ts" : 1711646931870
# }, {
#   "symbol" : "FARM_BTC",
#   "price" : "0.000695",
#   "time" : 1711712161757,
#   "dailyChange" : "0.00",
#   "ts" : 1711712161769
# }, {
#   "symbol" : "FARM_USDT",
#   "price" : "41.62",
#   "time" : 1711725794425,
#   "dailyChange" : "0.00",
#   "ts" : 1711725794434
# }, {
#   "symbol" : "DOT_BTC",
#   "price" : "0.0001352",
#   "time" : 1711826694810,
#   "dailyChange" : "-0.0131",
#   "ts" : 1711826694821
# }, {
#   "symbol" : "GRT_USDT",
#   "price" : "0.3898",
#   "time" : 1711849807833,
#   "dailyChange" : "-0.0059",
#   "ts" : 1711849807843
# }, {
#   "symbol" : "ESD_USDT",
#   "price" : "0.000702",
#   "time" : 1673213514627,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659474
# }, {
#   "symbol" : "ONEINCH_USDT",
#   "price" : "0.6125",
#   "time" : 1711821224568,
#   "dailyChange" : "0.0205",
#   "ts" : 1711821224583
# }, {
#   "symbol" : "REEF_USDT",
#   "price" : "0.00298",
#   "time" : 1711706573008,
#   "dailyChange" : "0.00",
#   "ts" : 1711706573015
# }, {
#   "symbol" : "LON_USDT",
#   "price" : "0.2001",
#   "time" : 1711308749881,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659489
# }, {
#   "symbol" : "ROOK_USDT",
#   "price" : "0.91",
#   "time" : 1711815331633,
#   "dailyChange" : "0.0581",
#   "ts" : 1711815331647
# }, {
#   "symbol" : "TRU_USDT",
#   "price" : "0.14851",
#   "time" : 1711835852395,
#   "dailyChange" : "-0.0361",
#   "ts" : 1711835852408
# }, {
#   "symbol" : "CUDOS_USDT",
#   "price" : "0.019201",
#   "time" : 1711789815582,
#   "dailyChange" : "0.00",
#   "ts" : 1711789815587
# }, {
#   "symbol" : "BOND_USDT",
#   "price" : "5.12",
#   "time" : 1711656069435,
#   "dailyChange" : "0.00",
#   "ts" : 1711656069443
# }, {
#   "symbol" : "TUSD_USDT",
#   "price" : "1.00232",
#   "time" : 1711847154917,
#   "dailyChange" : "-0.0001",
#   "ts" : 1711847154928
# }, {
#   "symbol" : "TUSD_USDC",
#   "price" : "1.00307",
#   "time" : 1711833728573,
#   "dailyChange" : "0.00",
#   "ts" : 1711833728584
# }, {
#   "symbol" : "WETH_USDT",
#   "price" : "1600",
#   "time" : 1711825521209,
#   "dailyChange" : "-0.1931",
#   "ts" : 1711825521224
# }, {
#   "symbol" : "TRU_BTC",
#   "price" : "0.000001652",
#   "time" : 1711347671749,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659545
# }, {
#   "symbol" : "FTT_USDT",
#   "price" : "1.946",
#   "time" : 1711849537738,
#   "dailyChange" : "0.0221",
#   "ts" : 1711849537750
# }, {
#   "symbol" : "SRM_USDT",
#   "price" : "0.0565",
#   "time" : 1711825521215,
#   "dailyChange" : "0.0162",
#   "ts" : 1711825521227
# }, {
#   "symbol" : "LPT_USDT",
#   "price" : "18.74",
#   "time" : 1711828574558,
#   "dailyChange" : "-0.0168",
#   "ts" : 1711828574573
# }, {
#   "symbol" : "BTC_TUSD",
#   "price" : "70007.32",
#   "time" : 1711694277310,
#   "dailyChange" : "0.00",
#   "ts" : 1711694277318
# }, {
#   "symbol" : "ETH_TUSD",
#   "price" : "3507.71",
#   "time" : 1711847154891,
#   "dailyChange" : "0.00",
#   "ts" : 1711847154903
# }, {
#   "symbol" : "ALPHA_USDT",
#   "price" : "0.1446",
#   "time" : 1711778702240,
#   "dailyChange" : "-0.0062",
#   "ts" : 1711778702248
# }, {
#   "symbol" : "TORN_USDT",
#   "price" : "2.2",
#   "time" : 1711825521725,
#   "dailyChange" : "-0.3333",
#   "ts" : 1711825521731
# }, {
#   "symbol" : "ZKS_USDT",
#   "price" : "0.02505",
#   "time" : 1711825521261,
#   "dailyChange" : "-0.3575",
#   "ts" : 1711825521290
# }, {
#   "symbol" : "RNDR_USDT",
#   "price" : "10.9991",
#   "time" : 1711829876561,
#   "dailyChange" : "0.00",
#   "ts" : 1711829876571
# }, {
#   "symbol" : "KCS_USDT",
#   "price" : "9.31",
#   "time" : 1711677382071,
#   "dailyChange" : "0.00",
#   "ts" : 1711677382081
# }, {
#   "symbol" : "FIL_BTC",
#   "price" : "0.0001353",
#   "time" : 1711844122894,
#   "dailyChange" : "-0.0438",
#   "ts" : 1711844122907
# }, {
#   "symbol" : "FIL_USDT",
#   "price" : "9.522",
#   "time" : 1711849799446,
#   "dailyChange" : "-0.0342",
#   "ts" : 1711849799454
# }, {
#   "symbol" : "XYM_BTC",
#   "price" : "0.00000028",
#   "time" : 1711826421525,
#   "dailyChange" : "-0.0667",
#   "ts" : 1711826421537
# }, {
#   "symbol" : "XYM_USDT",
#   "price" : "0.02614",
#   "time" : 1711838453550,
#   "dailyChange" : "-0.0136",
#   "ts" : 1711838453563
# }, {
#   "symbol" : "LIVE_USDT",
#   "price" : "0.01281",
#   "time" : 1668079415742,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659105
# }, {
#   "symbol" : "SHIB_USDT",
#   "price" : "0.000030268",
#   "time" : 1711849803875,
#   "dailyChange" : "-0.0205",
#   "ts" : 1711849803883
# }, {
#   "symbol" : "AKITA_USDT",
#   "price" : "0.0000001619",
#   "time" : 1711844678207,
#   "dailyChange" : "0.0106",
#   "ts" : 1711844678213
# }, {
#   "symbol" : "KLV_USDT",
#   "price" : "0.00526",
#   "time" : 1711669051150,
#   "dailyChange" : "0.00",
#   "ts" : 1711669051160
# }, {
#   "symbol" : "KLV_BTC",
#   "price" : "0.0000000989",
#   "time" : 1711784547274,
#   "dailyChange" : "0.3329",
#   "ts" : 1711784547289
# }, {
#   "symbol" : "KLV_TRX",
#   "price" : "0.0497",
#   "time" : 1711648995356,
#   "dailyChange" : "0.00",
#   "ts" : 1711648995371
# }, {
#   "symbol" : "LQTY_USDT",
#   "price" : "1.49",
#   "time" : 1711783403598,
#   "dailyChange" : "0.0644",
#   "ts" : 1711783403619
# }, {
#   "symbol" : "DEGO_USDT",
#   "price" : "2.431",
#   "time" : 1710495838787,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659149
# }, {
#   "symbol" : "ELON_USDT",
#   "price" : "0.0000001954",
#   "time" : 1711849805046,
#   "dailyChange" : "0.0989",
#   "ts" : 1711849805061
# }, {
#   "symbol" : "QUICK_USDT",
#   "price" : "0.08746",
#   "time" : 1711827632009,
#   "dailyChange" : "0.1147",
#   "ts" : 1711827632021
# }, {
#   "symbol" : "MVL_USDT",
#   "price" : "0.003596",
#   "time" : 1711796126081,
#   "dailyChange" : "0.0897",
#   "ts" : 1711796126090
# }, {
#   "symbol" : "NFT_USDT",
#   "price" : "0.00000058459",
#   "time" : 1711849806340,
#   "dailyChange" : "0.0349",
#   "ts" : 1711849806348
# }, {
#   "symbol" : "NFT_TRX",
#   "price" : "0.000004673",
#   "time" : 1711829505238,
#   "dailyChange" : "0.0024",
#   "ts" : 1711829505249
# }, {
#   "symbol" : "HT_USDT",
#   "price" : "0.78",
#   "time" : 1711849802215,
#   "dailyChange" : "-0.1213",
#   "ts" : 1711849802226
# }, {
#   "symbol" : "CTSI_USDT",
#   "price" : "0.3199",
#   "time" : 1711794772873,
#   "dailyChange" : "0.0667",
#   "ts" : 1711794772886
# }, {
#   "symbol" : "RLC_USDT",
#   "price" : "3.1601",
#   "time" : 1711839862081,
#   "dailyChange" : "-0.0803",
#   "ts" : 1711839862090
# }, {
#   "symbol" : "ERSDL_USDT",
#   "price" : "0.004699",
#   "time" : 1711840459379,
#   "dailyChange" : "0.3403",
#   "ts" : 1711840459392
# }, {
#   "symbol" : "RUNE_USDT",
#   "price" : "8.3545",
#   "time" : 1711843703130,
#   "dailyChange" : "0.1192",
#   "ts" : 1711843703140
# }, {
#   "symbol" : "KISHU_TRX",
#   "price" : "0.000000001805",
#   "time" : 1711786883500,
#   "dailyChange" : "-0.299",
#   "ts" : 1711786883516
# }, {
#   "symbol" : "GTC_USDT",
#   "price" : "2.118",
#   "time" : 1711634105354,
#   "dailyChange" : "0.00",
#   "ts" : 1711634105362
# }, {
#   "symbol" : "OKB_USDT",
#   "price" : "39",
#   "time" : 1711609809504,
#   "dailyChange" : "0.00",
#   "ts" : 1711609809516
# }, {
#   "symbol" : "SUN_USDT",
#   "price" : "0.015899",
#   "time" : 1711849804185,
#   "dailyChange" : "-0.0064",
#   "ts" : 1711849804194
# }, {
#   "symbol" : "SUN_TRX",
#   "price" : "0.07501",
#   "time" : 1711462049775,
#   "dailyChange" : "0.00",
#   "ts" : 1711462049788
# }, {
#   "symbol" : "XEC_USDT",
#   "price" : "0.00006579",
#   "time" : 1711840459160,
#   "dailyChange" : "-0.045",
#   "ts" : 1711840459169
# }, {
#   "symbol" : "CAKE_USDT",
#   "price" : "4.563",
#   "time" : 1711833933528,
#   "dailyChange" : "0.1108",
#   "ts" : 1711833933536
# }, {
#   "symbol" : "XVS_USDT",
#   "price" : "14.89",
#   "time" : 1711845457725,
#   "dailyChange" : "-0.0062",
#   "ts" : 1711845457739
# }, {
#   "symbol" : "BURGER_USDT",
#   "price" : "0.8998",
#   "time" : 1711820663433,
#   "dailyChange" : "0.0407",
#   "ts" : 1711820663448
# }, {
#   "symbol" : "AXS_USDT",
#   "price" : "10.99",
#   "time" : 1711844317691,
#   "dailyChange" : "-0.0108",
#   "ts" : 1711844317704
# }, {
#   "symbol" : "ALPACA_USDT",
#   "price" : "0.2538",
#   "time" : 1711793489304,
#   "dailyChange" : "0.00",
#   "ts" : 1711793489319
# }, {
#   "symbol" : "C98_USDT",
#   "price" : "0.4097",
#   "time" : 1711845889194,
#   "dailyChange" : "-0.0007",
#   "ts" : 1711845889206
# }, {
#   "symbol" : "PERP_USDT",
#   "price" : "2.1943",
#   "time" : 1711713487192,
#   "dailyChange" : "0.00",
#   "ts" : 1711713487202
# }, {
#   "symbol" : "TRU_TUSD",
#   "price" : "0.08021",
#   "time" : 1710257681051,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659287
# }, {
#   "symbol" : "ACH1_USDT",
#   "price" : "0.03497",
#   "time" : 1711614967612,
#   "dailyChange" : "0.00",
#   "ts" : 1711614967627
# }, {
#   "symbol" : "CLV_USDT",
#   "price" : "0.1148",
#   "time" : 1711640229100,
#   "dailyChange" : "0.00",
#   "ts" : 1711640229119
# }, {
#   "symbol" : "YGG_USDT",
#   "price" : "1.3628",
#   "time" : 1711843581037,
#   "dailyChange" : "0.1251",
#   "ts" : 1711843581044
# }, {
#   "symbol" : "ALICE_USDT",
#   "price" : "1.915",
#   "time" : 1711759632340,
#   "dailyChange" : "0.00",
#   "ts" : 1711759632347
# }, {
#   "symbol" : "AUDIO_USDT",
#   "price" : "0.25",
#   "time" : 1711792792135,
#   "dailyChange" : "-0.154",
#   "ts" : 1711792792144
# }, {
#   "symbol" : "BIT_USDT",
#   "price" : "0.5961",
#   "time" : 1690216388216,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659314
# }, {
#   "symbol" : "BNB_USDC",
#   "price" : "585.68",
#   "time" : 1711752674587,
#   "dailyChange" : "0.00",
#   "ts" : 1711752674597
# }, {
#   "symbol" : "LINK_USDC",
#   "price" : "20",
#   "time" : 1711438106805,
#   "dailyChange" : "0.00",
#   "ts" : 1711438106822
# }, {
#   "symbol" : "MBOX_USDT",
#   "price" : "0.45",
#   "time" : 1711656091781,
#   "dailyChange" : "0.00",
#   "ts" : 1711656091796
# }, {
#   "symbol" : "MATTER_USDT",
#   "price" : "0.036",
#   "time" : 1711848898262,
#   "dailyChange" : "-0.1509",
#   "ts" : 1711848898268
# }, {
#   "symbol" : "MATTER_TRX",
#   "price" : "0.866",
#   "time" : 1710886598438,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659379
# }, {
#   "symbol" : "AGLD_USDT",
#   "price" : "1.5996",
#   "time" : 1711698779222,
#   "dailyChange" : "0.00",
#   "ts" : 1711698779232
# }, {
#   "symbol" : "MATIC_USDC",
#   "price" : "1.1999",
#   "time" : 1711664565237,
#   "dailyChange" : "0.00",
#   "ts" : 1711664565247
# }, {
#   "symbol" : "MANA_USDC",
#   "price" : "0.6817",
#   "time" : 1711592974739,
#   "dailyChange" : "0.00",
#   "ts" : 1711592974746
# }, {
#   "symbol" : "XEM_USDC",
#   "price" : "0.0474",
#   "time" : 1710979695213,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659395
# }, {
#   "symbol" : "BTT_USDC",
#   "price" : "0.0000013173",
#   "time" : 1711775302583,
#   "dailyChange" : "-0.3044",
#   "ts" : 1711775302592
# }, {
#   "symbol" : "SRM_USDC",
#   "price" : "0.2999",
#   "time" : 1710715638554,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659399
# }, {
#   "symbol" : "XEM_USDT",
#   "price" : "0.05069",
#   "time" : 1711837304400,
#   "dailyChange" : "-0.0103",
#   "ts" : 1711837304414
# }, {
#   "symbol" : "SRM_BTC",
#   "price" : "0.0000009",
#   "time" : 1710352739158,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659404
# }, {
#   "symbol" : "DYDX_USDT",
#   "price" : "3.659",
#   "time" : 1711845183551,
#   "dailyChange" : "0.0108",
#   "ts" : 1711845183561
# }, {
#   "symbol" : "XCAD_USDT",
#   "price" : "1.11",
#   "time" : 1711825521471,
#   "dailyChange" : "0.0091",
#   "ts" : 1711825521486
# }, {
#   "symbol" : "GALA_USDT",
#   "price" : "0.068",
#   "time" : 1711846005981,
#   "dailyChange" : "0.0342",
#   "ts" : 1711846005993
# }, {
#   "symbol" : "LDO_USDT",
#   "price" : "2.816",
#   "time" : 1711849806949,
#   "dailyChange" : "-0.0154",
#   "ts" : 1711849806963
# }, {
#   "symbol" : "BTRST_USDT",
#   "price" : "1.085",
#   "time" : 1711656902636,
#   "dailyChange" : "0.00",
#   "ts" : 1711656902643
# }, {
#   "symbol" : "FLOKI_USDT",
#   "price" : "0.000254",
#   "time" : 1711849486029,
#   "dailyChange" : "0.0653",
#   "ts" : 1711849486045
# }, {
#   "symbol" : "TOKE_USDT",
#   "price" : "0.729",
#   "time" : 1711848674512,
#   "dailyChange" : "0.0297",
#   "ts" : 1711848674535
# }, {
#   "symbol" : "WNCG_USDT",
#   "price" : "0.0376",
#   "time" : 1711844794360,
#   "dailyChange" : "0.00",
#   "ts" : 1711844794368
# }, {
#   "symbol" : "MLN_USDT",
#   "price" : "27.23",
#   "time" : 1711554846463,
#   "dailyChange" : "0.00",
#   "ts" : 1711554846480
# }, {
#   "symbol" : "WOO_USDT",
#   "price" : "0.4565",
#   "time" : 1711693970516,
#   "dailyChange" : "0.00",
#   "ts" : 1711693970532
# }, {
#   "symbol" : "ENJ_USDT",
#   "price" : "0.4998",
#   "time" : 1711800585661,
#   "dailyChange" : "0.0079",
#   "ts" : 1711800585677
# }, {
#   "symbol" : "CHZ_USDT",
#   "price" : "0.15",
#   "time" : 1711752866114,
#   "dailyChange" : "0.00",
#   "ts" : 1711752866122
# }, {
#   "symbol" : "SLP_USDT",
#   "price" : "0.005227",
#   "time" : 1711825521560,
#   "dailyChange" : "-0.0019",
#   "ts" : 1711825521570
# }, {
#   "symbol" : "OGN_USDT",
#   "price" : "0.215",
#   "time" : 1711836074085,
#   "dailyChange" : "-0.1781",
#   "ts" : 1711836074095
# }, {
#   "symbol" : "PLA_USDT",
#   "price" : "0.15",
#   "time" : 1710868664072,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659477
# }, {
#   "symbol" : "TLM_USDT",
#   "price" : "0.02318",
#   "time" : 1711823478384,
#   "dailyChange" : "0.0013",
#   "ts" : 1711823478397
# }, {
#   "symbol" : "SUPER_USDT",
#   "price" : "1.29",
#   "time" : 1711830089157,
#   "dailyChange" : "-0.0001",
#   "ts" : 1711830089167
# }, {
#   "symbol" : "ILV_USDT",
#   "price" : "172.17",
#   "time" : 1711689734360,
#   "dailyChange" : "0.00",
#   "ts" : 1711689734375
# }, {
#   "symbol" : "ERN_USDT",
#   "price" : "7.2829",
#   "time" : 1711456716154,
#   "dailyChange" : "0.00",
#   "ts" : 1711456716171
# }, {
#   "symbol" : "SPELL_USDT",
#   "price" : "0.0009",
#   "time" : 1711825521522,
#   "dailyChange" : "-0.2863",
#   "ts" : 1711825521535
# }, {
#   "symbol" : "EFI_USDT",
#   "price" : "0.0467",
#   "time" : 1698133997452,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659512
# }, {
#   "symbol" : "RACA_USDT",
#   "price" : "0.0003603",
#   "time" : 1711814869497,
#   "dailyChange" : "0.1907",
#   "ts" : 1711814869506
# }, {
#   "symbol" : "AVAX_USDT",
#   "price" : "53.32",
#   "time" : 1711849800616,
#   "dailyChange" : "-0.0066",
#   "ts" : 1711849800626
# }, {
#   "symbol" : "GMEE_USDT",
#   "price" : "0.02222",
#   "time" : 1711812695868,
#   "dailyChange" : "-0.4927",
#   "ts" : 1711812695875
# }, {
#   "symbol" : "CVX_USDT",
#   "price" : "5.48",
#   "time" : 1711487793645,
#   "dailyChange" : "0.00",
#   "ts" : 1711487793655
# }, {
#   "symbol" : "SHIB_USDC",
#   "price" : "0.00003144",
#   "time" : 1711812609912,
#   "dailyChange" : "0.048",
#   "ts" : 1711812609924
# }, {
#   "symbol" : "AVAX_USDC",
#   "price" : "47",
#   "time" : 1711384268089,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659543
# }, {
#   "symbol" : "AVAX_BTC",
#   "price" : "0.000757",
#   "time" : 1711826422140,
#   "dailyChange" : "-0.0026",
#   "ts" : 1711826422149
# }, {
#   "symbol" : "ENS_USDT",
#   "price" : "20.01",
#   "time" : 1711829422440,
#   "dailyChange" : "0.00",
#   "ts" : 1711829422447
# }, {
#   "symbol" : "IMX_USDT",
#   "price" : "3.0398",
#   "time" : 1711849804282,
#   "dailyChange" : "0.0023",
#   "ts" : 1711849804289
# }, {
#   "symbol" : "KDOE_USDT",
#   "price" : "0.003332",
#   "time" : 1711849693627,
#   "dailyChange" : "-0.1643",
#   "ts" : 1711849693638
# }, {
#   "symbol" : "GN_USDT",
#   "price" : "0.00000044",
#   "time" : 1653071099000,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659044
# }, {
#   "symbol" : "SAITAMA_USDT",
#   "price" : "0.0007731",
#   "time" : 1711849804622,
#   "dailyChange" : "-0.0051",
#   "ts" : 1711849804632
# }, {
#   "symbol" : "BOBA_USDT",
#   "price" : "0.4692",
#   "time" : 1711822571934,
#   "dailyChange" : "-0.1027",
#   "ts" : 1711822571949
# }, {
#   "symbol" : "POLYDOGE_USDT",
#   "price" : "0.000000012156",
#   "time" : 1711846636651,
#   "dailyChange" : "0.0563",
#   "ts" : 1711846636665
# }, {
#   "symbol" : "HEX_USDT",
#   "price" : "0.0031",
#   "time" : 1711824920312,
#   "dailyChange" : "-0.0988",
#   "ts" : 1711824920325
# }, {
#   "symbol" : "FXS_USDT",
#   "price" : "8.159",
#   "time" : 1711734231892,
#   "dailyChange" : "0.00",
#   "ts" : 1711734231904
# }, {
#   "symbol" : "DYP_USDT",
#   "price" : "0.07",
#   "time" : 1711194965620,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659080
# }, {
#   "symbol" : "TRIBE_USDT",
#   "price" : "0.1616",
#   "time" : 1711825521586,
#   "dailyChange" : "0.0094",
#   "ts" : 1711825521602
# }, {
#   "symbol" : "SOL_USDT",
#   "price" : "196.877",
#   "time" : 1711849807088,
#   "dailyChange" : "0.0229",
#   "ts" : 1711849807093
# }, {
#   "symbol" : "SOL_BTC",
#   "price" : "0.002803",
#   "time" : 1711837895658,
#   "dailyChange" : "0.0182",
#   "ts" : 1711837895667
# }, {
#   "symbol" : "SOL_USDC",
#   "price" : "196.01",
#   "time" : 1711833393479,
#   "dailyChange" : "0.0426",
#   "ts" : 1711833393489
# }, {
#   "symbol" : "DORA_USDT",
#   "price" : "0.72",
#   "time" : 1710862713343,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659100
# }, {
#   "symbol" : "ORCA_USDT",
#   "price" : "3.965",
#   "time" : 1711796627468,
#   "dailyChange" : "0.024",
#   "ts" : 1711796627481
# }, {
#   "symbol" : "PEOPLE_USDT",
#   "price" : "0.03887",
#   "time" : 1711840240710,
#   "dailyChange" : "0.0338",
#   "ts" : 1711840240719
# }, {
#   "symbol" : "PSP_USDT",
#   "price" : "0.03301",
#   "time" : 1711825521550,
#   "dailyChange" : "-0.2824",
#   "ts" : 1711825521556
# }, {
#   "symbol" : "NEXO_USDT",
#   "price" : "1.3742",
#   "time" : 1710625172310,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659138
# }, {
#   "symbol" : "FTM_USDT",
#   "price" : "0.9354",
#   "time" : 1711847061615,
#   "dailyChange" : "-0.056",
#   "ts" : 1711847061631
# }, {
#   "symbol" : "BNX_USDT",
#   "price" : "0.6763",
#   "time" : 1711844476888,
#   "dailyChange" : "0.1463",
#   "ts" : 1711844476904
# }, {
#   "symbol" : "QI_USDT",
#   "price" : "0.02699",
#   "time" : 1711845133794,
#   "dailyChange" : "0.0762",
#   "ts" : 1711845133809
# }, {
#   "symbol" : "ADA_USDT",
#   "price" : "0.64662",
#   "time" : 1711849805219,
#   "dailyChange" : "-0.0276",
#   "ts" : 1711849805229
# }, {
#   "symbol" : "REQ_USDT",
#   "price" : "0.09",
#   "time" : 1711825521597,
#   "dailyChange" : "-0.435",
#   "ts" : 1711825521610
# }, {
#   "symbol" : "SAMO_USDT",
#   "price" : "0.01305",
#   "time" : 1711825521640,
#   "dailyChange" : "0.0324",
#   "ts" : 1711825521655
# }, {
#   "symbol" : "ATLAS_USDT",
#   "price" : "0.008",
#   "time" : 1711830190021,
#   "dailyChange" : "0.0542",
#   "ts" : 1711830190030
# }, {
#   "symbol" : "POLIS_USDT",
#   "price" : "0.4491",
#   "time" : 1711643532960,
#   "dailyChange" : "0.00",
#   "ts" : 1711643532966
# }, {
#   "symbol" : "FIDA_USDT",
#   "price" : "0.4462",
#   "time" : 1711827814899,
#   "dailyChange" : "-0.1504",
#   "ts" : 1711827814912
# }, {
#   "symbol" : "BICO_USDT",
#   "price" : "0.5051",
#   "time" : 1711705289514,
#   "dailyChange" : "0.00",
#   "ts" : 1711705289521
# }, {
#   "symbol" : "GODS_USDT",
#   "price" : "0.1",
#   "time" : 1711610329516,
#   "dailyChange" : "0.00",
#   "ts" : 1711610329526
# }, {
#   "symbol" : "RBN_USDT",
#   "price" : "0.6152",
#   "time" : 1711844815410,
#   "dailyChange" : "-0.5655",
#   "ts" : 1711844815424
# }, {
#   "symbol" : "PYR_USDT",
#   "price" : "7.37",
#   "time" : 1711825521694,
#   "dailyChange" : "-0.0105",
#   "ts" : 1711825521714
# }, {
#   "symbol" : "SOS_USDT",
#   "price" : "0.0000000296",
#   "time" : 1711825522207,
#   "dailyChange" : "-0.0864",
#   "ts" : 1711825522220
# }, {
#   "symbol" : "HIGH_USDT",
#   "price" : "2.052",
#   "time" : 1711784008345,
#   "dailyChange" : "-0.0335",
#   "ts" : 1711784008360
# }, {
#   "symbol" : "VOXEL_USDT",
#   "price" : "0.4",
#   "time" : 1711812285184,
#   "dailyChange" : "0.00",
#   "ts" : 1711812285193
# }, {
#   "symbol" : "ADA_BTC",
#   "price" : "0.00000931",
#   "time" : 1711830467393,
#   "dailyChange" : "-0.0241",
#   "ts" : 1711830467399
# }, {
#   "symbol" : "ADA_USDC",
#   "price" : "0.818",
#   "time" : 1711787638094,
#   "dailyChange" : "0.3916",
#   "ts" : 1711787638100
# }, {
#   "symbol" : "CTC_USDT",
#   "price" : "0.63",
#   "time" : 1711833492925,
#   "dailyChange" : "0.26",
#   "ts" : 1711833492934
# }, {
#   "symbol" : "METIS_USDT",
#   "price" : "100.83",
#   "time" : 1710698931776,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659257
# }, {
#   "symbol" : "OOKI_USDT",
#   "price" : "0.003887",
#   "time" : 1711629012554,
#   "dailyChange" : "0.00",
#   "ts" : 1711629012582
# }, {
#   "symbol" : "LOOKS_USDT",
#   "price" : "0.0401",
#   "time" : 1711825612418,
#   "dailyChange" : "-0.0475",
#   "ts" : 1711825612429
# }, {
#   "symbol" : "FTM_USDC",
#   "price" : "0.7001",
#   "time" : 1711507175458,
#   "dailyChange" : "0.00",
#   "ts" : 1711507175473
# }, {
#   "symbol" : "FTM_BTC",
#   "price" : "0.00001355",
#   "time" : 1711825903573,
#   "dailyChange" : "-0.0431",
#   "ts" : 1711825903584
# }, {
#   "symbol" : "SHPING_USDT",
#   "price" : "0.00628",
#   "time" : 1711848696707,
#   "dailyChange" : "-0.0157",
#   "ts" : 1711848696716
# }, {
#   "symbol" : "LOKA_USDT",
#   "price" : "0.4772",
#   "time" : 1711832342669,
#   "dailyChange" : "0.2023",
#   "ts" : 1711832342684
# }, {
#   "symbol" : "VRA_USDT",
#   "price" : "0.008008",
#   "time" : 1711844242692,
#   "dailyChange" : "-0.1048",
#   "ts" : 1711844242700
# }, {
#   "symbol" : "SUKU_USDT",
#   "price" : "0.07497",
#   "time" : 1711845322439,
#   "dailyChange" : "0.6946",
#   "ts" : 1711845322454
# }, {
#   "symbol" : "NCT_USDT",
#   "price" : "0.01001",
#   "time" : 1711295502118,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659292
# }, {
#   "symbol" : "HUNT_USDT",
#   "price" : "0.52",
#   "time" : 1711800001015,
#   "dailyChange" : "1.4762",
#   "ts" : 1711800001019
# }, {
#   "symbol" : "TITAN_USDT",
#   "price" : "0.0038",
#   "time" : 1711802990483,
#   "dailyChange" : "-0.0256",
#   "ts" : 1711802990497
# }, {
#   "symbol" : "UMEE_USDT",
#   "price" : "0.00443",
#   "time" : 1711446132245,
#   "dailyChange" : "0.00",
#   "ts" : 1711446132258
# }, {
#   "symbol" : "ALPINE_USDT",
#   "price" : "2.001",
#   "time" : 1711644640783,
#   "dailyChange" : "0.00",
#   "ts" : 1711644640789
# }, {
#   "symbol" : "GMT_USDT",
#   "price" : "0.365",
#   "time" : 1711841291109,
#   "dailyChange" : "-0.0595",
#   "ts" : 1711841291120
# }, {
#   "symbol" : "AERGO_USDT",
#   "price" : "0.0954",
#   "time" : 1673433959405,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659362
# }, {
#   "symbol" : "APE_USDT",
#   "price" : "1.91",
#   "time" : 1711811769008,
#   "dailyChange" : "-0.021",
#   "ts" : 1711811769017
# }, {
#   "symbol" : "NVIR_USDT",
#   "price" : "0.03999",
#   "time" : 1711805186387,
#   "dailyChange" : "0.00",
#   "ts" : 1711805186401
# }, {
#   "symbol" : "STG_USDT",
#   "price" : "0.7655",
#   "time" : 1711694423865,
#   "dailyChange" : "0.00",
#   "ts" : 1711694423879
# }, {
#   "symbol" : "CULT_USDT",
#   "price" : "0.000002007",
#   "time" : 1711821447605,
#   "dailyChange" : "-0.3306",
#   "ts" : 1711821447615
# }, {
#   "symbol" : "KSM_USDT",
#   "price" : "48.73",
#   "time" : 1711835570776,
#   "dailyChange" : "-0.0421",
#   "ts" : 1711835570789
# }, {
#   "symbol" : "ZELIX_USDT",
#   "price" : "0.0006149",
#   "time" : 1711849807255,
#   "dailyChange" : "0.2007",
#   "ts" : 1711849807271
# }, {
#   "symbol" : "CEEK_USDT",
#   "price" : "0.0551",
#   "time" : 1711129646242,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659388
# }, {
#   "symbol" : "NYM_USDT",
#   "price" : "0.2653",
#   "time" : 1711794914811,
#   "dailyChange" : "0.057",
#   "ts" : 1711794914819
# }, {
#   "symbol" : "CAW_USDT",
# ...
#   "ts" : 1711833752900
# }, {
#   "symbol" : "PIXEL_USDT",
#   "price" : "0.7608",
#   "time" : 1711843144344,
#   "dailyChange" : "0.0144",
#   "ts" : 1711843144351
# }, {
#   "symbol" : "STRK_USDT",
#   "price" : "2.21",
#   "time" : 1711738482201,
#   "dailyChange" : "0.00",
#   "ts" : 1711738482211
# }, {
#   "symbol" : "JIVA_USDT",
#   "price" : "0.00035",
#   "time" : 1711841761462,
#   "dailyChange" : "0.0938",
#   "ts" : 1711841761468
# }, {
#   "symbol" : "SORA_USDT",
#   "price" : "0.007",
#   "time" : 1711839095617,
#   "dailyChange" : "-0.2054",
#   "ts" : 1711839095632
# }, {
#   "symbol" : "MAVIA_USDT",
#   "price" : "5.41",
#   "time" : 1711846239645,
#   "dailyChange" : "-0.0938",
#   "ts" : 1711846239654
# }, {
#   "symbol" : "SPYRO_USDT",
#   "price" : "0.000000214",
#   "time" : 1711825523720,
#   "dailyChange" : "-0.7301",
#   "ts" : 1711825523731
# }, {
#   "symbol" : "NAVX_USDT",
#   "price" : "0.2999",
#   "time" : 1711676161459,
#   "dailyChange" : "0.00",
#   "ts" : 1711676161472
# }, {
#   "symbol" : "WHALES_USDT",
#   "price" : "1.2",
#   "time" : 1711825523767,
#   "dailyChange" : "-0.3528",
#   "ts" : 1711825523791
# }, {
#   "symbol" : "LMWR_USDT",
#   "price" : "1.1687",
#   "time" : 1711834200559,
#   "dailyChange" : "0.3811",
#   "ts" : 1711834200573
# }, {
#   "symbol" : "BFICGOLD_BFIC",
#   "price" : "0.2581",
#   "time" : 1710242522270,
#   "dailyChange" : "0.00",
#   "ts" : 1711423710177
# }, {
#   "symbol" : "YES_USDT",
#   "price" : "7.99",
#   "time" : 1711802693831,
#   "dailyChange" : "0.1301",
#   "ts" : 1711802693841
# }, {
#   "symbol" : "GMEONETH_USDT",
#   "price" : "0.000045",
#   "time" : 1711749924311,
#   "dailyChange" : "0.00",
#   "ts" : 1711749924363
# }, {
#   "symbol" : "SQUIDSOL_USDT",
#   "price" : "0.0002196",
#   "time" : 1707404533992,
#   "dailyChange" : "0.00",
#   "ts" : 1711423710161
# }, {
#   "symbol" : "FART_USDT",
#   "price" : "0.00000021",
#   "time" : 1711757551362,
#   "dailyChange" : "0.00",
#   "ts" : 1711757551377
# }, {
#   "symbol" : "ZETA_USDT",
#   "price" : "1.6033",
#   "time" : 1711825523716,
#   "dailyChange" : "-0.1499",
#   "ts" : 1711825523731
# }, {
#   "symbol" : "PEBO_USDT",
#   "price" : "0.000289",
#   "time" : 1711730221454,
#   "dailyChange" : "0.00",
#   "ts" : 1711730221467
# }, {
#   "symbol" : "AC_USDT",
#   "price" : "0.4291",
#   "time" : 1711842225192,
#   "dailyChange" : "0.9097",
#   "ts" : 1711842225204
# }, {
#   "symbol" : "DZHV_USDT",
#   "price" : "0.01996",
#   "time" : 1711829338230,
#   "dailyChange" : "0.0522",
#   "ts" : 1711829338240
# }, {
#   "symbol" : "TREMP_USDT",
#   "price" : "0.87648",
#   "time" : 1711849667638,
#   "dailyChange" : "0.3348",
#   "ts" : 1711849667645
# }, {
#   "symbol" : "BIF_USDT",
#   "price" : "0.00118",
#   "time" : 1711769526544,
#   "dailyChange" : "-0.0367",
#   "ts" : 1711769526561
# }, {
#   "symbol" : "SHU_USDT",
#   "price" : "0.11",
#   "time" : 1711766000654,
#   "dailyChange" : "-0.0036",
#   "ts" : 1711766000663
# }, {
#   "symbol" : "TBANK_USDT",
#   "price" : "0.9908",
#   "time" : 1711812666863,
#   "dailyChange" : "-0.0909",
#   "ts" : 1711812666877
# }, {
#   "symbol" : "ICENETWORK_USDT",
#   "price" : "0.004512",
#   "time" : 1711840691125,
#   "dailyChange" : "0.0094",
#   "ts" : 1711840691138
# }, {
#   "symbol" : "MOBY_USDT",
#   "price" : "1.068",
#   "time" : 1711648312226,
#   "dailyChange" : "0.00",
#   "ts" : 1711648312234
# }, {
#   "symbol" : "CHAT_USDT",
#   "price" : "1.801",
#   "time" : 1711777135146,
#   "dailyChange" : "0.00",
#   "ts" : 1711777135163
# }, {
#   "symbol" : "ML_USDT",
#   "price" : "0.44322",
#   "time" : 1711849800700,
#   "dailyChange" : "0.1004",
#   "ts" : 1711849800706
# }, {
#   "symbol" : "BENDOG_USDT",
#   "price" : "0.012011",
#   "time" : 1711805344642,
#   "dailyChange" : "-0.1037",
#   "ts" : 1711805344651
# }, {
#   "symbol" : "BEOBLE_USDT",
#   "price" : "0.15051",
#   "time" : 1711774269435,
#   "dailyChange" : "0.1382",
#   "ts" : 1711774269445
# }, {
#   "symbol" : "PORK_USDT",
#   "price" : "0.00000027",
#   "time" : 1711847308603,
#   "dailyChange" : "-0.10",
#   "ts" : 1711847308613
# }, {
#   "symbol" : "NADA_USDT",
#   "price" : "0.01255",
#   "time" : 1711849785787,
#   "dailyChange" : "-0.0984",
#   "ts" : 1711849785794
# }, {
#   "symbol" : "XPET_USDT",
#   "price" : "0.4362",
#   "time" : 1711458697598,
#   "dailyChange" : "0.00",
#   "ts" : 1711458697614
# }, {
#   "symbol" : "KLIMA_USDT",
#   "price" : "3.5164",
#   "time" : 1711849803925,
#   "dailyChange" : "0.0946",
#   "ts" : 1711849803939
# }, {
#   "symbol" : "CLOSEDAI_USDT",
#   "price" : "0.0001401",
#   "time" : 1711839822183,
#   "dailyChange" : "0.0007",
#   "ts" : 1711839822195
# }, {
#   "symbol" : "BRETT_USDT",
#   "price" : "0.07502",
#   "time" : 1711849431925,
#   "dailyChange" : "0.199",
#   "ts" : 1711849431936
# }, {
#   "symbol" : "PENG_USDT",
#   "price" : "0.29165",
#   "time" : 1711840245847,
#   "dailyChange" : "-0.3055",
#   "ts" : 1711840245858
# }, {
#   "symbol" : "OPSEC_USDT",
#   "price" : "2.9899",
#   "time" : 1711848817565,
#   "dailyChange" : "0.2008",
#   "ts" : 1711848817578
# }, {
#   "symbol" : "UPDOG_USDT",
#   "price" : "0.001013",
#   "time" : 1711802972462,
#   "dailyChange" : "0.013",
#   "ts" : 1711802972474
# }, {
#   "symbol" : "PORTAL_USDT",
#   "price" : "1.923",
#   "time" : 1711846938769,
#   "dailyChange" : "-0.0209",
#   "ts" : 1711846938777
# }, {
#   "symbol" : "ALVA_USDT",
#   "price" : "1.0669",
#   "time" : 1711849802234,
#   "dailyChange" : "0.0099",
#   "ts" : 1711849802245
# }, {
#   "symbol" : "HEMULE_USDT",
#   "price" : "0.02589",
#   "time" : 1711832137764,
#   "dailyChange" : "0.1997",
#   "ts" : 1711832137772
# }, {
#   "symbol" : "CAF_USDT",
#   "price" : "0.3322",
#   "time" : 1711849523741,
#   "dailyChange" : "0.6478",
#   "ts" : 1711849523755
# }, {
#   "symbol" : "FORK_USDT",
#   "price" : "0.0000016",
#   "time" : 1711836598535,
#   "dailyChange" : "0.3322",
#   "ts" : 1711836598544
# }, {
#   "symbol" : "SOLCHAT_USDT",
#   "price" : "7.098",
#   "time" : 1711843677906,
#   "dailyChange" : "-0.1128",
#   "ts" : 1711843677916
# }, {
#   "symbol" : "POPCAT_USDT",
#   "price" : "0.39499",
#   "time" : 1711846890297,
#   "dailyChange" : "0.2553",
#   "ts" : 1711846890306
# }, {
#   "symbol" : "RFKJ_USDT",
#   "price" : "0.0004214",
#   "time" : 1709578685696,
#   "dailyChange" : "0.00",
#   "ts" : 1711423710272
# }, {
#   "symbol" : "TYT_USDT",
#   "price" : "0.888",
#   "time" : 1711849801812,
#   "dailyChange" : "0.0218",
#   "ts" : 1711849801826
# }, {
#   "symbol" : "NEVER_USDT",
#   "price" : "0.0002099",
#   "time" : 1711849807808,
#   "dailyChange" : "-0.0838",
#   "ts" : 1711849807821
# }, {
#   "symbol" : "BOME_USDT",
#   "price" : "0.0137695",
#   "time" : 1711849492157,
#   "dailyChange" : "0.0734",
#   "ts" : 1711849492167
# }, {
#   "symbol" : "AEVO_USDT",
#   "price" : "2.96",
#   "time" : 1711846608707,
#   "dailyChange" : "-0.0452",
#   "ts" : 1711846608717
# }, {
#   "symbol" : "MUMU_USDT",
#   "price" : "0.0000088",
#   "time" : 1711849264386,
#   "dailyChange" : "-0.3714",
#   "ts" : 1711849264401
# }, {
#   "symbol" : "OETH_ETH",
#   "price" : "0.998238",
#   "time" : 1711848328587,
#   "dailyChange" : "0.00",
#   "ts" : 1711848328600
# }, {
#   "symbol" : "PRISMA_USDT",
#   "price" : "0.1459",
#   "time" : 1711841761293,
#   "dailyChange" : "80.0556",
#   "ts" : 1711841761306
# }, {
#   "symbol" : "BFICGOLD_USDT",
#   "price" : "2.29",
#   "time" : 1711848852095,
#   "dailyChange" : "-0.0292",
#   "ts" : 1711848852108
# }, {
#   "symbol" : "SYNC_USDT",
#   "price" : "0.02878",
#   "time" : 1711849029203,
#   "dailyChange" : "2.3349",
#   "ts" : 1711849029211
# }, {
#   "symbol" : "FAIR_USDT",
#   "price" : "0.000903",
#   "time" : 1711780555676,
#   "dailyChange" : "-0.2828",
#   "ts" : 1711780555690
# }, {
#   "symbol" : "WTAO_USDT",
#   "price" : "0.00524",
#   "time" : 1711773387961,
#   "dailyChange" : "-0.1643",
#   "ts" : 1711773387977
# }, {
#   "symbol" : "CLD_USDT",
#   "price" : "0.26",
#   "time" : 1711773455953,
#   "dailyChange" : "-0.0262",
#   "ts" : 1711773455968
# }, {
#   "symbol" : "GPU_USDT",
#   "price" : "2.0651",
#   "time" : 1711849531404,
#   "dailyChange" : "0.0379",
#   "ts" : 1711849531414
# }, {
#   "symbol" : "DEPD_USDT",
#   "price" : "0.00128",
#   "time" : 1711773429753,
#   "dailyChange" : "0.0323",
#   "ts" : 1711773429764
# }, {
#   "symbol" : "MOZ_USDT",
#   "price" : "0.053",
#   "time" : 1711846505385,
#   "dailyChange" : "0.1937",
#   "ts" : 1711846505396
# }, {
#   "symbol" : "BVM_USDT",
#   "price" : "2.746",
#   "time" : 1711769443061,
#   "dailyChange" : "0.0062",
#   "ts" : 1711769443073
# }, {
#   "symbol" : "SCA_USDT",
#   "price" : "0.8906",
#   "time" : 1711770619069,
#   "dailyChange" : "-0.063",
#   "ts" : 1711770619075
# }, {
#   "symbol" : "NOCHILL_USDT",
#   "price" : "0.02366",
#   "time" : 1711849807885,
#   "dailyChange" : "-0.0708",
#   "ts" : 1711849807892
# }, {
#   "symbol" : "NAP_USDT",
#   "price" : "0.00001112",
#   "time" : 1711849804845,
#   "dailyChange" : "-0.0827",
#   "ts" : 1711849804856
# }, {
#   "symbol" : "DUPE_USDT",
#   "price" : "0.002056",
#   "time" : 1711849806524,
#   "dailyChange" : "0.5425",
#   "ts" : 1711849806535
# }, {
#   "symbol" : "WEETH_ETH",
#   "price" : "1.018958",
#   "time" : 1711849805505,
#   "dailyChange" : "0.0022",
#   "ts" : 1711849805517
# }, {
#   "symbol" : "SAFEMOON_USDT",
#   "price" : "0.000396",
#   "time" : 1711849779244,
#   "dailyChange" : "0.1647",
#   "ts" : 1711849779257
# }, {
#   "symbol" : "IDK_USDT",
#   "price" : "0.00038",
#   "time" : 1711789758932,
#   "dailyChange" : "-0.05",
#   "ts" : 1711789758943
# }, {
#   "symbol" : "SLERF_USDT",
#   "price" : "0.6081",
#   "time" : 1711849799845,
#   "dailyChange" : "-0.0616",
#   "ts" : 1711849799852
# }, {
#   "symbol" : "GTOP_USDT",
#   "price" : "0.000506",
#   "time" : 1711849746404,
#   "dailyChange" : "-0.0453",
#   "ts" : 1711849746420
# }, {
#   "symbol" : "ETHFI_USDT",
#   "price" : "6.5447",
#   "time" : 1711849807196,
#   "dailyChange" : "-0.0771",
#   "ts" : 1711849807204
# }, {
#   "symbol" : "POGAISOL_USDT",
#   "price" : "0.0000116",
#   "time" : 1711849803282,
#   "dailyChange" : "-0.1278",
#   "ts" : 1711849803291
# }, {
#   "symbol" : "BINU_USDT",
#   "price" : "0.00034",
#   "time" : 1711849807287,
#   "dailyChange" : "0.1667",
#   "ts" : 1711849807295
# }, {
#   "symbol" : "ACRIA_USDT",
#   "price" : "0.03521",
#   "time" : 1711849802110,
#   "dailyChange" : "-0.0154",
#   "ts" : 1711849802117
# }, {
#   "symbol" : "MOROS_USDT",
#   "price" : "0.01052",
#   "time" : 1711848248508,
#   "dailyChange" : "-0.173",
#   "ts" : 1711848248524
# }, {
#   "symbol" : "PORTNOY_USDT",
#   "price" : "0.00015",
#   "time" : 1711847996975,
#   "dailyChange" : "-0.3478",
#   "ts" : 1711847996987
# }, {
#   "symbol" : "ANDYSOL_USDT",
#   "price" : "0.00848",
#   "time" : 1711849369030,
#   "dailyChange" : "-0.432",
#   "ts" : 1711849369044
# }, {
#   "symbol" : "PANDA_USDT",
#   "price" : "0.017603",
#   "time" : 1711849796890,
#   "dailyChange" : "-0.3891",
#   "ts" : 1711849796903
# }, {
#   "symbol" : "PIPI_USDT",
#   "price" : "0.00000000159",
#   "time" : 1711849799689,
#   "dailyChange" : "-0.3375",
#   "ts" : 1711849799697
# }, {
#   "symbol" : "COME_USDT",
#   "price" : "0.00001219",
#   "time" : 1711849803673,
#   "dailyChange" : "-0.0097",
#   "ts" : 1711849803686
# }, {
#   "symbol" : "SHROOM_USDT",
#   "price" : "0.01176",
#   "time" : 1711849800059,
#   "dailyChange" : "0.8326",
#   "ts" : 1711849800073
# }, {
#   "symbol" : "FIRE_USDT",
#   "price" : "0.9418",
#   "time" : 1711849795639,
#   "dailyChange" : "0.0318",
#   "ts" : 1711849795661
# }, {
#   "symbol" : "LOOMSOL_USDT",
#   "price" : "0.000066",
#   "time" : 1711849777428,
#   "dailyChange" : "-0.0833",
#   "ts" : 1711849777443
# }, {
#   "symbol" : "NGL_USDT",
#   "price" : "1.803",
#   "time" : 1711849795205,
#   "dailyChange" : "-0.1127",
#   "ts" : 1711849795219
# }, {
#   "symbol" : "DEGEN_USDT",
#   "price" : "0.037353",
#   "time" : 1711849797877,
#   "dailyChange" : "0.3208",
#   "ts" : 1711849797888
# }, {
#   "symbol" : "PNUT_USDT",
#   "price" : "0.00082",
#   "time" : 1711838161222,
#   "dailyChange" : "-0.59",
#   "ts" : 1711838161230
# }, {
#   "symbol" : "BRIUN_USDT",
#   "price" : "0.01131",
#   "time" : 1711849802260,
#   "dailyChange" : "-0.1486",
#   "ts" : 1711849802284
# }, {
#   "symbol" : "NORMIEBASE_USDT",
#   "price" : "0.1099",
#   "time" : 1711849805029,
#   "dailyChange" : "0.3467",
#   "ts" : 1711849805038
# }, {
#   "symbol" : "PRIME_USDT",
#   "price" : "23.95",
#   "time" : 1711849800463,
#   "dailyChange" : "-0.1159",
#   "ts" : 1711849800473
# }, {
#   "symbol" : "GRIMACE_USDT",
#   "price" : "9.259",
#   "time" : 1711849790749,
#   "dailyChange" : "-0.304",
#   "ts" : 1711849790759
# }, {
#   "symbol" : "SMOLE_USDT",
#   "price" : "0.0001205",
#   "time" : 1711849803179,
#   "dailyChange" : "0.3492",
#   "ts" : 1711849803190
# }, {
#   "symbol" : "KERMIT_USDT",
#   "price" : "0.00194",
#   "time" : 1711849802920,
#   "dailyChange" : "-0.2017",
#   "ts" : 1711849802930
# }, {
#   "symbol" : "MAIL_USDT",
#   "price" : "0.04751",
#   "time" : 1711849799393,
#   "dailyChange" : "-0.0284",
#   "ts" : 1711849799407
# }, {
#   "symbol" : "FINK_USDT",
#   "price" : "0.010597",
#   "time" : 1711849795609,
#   "dailyChange" : "-0.3045",
#   "ts" : 1711849795621
# }, {
#   "symbol" : "FOMOBASE_USDT",
#   "price" : "0.000657",
#   "time" : 1711849806425,
#   "dailyChange" : "-0.0166",
#   "ts" : 1711849806437
# }, {
#   "symbol" : "DOGINME_USDT",
#   "price" : "0.000731",
#   "time" : 1711849807409,
#   "dailyChange" : "-0.1887",
#   "ts" : 1711849807420
# }, {
#   "symbol" : "SORABTC_USDT",
#   "price" : "0.101",
#   "time" : 1711842784106,
#   "dailyChange" : "-0.057",
#   "ts" : 1711842784121
# }, {
#   "symbol" : "LIME_USDT",
#   "price" : "0.1125",
#   "time" : 1711849806717,
#   "dailyChange" : "-0.0443",
#   "ts" : 1711849806733
# }, {
#   "symbol" : "MEW_USDT",
#   "price" : "0.008459",
#   "time" : 1711849803640,
#   "dailyChange" : "0.4841",
#   "ts" : 1711849803651
# }, {
#   "symbol" : "REX_USDT",
#   "price" : "0.0176",
#   "time" : 1711849800531,
#   "dailyChange" : "-0.4268",
#   "ts" : 1711849800538
# }, {
#   "symbol" : "PUNDU_USDT",
#   "price" : "0.03474",
#   "time" : 1711849798526,
#   "dailyChange" : "-0.0589",
#   "ts" : 1711849798536
# }, {
#   "symbol" : "BASEDAI_USDT",
#   "price" : "11.068",
#   "time" : 1711849790154,
#   "dailyChange" : "0.0438",
#   "ts" : 1711849790166
# }, {
#   "symbol" : "BODEN_USDT",
#   "price" : "0.3188",
#   "time" : 1711849799430,
#   "dailyChange" : "-0.1116",
#   "ts" : 1711849799438
# }, {
#   "symbol" : "PUMP_USDT",
#   "price" : "0.000003834",
#   "time" : 1711849755438,
#   "dailyChange" : "-0.4233",
#   "ts" : 1711849755454
# }, {
#   "symbol" : "BENJI_USDT",
#   "price" : "0.02046",
#   "time" : 1711849807135,
#   "dailyChange" : "-0.3583",
#   "ts" : 1711849807146
# }, {
#   "symbol" : "DWIFC_USDT",
#   "price" : "0.00164",
#   "time" : 1711849807336,
#   "dailyChange" : "-0.1558",
#   "ts" : 1711849807348
# }, {
#   "symbol" : "CWIF_USDT",
#   "price" : "0.0000004883",
#   "time" : 1711849783497,
#   "dailyChange" : "0.2562",
#   "ts" : 1711849783504
# }, {
#   "symbol" : "VENOM_USDT",
#   "price" : "0.5557",
#   "time" : 1711843894155,
#   "dailyChange" : "-0.0856",
#   "ts" : 1711843894177
# }, {
#   "symbol" : "DOG_USDT",
#   "price" : "0.01358",
#   "time" : 1711849796702,
#   "dailyChange" : "0.043",
#   "ts" : 1711849796710
# }, {
#   "symbol" : "SHOL_USDT",
#   "price" : "0.0000147",
#   "time" : 1711849680866,
#   "dailyChange" : "-0.2864",
#   "ts" : 1711849680883
# }, {
#   "symbol" : "SHIV_USDT",
#   "price" : "0.000000117",
#   "time" : 1711849798952,
#   "dailyChange" : "0.047",
#   "ts" : 1711849798965
# }, {
#   "symbol" : "SBFSOL_USDT",
#   "price" : "0.000294",
#   "time" : 1711849602629,
#   "dailyChange" : "-0.1503",
#   "ts" : 1711849602647
# }, {
#   "symbol" : "TPU_USDT",
#   "price" : "0.08069",
#   "time" : 1711849802286,
#   "dailyChange" : "-0.1201",
#   "ts" : 1711849802298
# }, {
#   "symbol" : "NEURA_USDT",
#   "price" : "0.05021",
#   "time" : 1711849805990,
#   "dailyChange" : "0.4445",
#   "ts" : 1711849806002
# }, {
#   "symbol" : "ARCX_USDT",
#   "price" : "11.484",
#   "time" : 1711849806094,
#   "dailyChange" : "0.293",
#   "ts" : 1711849806106
# }, {
#   "symbol" : "CSWAP_USDT",
#   "price" : "0.07914",
#   "time" : 1711849804658,
#   "dailyChange" : "0.2823",
#   "ts" : 1711849804669
# }, {
#   "symbol" : "ROOST_USDT",
#   "price" : "0.08337",
#   "time" : 1711849796201,
#   "dailyChange" : "0.9241",
#   "ts" : 1711849796215
# }, {
#   "symbol" : "GRUMPY_USDT",
#   "price" : "0.000086",
#   "time" : 1711848751510,
#   "dailyChange" : "-0.3485",
#   "ts" : 1711848751521
# }, {
#   "symbol" : "DAW_USDT",
#   "price" : "0.001633",
#   "time" : 1711849806308,
#   "dailyChange" : "-0.06",
#   "ts" : 1711849806325
# }, {
#   "symbol" : "ALU_USDT",
#   "price" : "0.06756",
#   "time" : 1711847432113,
#   "dailyChange" : "-0.0084",
#   "ts" : 1711847432127
# }, {
#   "symbol" : "SCALE_USDT",
#   "price" : "0.5615",
#   "time" : 1711849806826,
#   "dailyChange" : "0.2693",
#   "ts" : 1711849806839
# } ]

# %%
# ahora lo que se desea hacer es usar ese texto para estructurarlo como un json (texto estructurado para javascript)
# -----------------------------------------------------------------------------
# now, the best way to proceed is to make a json load of that text

if precios.status_code == 200:
    precios_json = json.loads(precios.text)
    print(precios_json)
# Out:
# [{'symbol': 'BTS_BTC', 'price': '0.0000000555', 'time': 1711828123446, 'dailyChange': '0.0571', 'ts': 1711828123454}, {'symbol': 'DASH_BTC', 'price': '0.000558', 'time': 1711841761858, 'dailyChange': '-0.0211', 'ts': 1711841761869}, {'symbol': 'DOGE_BTC', 'price': '0.000002906', 'time': 1711847679793, 'dailyChange': '-0.0583', 'ts': 1711847679803}, {'symbol': 'LTC_BTC', 'price': '0.001477', 'time': 1711848829338, 'dailyChange': '-0.0244', 'ts': 1711848829344}, {'symbol': 'XLM_BTC', 'price': '0.000001972', 'time': 1711826604421, 'dailyChange': '-0.0179', 'ts': 1711826604429}, {'symbol': 'XEM_BTC', 'price': '0.000000727', 'time': 1711837304413, 'dailyChange': '-0.0109', 'ts': 1711837304428}, {'symbol': 'XMR_BTC', 'price': '0.001706', 'time': 1711849672592, 'dailyChange': '-0.041', 'ts': 1711849672604}, {'symbol': 'XRP_BTC', 'price': '0.00000892', 'time': 1711844879964, 'dailyChange': '-0.0089', 'ts': 1711844879973}, {'symbol': 'BTC_USDT', 'price': '69965.01', 'time': 1711849800468, 'dailyChange': '-0.0001', 'ts': 1711849800482}, {'symbol': 'DASH_USDT', 'price': '38.76', 'time': 1711841761848, 'dailyChange': '-0.0404', 'ts': 1711841761860}, {'symbol': 'LTC_USDT', 'price': '103.743', 'time': 1711849804529, 'dailyChange': '-0.02', 'ts': 1711849804538}, {'symbol': 'XLM_USDT', 'price': '0.141', 'time': 1711849457834, 'dailyChange': '0.0203', 'ts': 1711849457844}, {'symbol': 'XMR_USDT', 'price': '117.02', 'time': 1711849806309, 'dailyChange': '-0.0507', 'ts': 1711849806319}, {'symbol': 'XRP_USDT', 'price': '0.6238', 'time': 1711849788525, 'dailyChange': '-0.0051', 'ts': 1711849788531}, {'symbol': 'ETH_BTC', 'price': '0.05045', 'time': 1711848724026, 'dailyChange': '0.0056', 'ts': 1711848724035}, {'symbol': 'ETH_USDT', 'price': '3519.15', 'time': 1711849804951, 'dailyChange': '0.0018', 'ts': 1711849804961}, {'symbol': 'SC_BTC', 'price': '0.0000001425', 'time': 1711847054134, 'dailyChange': '-0.0253', 'ts': 1711847054142}, {'symbol': 'DCR_BTC', 'price': '0.000391', 'time': 1711752776515, 'dailyChange': '0.00', 'ts': 1711752776527}, {'symbol': 'LSK_BTC', 'price': '0.00001314', 'time': 1711833927515, 'dailyChange': '0.0008', 'ts': 1711833927526}, {'symbol': 'STEEM_BTC', 'price': '0.00000524', 'time': 1711719124087, 'dailyChange': '0.00', 'ts': 1711719124096}, {'symbol': 'ETC_BTC', 'price': '0.000474', 'time': 1711849729886, 'dailyChange': '-0.0366', 'ts': 1711849729896}, {'symbol': 'ETC_ETH', 'price': '0.00949', 'time': 1711799705200, 'dailyChange': '-0.0267', 'ts': 1711799705213}, {'symbol': 'ETC_USDT', 'price': '33.284', 'time': 1711849807536, 'dailyChange': '-0.022', 'ts': 1711849807546}, {'symbol': 'ARDR_BTC', 'price': '0.000001877', 'time': 1711812127075, 'dailyChange': '-0.0652', 'ts': 1711812127081}, {'symbol': 'ZEC_BTC', 'price': '0.000432', 'time': 1711826470455, 'dailyChange': '-0.0137', 'ts': 1711826470466}, {'symbol': 'ZEC_ETH', 'price': '0.00889', 'time': 1711570095041, 'dailyChange': '0.00', 'ts': 1711570095053}, {'symbol': 'ZEC_USDT', 'price': '30.2', 'time': 1711849798470, 'dailyChange': '-0.0131', 'ts': 1711849798480}, {'symbol': 'ZRX_BTC', 'price': '0.00001101', 'time': 1711843430220, 'dailyChange': '-0.0802', 'ts': 1711843430235}, {'symbol': 'ZRX_ETH', 'price': '0.000232', 'time': 1711804803474, 'dailyChange': '-0.1255', 'ts': 1711804803485}, {'symbol': 'CVC_BTC', 'price': '0.000003176', 'time': 1711756951382, 'dailyChange': '0.00', 'ts': 1711756951395}, {'symbol': 'OMG_BTC', 'price': '0.00001258', 'time': 1711841441615, 'dailyChange': '-0.2254', 'ts': 1711841441628}, {'symbol': 'GAS_BTC', 'price': '0.0001', 'time': 1711737864785, 'dailyChange': '0.00', 'ts': 1711737864794}, {'symbol': 'STORJ_BTC', 'price': '0.00001063', 'time': 1711826452456, 'dailyChange': '0.0047', 'ts': 1711826452472}, {'symbol': 'EOS_BTC', 'price': '0.00001553', 'time': 1711848409132, 'dailyChange': '-0.007', 'ts': 1711848409141}, {'symbol': 'EOS_ETH', 'price': '0.0003188', 'time': 1711690926672, 'dailyChange': '0.00', 'ts': 1711690926683}, {'symbo ...

# %%
# ahora acomodaremos la informacion en una lista donde solo se incluya la informacion de symbol como tipo y la informacio de price como precio, 
# desde la informacion tipo json
# -----------------------------------------------------------------------------
# now we can make our own list/array based on this information (json data), for example a list only with the symbols and prices

lista_precios = []
if precios.status_code == 200:
    precios_json = json.loads(precios.text)
    for p in precios_json:
        lista_precios.append({"tipo": p["symbol"], "precio": p["price"]})
print(lista_precios)
# Out:
# [{'tipo': 'BTS_BTC', 'precio': '0.0000000555'}, {'tipo': 'DASH_BTC', 'precio': '0.000558'}, {'tipo': 'DOGE_BTC', 'precio': '0.000002906'}, {'tipo': 'LTC_BTC', 'precio': '0.001477'}, {'tipo': 'XLM_BTC', 'precio': '0.000001972'}, {'tipo': 'XEM_BTC', 'precio': '0.000000727'}, {'tipo': 'XMR_BTC', 'precio': '0.001706'}, {'tipo': 'XRP_BTC', 'precio': '0.00000892'}, {'tipo': 'BTC_USDT', 'precio': '69965.01'}, {'tipo': 'DASH_USDT', 'precio': '38.76'}, {'tipo': 'LTC_USDT', 'precio': '103.743'}, {'tipo': 'XLM_USDT', 'precio': '0.141'}, {'tipo': 'XMR_USDT', 'precio': '117.02'}, {'tipo': 'XRP_USDT', 'precio': '0.6238'}, {'tipo': 'ETH_BTC', 'precio': '0.05045'}, {'tipo': 'ETH_USDT', 'precio': '3519.15'}, {'tipo': 'SC_BTC', 'precio': '0.0000001425'}, {'tipo': 'DCR_BTC', 'precio': '0.000391'}, {'tipo': 'LSK_BTC', 'precio': '0.00001314'}, {'tipo': 'STEEM_BTC', 'precio': '0.00000524'}, {'tipo': 'ETC_BTC', 'precio': '0.000474'}, {'tipo': 'ETC_ETH', 'precio': '0.00949'}, {'tipo': 'ETC_USDT', 'precio': '33.284'}, {'tipo': 'ARDR_BTC', 'precio': '0.000001877'}, {'tipo': 'ZEC_BTC', 'precio': '0.000432'}, {'tipo': 'ZEC_ETH', 'precio': '0.00889'}, {'tipo': 'ZEC_USDT', 'precio': '30.2'}, {'tipo': 'ZRX_BTC', 'precio': '0.00001101'}, {'tipo': 'ZRX_ETH', 'precio': '0.000232'}, {'tipo': 'CVC_BTC', 'precio': '0.000003176'}, {'tipo': 'OMG_BTC', 'precio': '0.00001258'}, {'tipo': 'GAS_BTC', 'precio': '0.0001'}, {'tipo': 'STORJ_BTC', 'precio': '0.00001063'}, {'tipo': 'EOS_BTC', 'precio': '0.00001553'}, {'tipo': 'EOS_ETH', 'precio': '0.0003188'}, {'tipo': 'EOS_USDT', 'precio': '1.0868'}, {'tipo': 'SNT_BTC', 'precio': '0.000000574'}, {'tipo': 'KNC_BTC', 'precio': '0.00001243'}, {'tipo': 'BAT_BTC', 'precio': '0.00000431'}, {'tipo': 'BAT_USDT', 'precio': '0.3269'}, {'tipo': 'LOOM_BTC', 'precio': '0.000001506'}, {'tipo': 'DOGE_USDT', 'precio': '0.204144'}, {'tipo': 'LSK_USDT', 'precio': '0.8481'}, {'tipo': 'SC_USDT', 'precio': '0.00995'}, {'tipo': 'ZRX_USDT', 'precio': '0.7654'}, {'tipo': 'QTUM_BTC', 'precio': '0.0000673'}, {'tipo': 'QTUM_USDT', 'precio': '4.629'}, {'tipo': 'BTC_USDC', 'precio': '69813.89'}, {'tipo': 'ETH_USDC', 'precio': '3514.51'}, {'tipo': 'USDT_USDC', 'precio': '1.00219'}, {'tipo': 'MANA_BTC', 'precio': '0.00000951'}, {'tipo': 'MANA_USDT', 'precio': '0.6634'}, {'tipo': 'BNT_BTC', 'precio': '0.00001151'}, {'tipo': 'BCHSV_BTC', 'precio': '0.00142'}, {'tipo': 'BCHSV_USDC', 'precio': '98.52'}, {'tipo': 'XRP_USDC', 'precio': '0.6377'}, {'tipo': 'XMR_USDC', 'precio': '116'}, {'tipo': 'XLM_USDC', 'precio': '0.1272'}, {'tipo': 'DOGE_USDC', 'precio': '0.2'}, {'tipo': 'LTC_USDC', 'precio': '105.68'}, {'tipo': 'ZEC_USDC', 'precio': '26.82'}, {'tipo': 'NMR_BTC', 'precio': '0.000463'}, {'tipo': 'POLY_BTC', 'precio': '0.000000753'}, {'tipo': 'LPT_BTC', 'precio': '0.0003031'}, {'tipo': 'ATOM_BTC', 'precio': '0.0001767'}, {'tipo': 'ATOM_USDC', 'precio': '10.97'}, {'tipo': 'ATOM_USDT', 'precio': '12.335'}, {'tipo': 'DASH_USDC', 'precio': '39.6'}, {'tipo': 'EOS_USDC', 'precio': '1.5474'}, {'tipo': 'ETC_USDC', 'precio': '24.88'}, {'tipo': 'BCHSV_USDT', 'precio': '100.16'}, {'tipo': 'TRX_BTC', 'precio': '0.000001751'}, {'tipo': 'TRX_USDC', 'precio': '0.12573'}, {'tipo': 'TRX_USDT', 'precio': '0.12243'}, {'tipo': 'ETH_TRX', 'precio': '28709.87'}, {'tipo': 'XRP_TRX', 'precio': '5.049'}, {'tipo': 'BTT_USDT', 'precio': '0.0000015944'}, {'tipo': 'BTT_TRX', 'precio': '0.00001251'}, {'tipo': 'WIN_USDT', 'precio': '0.00017009'}, {'tipo': 'WIN_TRX', 'precio': '0.001183'}, {'tipo': 'STEEM_TRX', 'precio': '2.5'}, {'tipo': 'LINK_BTC', 'precio': '0.0002673'}, {'tipo': 'LINK_TRX', 'precio': '146.03'}, {'tipo': 'XTZ_BTC', 'precio': '0.00001851'}, {'tipo': 'XTZ_USDT', 'precio': '1.37'}, {'tipo': 'XTZ_TRX', 'precio': '11.7'}, {'tipo': 'USDJ_USDT', 'precio': '1.1197'}, {'tipo': 'SNX_BTC', 'precio': '0.0000637'}, {'tipo': 'SNX_USDT', 'precio': '4.562'}, {'tipo': 'SNX_TRX', 'precio': '39.48'}, {'tipo': 'MATIC_BTC', 'precio': '0.00001364'}, {'tipo': 'MATIC_USDT', 'precio': '0.98151'},  ...

# %%
# ahora se trabajara para obtener la tabla de Orderbook
# -----------------------------------------------------------------------------
# now, we can do something similar to obtein something like the Orderbook (the records of the current orders)

tipo = "DASH_BTC"
limite = 20
ob = requests.get(f"https://api.poloniex.com/markets/{tipo}/orderBook?limit={limite}")
print(ob.text)
# Out:
# <Response [200]>
# {
#   "time" : 1711852104863,
#   "scale" : "0.000001",
#   "asks" : [ "0.000569", "1.95", "0.00057", "0.04", "0.000581", "1.29", "0.000582", "0.02", "0.000583", "0.14", "0.000588", "0.04", "0.000591", "0.04", "0.000593", "0.03", "0.000594", "0.02", "0.0006", "0.02", "0.000605", "0.02", "0.000606", "0.02", "0.00061", "0.2", "0.000618", "0.02", "0.000624", "4.02", "0.000625", "0.32", "0.00063", "0.02", "0.000632", "0.03", "0.000636", "0.02", "0.000642", "0.05" ],
#   "bids" : [ "0.000558", "20.97", "0.000555", "0.02", "0.000551", "16.78", "0.000549", "1.35", "0.000544", "0.02", "0.000539", "0.02", "0.000536", "0.12", "0.000531", "0.24", "0.000529", "0.02", "0.000525", "0.38", "0.000524", "0.02", "0.000522", "0.03", "0.000517", "0.03", "0.000516", "0.6", "0.000513", "0.11", "0.000512", "0.03", "0.000507", "0.03", "0.000502", "0.03", "0.0005", "0.4", "0.000495", "1.13" ],
#   "ts" : 1711852105074
# }

# %%
# solo tomaremos lo contenido en asks y lo separaremos en precios y tamaños dependiendo si el indice es par o impar 
# -----------------------------------------------------------------------------
#  now, we can create a list of the orderbook response and evaluate the content for the asks and divide the data in prices and sizes

preguntar_precios = []
preguntar_tamanos = []
conteo = 0
ob_json = []

if ob.status_code == 200:
    ob_json = json.loads(ob.text)

    # usando un contador y dividiendolo entre %2 para saber si el indice is par o no (par es precio, impar es tamaño)
    # -----------------------------------------------------------------------------
    # we can use a counter and divide it %2 to evaluate if the index is even or not (even = prices, else = size)
    
    for a in ob_json["asks"]:
        if conteo % 2 == 0:
            preguntar_precios.append(a)
        else:
            preguntar_tamanos.append(a)
        conteo += 1
        
    print(preguntar_precios)
    print(preguntar_tamanos)
# Out:
# ['0.000569', '0.00057', '0.000581', '0.000582', '0.000583', '0.000588', '0.000591', '0.000593', '0.000594', '0.0006', '0.000605', '0.000606', '0.00061', '0.000618', '0.000624', '0.000625', '0.00063', '0.000632', '0.000636', '0.000642']
# ['1.95', '0.04', '1.29', '0.02', '0.14', '0.04', '0.04', '0.03', '0.02', '0.02', '0.02', '0.02', '0.2', '0.02', '4.02', '0.32', '0.02', '0.03', '0.02', '0.05']

# %%
# Basicamente asi funcionan todas las apis de este tipo curl/url
# -----------------------------------------------------------------------------
# this is basically how curls/url apis works
