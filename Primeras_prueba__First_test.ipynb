# %%
# Para poder trabajar con las API de las exchanges siempre hay importar requests que es la libreria para solicitar informacion via http
# la documentacion se encuentra en: https://requests.readthedocs.io/en/latest/user/quickstart/
# -----------------------------------------------------------------------------
# To be able to work with these kind of APIs (Exchange Apis are curls apis) you must import requests, this extension will help you to manage
# the https requests
# for more details you can consult the next webpage: https://requests.readthedocs.io/en/latest/user/quickstart/

import requests

# Tambien sera neceario importar la libreria json para generar o leer informacion en esta estructuracion de datos
# -----------------------------------------------------------------------------
# Also... It could be neccesary to import json, to manage json data/structure

import json

# %%
# se usa la funcion get para conseguir la informacion del url/servidor en cuestion
# para esta etapa del ejemplo se usa /price que es para obtener la tabla de precios
# para mas detalles de la api/url de poloniex: https://api-docs.poloniex.com/
# -----------------------------------------------------------------------------
# the function get makes a GET request to the pointed url/server
# In this particular case we are using the poloniex url with the ending /prices, that will responde with the current prices table
# for more details: https://api-docs.poloniex.com/

precios = requests.get("https://api.poloniex.com/markets/price")

# lo que se recicbe es el codigo de estatus de la comunicacion con el servidor
# -----------------------------------------------------------------------------
# if you print directly the response you will printe just the response code of the url

print(precios)
# Out:
# <Response [200]>

# %%
# Para tener un mejor entendimiento de los codigos hay que conocer el protocolo http
# para mas informacion: https://developer.mozilla.org/es/docs/Web/HTTP/Status
# -----------------------------------------------------------------------------
# to get a better understanding of this codes you need to read a little bit more about the http protocol
# more info in: https://developer.mozilla.org/es/docs/Web/HTTP/Status

# el codigo 200 significa comunicacion exitosa
# -----------------------------------------------------------------------------
# for example the code 200 means success in the comunication with the url/server

if precios.status_code == 200:
    print("¡Exito!")

# un codigo 404 significaria un error en la comunicacion o en el propio servidor
# -----------------------------------------------------------------------------
# and a code 404 means that the url/server was not find (no comunnication)

elif precios.status_code == 404:
    print("Error 404, ¡Pagina no encontrada!")
# Out:
# ¡Exito!

# %%
# siempre se recomienda antes de continuar el proceso es confirmar el codigo de comunicacion exitosa (200)
# nota: los datos que se obtengan van a estar en forma de bytes (usando content,- informacion original)
# -----------------------------------------------------------------------------
# you should evaluate the code before to continue with all the process
# note: the base content will be always in bytes and not in text

if precios.status_code == 200:
    print(precios.content)
# Out:
# b'[ {\n  "symbol" : "BTS_BTC",\n  "price" : "0.0000000501",\n  "time" : 1711915236847,\n  "dailyChange" : "-0.0973",\n  "ts" : 1711915236862\n}, {\n  "symbol" : "DASH_BTC",\n  "price" : "0.000567",\n  "time" : 1711915688975,\n  "dailyChange" : "0.0161",\n  "ts" : 1711915688983\n}, {\n  "symbol" : "DOGE_BTC",\n  "price" : "0.000003088",\n  "time" : 1711923923658,\n  "dailyChange" : "0.0741",\n  "ts" : 1711923923671\n}, {\n  "symbol" : "LTC_BTC",\n  "price" : "0.001485",\n  "time" : 1711923892216,\n  "dailyChange" : "0.0109",\n  "ts" : 1711923892231\n}, {\n  "symbol" : "XLM_BTC",\n  "price" : "0.000001978",\n  "time" : 1711917536747,\n  "dailyChange" : "0.003",\n  "ts" : 1711917536755\n}, {\n  "symbol" : "XEM_BTC",\n  "price" : "0.000000724",\n  "time" : 1711923596896,\n  "dailyChange" : "-0.0041",\n  "ts" : 1711923596903\n}, {\n  "symbol" : "XMR_BTC",\n  "price" : "0.001637",\n  "time" : 1711923036481,\n  "dailyChange" : "-0.0291",\n  "ts" : 1711923036492\n}, {\n  "symbol" : "XRP_BTC",\n  "price" : "0.00000889",\n  "time" : 1711921082377,\n  "dailyChange" : "-0.0011",\n  "ts" : 1711921082389\n}, {\n  "symbol" : "BTC_USDT",\n  "price" : "70864.31",\n  "time" : 1711924240389,\n  "dailyChange" : "0.0158",\n  "ts" : 1711924240401\n}, {\n  "symbol" : "DASH_USDT",\n  "price" : "39.78",\n  "time" : 1711907267039,\n  "dailyChange" : "0.02",\n  "ts" : 1711907267051\n}, {\n  "symbol" : "LTC_USDT",\n  "price" : "105.001",\n  "time" : 1711924246085,\n  "dailyChange" : "0.0308",\n  "ts" : 1711924246093\n}, {\n  "symbol" : "XLM_USDT",\n  "price" : "0.1395",\n  "time" : 1711922004119,\n  "dailyChange" : "0.0058",\n  "ts" : 1711922004125\n}, {\n  "symbol" : "XMR_USDT",\n  "price" : "115.66",\n  "time" : 1711924245749,\n  "dailyChange" : "-0.0319",\n  "ts" : 1711924245764\n}, {\n  "symbol" : "XRP_USDT",\n  "price" : "0.627",\n  "time" : 1711924245543,\n  "dailyChange" : "0.0084",\n  "ts" : 1711924245551\n}, {\n  "symbol" : "ETH_BTC",\n  "price" : "0.05122",\n  "time" : 1711923655520,\n  "dailyChange" : "0.0145",\n  "ts" : 1711923655532\n}, {\n  "symbol" : "ETH_USDT",\n  "price" : "3629.95",\n  "time" : 1711924242729,\n  "dailyChange" : "0.0344",\n  "ts" : 1711924242739\n}, {\n  "symbol" : "SC_BTC",\n  "price" : "0.000000142",\n  "time" : 1711893532848,\n  "dailyChange" : "-0.0132",\n  "ts" : 1711893532863\n}, {\n  "symbol" : "DCR_BTC",\n  "price" : "0.000387",\n  "time" : 1711922942471,\n  "dailyChange" : "-0.0102",\n  "ts" : 1711922942479\n}, {\n  "symbol" : "LSK_BTC",\n  "price" : "0.00001313",\n  "time" : 1711900481803,\n  "dailyChange" : "-0.0008",\n  "ts" : 1711900481814\n}, {\n  "symbol" : "STEEM_BTC",\n  "price" : "0.00000524",\n  "time" : 1711719124087,\n  "dailyChange" : "0.00",\n  "ts" : 1711719124096\n}, {\n  "symbol" : "ETC_BTC",\n  "price" : "0.000484",\n  "time" : 1711922723824,\n  "dailyChange" : "0.0254",\n  "ts" : 1711922723837\n}, {\n  "symbol" : "ETC_ETH",\n  "price" : "0.00953",\n  "time" : 1711921276340,\n  "dailyChange" : "0.0042",\n  "ts" : 1711921276353\n}, {\n  "symbol" : "ETC_USDT",\n  "price" : "34.187",\n  "time" : 1711924242277,\n  "dailyChange" : "0.0379",\n  "ts" : 1711924242287\n}, {\n  "symbol" : "ARDR_BTC",\n  "price" : "0.000001806",\n  "time" : 1711907902913,\n  "dailyChange" : "-0.0378",\n  "ts" : 1711907902922\n}, {\n  "symbol" : "ZEC_BTC",\n  "price" : "0.00043",\n  "time" : 1711916614392,\n  "dailyChange" : "-0.0046",\n  "ts" : 1711916614401\n}, {\n  "symbol" : "ZEC_ETH",\n  "price" : "0.00842",\n  "time" : 1711909331328,\n  "dailyChange" : "-0.0529",\n  "ts" : 1711909331343\n}, {\n  "symbol" : "ZEC_USDT",\n  "price" : "30.25",\n  "time" : 1711924244128,\n  "dailyChange" : "0.0046",\n  "ts" : 1711924244137\n}, {\n  "symbol" : "ZRX_BTC",\n  "price" : "0.00001101",\n  "time" : 1711843430220,\n  "dailyChange" : "0.0251",\n  "ts" : 1711843430235\n}, {\n  "symbol" : "ZRX_ETH",\n  "price" : "0.000232",\n  "time" : 1711804803474,\n  "dailyChange" : "0.00",\n  "ts" : 1711804803485\n}, {\n  "symbol" : "CVC_BTC",\n ...

# %%
# si se desea que estos esten en forma de texto se puede usar (usando text)
# -----------------------------------------------------------------------------
# we can soulve this issue using the .text instead of the original .content

if precios.status_code == 200:
    print(precios.text)
# Out:
# [ {
#   "symbol" : "BTS_BTC",
#   "price" : "0.0000000501",
#   "time" : 1711915236847,
#   "dailyChange" : "-0.0973",
#   "ts" : 1711915236862
# }, {
#   "symbol" : "DASH_BTC",
#   "price" : "0.000567",
#   "time" : 1711915688975,
#   "dailyChange" : "0.0161",
#   "ts" : 1711915688983
# }, {
#   "symbol" : "DOGE_BTC",
#   "price" : "0.000003088",
#   "time" : 1711923923658,
#   "dailyChange" : "0.0741",
#   "ts" : 1711923923671
# }, {
#   "symbol" : "LTC_BTC",
#   "price" : "0.001485",
#   "time" : 1711923892216,
#   "dailyChange" : "0.0109",
#   "ts" : 1711923892231
# }, {
#   "symbol" : "XLM_BTC",
#   "price" : "0.000001978",
#   "time" : 1711917536747,
#   "dailyChange" : "0.003",
#   "ts" : 1711917536755
# }, {
#   "symbol" : "XEM_BTC",
#   "price" : "0.000000724",
#   "time" : 1711923596896,
#   "dailyChange" : "-0.0041",
#   "ts" : 1711923596903
# }, {
#   "symbol" : "XMR_BTC",
#   "price" : "0.001637",
#   "time" : 1711923036481,
#   "dailyChange" : "-0.0291",
#   "ts" : 1711923036492
# }, {
#   "symbol" : "XRP_BTC",
#   "price" : "0.00000889",
#   "time" : 1711921082377,
#   "dailyChange" : "-0.0011",
#   "ts" : 1711921082389
# }, {
#   "symbol" : "BTC_USDT",
#   "price" : "70864.31",
#   "time" : 1711924240389,
#   "dailyChange" : "0.0158",
#   "ts" : 1711924240401
# }, {
#   "symbol" : "DASH_USDT",
#   "price" : "39.78",
#   "time" : 1711907267039,
#   "dailyChange" : "0.02",
#   "ts" : 1711907267051
# }, {
#   "symbol" : "LTC_USDT",
#   "price" : "105.001",
#   "time" : 1711924246085,
#   "dailyChange" : "0.0308",
#   "ts" : 1711924246093
# }, {
#   "symbol" : "XLM_USDT",
#   "price" : "0.1395",
#   "time" : 1711922004119,
#   "dailyChange" : "0.0058",
#   "ts" : 1711922004125
# }, {
#   "symbol" : "XMR_USDT",
#   "price" : "115.66",
#   "time" : 1711924245749,
#   "dailyChange" : "-0.0319",
#   "ts" : 1711924245764
# }, {
#   "symbol" : "XRP_USDT",
#   "price" : "0.627",
#   "time" : 1711924245543,
#   "dailyChange" : "0.0084",
#   "ts" : 1711924245551
# }, {
#   "symbol" : "ETH_BTC",
#   "price" : "0.05122",
#   "time" : 1711923655520,
#   "dailyChange" : "0.0145",
#   "ts" : 1711923655532
# }, {
#   "symbol" : "ETH_USDT",
#   "price" : "3629.95",
#   "time" : 1711924242729,
#   "dailyChange" : "0.0344",
#   "ts" : 1711924242739
# }, {
#   "symbol" : "SC_BTC",
#   "price" : "0.000000142",
#   "time" : 1711893532848,
#   "dailyChange" : "-0.0132",
#   "ts" : 1711893532863
# }, {
#   "symbol" : "DCR_BTC",
#   "price" : "0.000387",
#   "time" : 1711922942471,
#   "dailyChange" : "-0.0102",
#   "ts" : 1711922942479
# }, {
#   "symbol" : "LSK_BTC",
#   "price" : "0.00001313",
#   "time" : 1711900481803,
#   "dailyChange" : "-0.0008",
#   "ts" : 1711900481814
# }, {
#   "symbol" : "STEEM_BTC",
#   "price" : "0.00000524",
#   "time" : 1711719124087,
#   "dailyChange" : "0.00",
#   "ts" : 1711719124096
# }, {
#   "symbol" : "ETC_BTC",
#   "price" : "0.000484",
#   "time" : 1711922723824,
#   "dailyChange" : "0.0254",
#   "ts" : 1711922723837
# }, {
#   "symbol" : "ETC_ETH",
#   "price" : "0.00953",
#   "time" : 1711921276340,
#   "dailyChange" : "0.0042",
#   "ts" : 1711921276353
# }, {
#   "symbol" : "ETC_USDT",
#   "price" : "34.187",
#   "time" : 1711924242277,
#   "dailyChange" : "0.0379",
#   "ts" : 1711924242287
# }, {
#   "symbol" : "ARDR_BTC",
#   "price" : "0.000001806",
#   "time" : 1711907902913,
#   "dailyChange" : "-0.0378",
#   "ts" : 1711907902922
# }, {
#   "symbol" : "ZEC_BTC",
#   "price" : "0.00043",
#   "time" : 1711916614392,
#   "dailyChange" : "-0.0046",
#   "ts" : 1711916614401
# }, {
#   "symbol" : "ZEC_ETH",
#   "price" : "0.00842",
#   "time" : 1711909331328,
#   "dailyChange" : "-0.0529",
#   "ts" : 1711909331343
# }, {
#   "symbol" : "ZEC_USDT",
#   "price" : "30.25",
#   "time" : 1711924244128,
#   "dailyChange" : "0.0046",
#   "ts" : 1711924244137
# }, {
#   "symbol" : "ZRX_BTC",
#   "price" : "0.00001101",
#   "time" : 1711843430220,
#   "dailyChange" : "0.0251",
#   "ts" : 1711843430235
# }, {
#   "symbol" : "ZRX_ETH",
#   "price" : "0.000232",
#   "time" : 1711804803474,
#   "dailyChange" : "0.00",
#   "ts" : 1711804803485
# }, {
#   "symbol" : "CVC_BTC",
#   "price" : "0.000003176",
#   "time" : 1711756951382,
#   "dailyChange" : "0.00",
#   "ts" : 1711756951395
# }, {
#   "symbol" : "OMG_BTC",
#   "price" : "0.0000125",
#   "time" : 1711916481240,
#   "dailyChange" : "-0.0008",
#   "ts" : 1711916481255
# }, {
#   "symbol" : "GAS_BTC",
#   "price" : "0.0000929",
#   "time" : 1711908054810,
#   "dailyChange" : "-0.071",
#   "ts" : 1711908054817
# }, {
#   "symbol" : "STORJ_BTC",
#   "price" : "0.00001042",
#   "time" : 1711916538884,
#   "dailyChange" : "-0.0198",
#   "ts" : 1711916538899
# }, {
#   "symbol" : "EOS_BTC",
#   "price" : "0.00001554",
#   "time" : 1711921268882,
#   "dailyChange" : "0.0052",
#   "ts" : 1711921268891
# }, {
#   "symbol" : "EOS_ETH",
#   "price" : "0.000313",
#   "time" : 1711921266462,
#   "dailyChange" : "-0.0182",
#   "ts" : 1711921266469
# }, {
#   "symbol" : "EOS_USDT",
#   "price" : "1.1014",
#   "time" : 1711924240468,
#   "dailyChange" : "0.0185",
#   "ts" : 1711924240478
# }, {
#   "symbol" : "SNT_BTC",
#   "price" : "0.000000574",
#   "time" : 1711826470824,
#   "dailyChange" : "0.00",
#   "ts" : 1711826470836
# }, {
#   "symbol" : "KNC_BTC",
#   "price" : "0.00001243",
#   "time" : 1711559354742,
#   "dailyChange" : "0.00",
#   "ts" : 1711559354749
# }, {
#   "symbol" : "BAT_BTC",
#   "price" : "0.00000431",
#   "time" : 1711686871880,
#   "dailyChange" : "0.00",
#   "ts" : 1711686871888
# }, {
#   "symbol" : "BAT_USDT",
#   "price" : "0.3274",
#   "time" : 1711903151669,
#   "dailyChange" : "0.0015",
#   "ts" : 1711903151676
# }, {
#   "symbol" : "LOOM_BTC",
#   "price" : "0.000001506",
#   "time" : 1711637510184,
#   "dailyChange" : "0.00",
#   "ts" : 1711637510191
# }, {
#   "symbol" : "DOGE_USDT",
#   "price" : "0.21769",
#   "time" : 1711924244811,
#   "dailyChange" : "0.0831",
#   "ts" : 1711924244823
# }, {
#   "symbol" : "LSK_USDT",
#   "price" : "0.9104",
#   "time" : 1711900481441,
#   "dailyChange" : "0.0735",
#   "ts" : 1711900481456
# }, {
#   "symbol" : "SC_USDT",
#   "price" : "0.010114",
#   "time" : 1711923834360,
#   "dailyChange" : "0.0091",
#   "ts" : 1711923834373
# }, {
#   "symbol" : "ZRX_USDT",
#   "price" : "0.7384",
#   "time" : 1711900497949,
#   "dailyChange" : "-0.0155",
#   "ts" : 1711900497959
# }, {
#   "symbol" : "QTUM_BTC",
#   "price" : "0.0000673",
#   "time" : 1711826628905,
#   "dailyChange" : "0.00",
#   "ts" : 1711826628918
# }, {
#   "symbol" : "QTUM_USDT",
#   "price" : "4.509",
#   "time" : 1711870844505,
#   "dailyChange" : "-0.0259",
#   "ts" : 1711870844518
# }, {
#   "symbol" : "BTC_USDC",
#   "price" : "71547.84",
#   "time" : 1711922967761,
#   "dailyChange" : "0.0166",
#   "ts" : 1711922967773
# }, {
#   "symbol" : "ETH_USDC",
#   "price" : "3633.13",
#   "time" : 1711922535985,
#   "dailyChange" : "0.0338",
#   "ts" : 1711922535993
# }, {
#   "symbol" : "USDT_USDC",
#   "price" : "1.0016",
#   "time" : 1711923868180,
#   "dailyChange" : "-0.0006",
#   "ts" : 1711923868189
# }, {
#   "symbol" : "MANA_BTC",
#   "price" : "0.00000951",
#   "time" : 1711890816142,
#   "dailyChange" : "0.0303",
#   "ts" : 1711890816155
# }, {
#   "symbol" : "MANA_USDT",
#   "price" : "0.6625",
#   "time" : 1711924246058,
#   "dailyChange" : "-0.0026",
#   "ts" : 1711924246065
# }, {
#   "symbol" : "BNT_BTC",
#   "price" : "0.00001151",
#   "time" : 1711826452875,
#   "dailyChange" : "0.00",
#   "ts" : 1711826452884
# }, {
#   "symbol" : "BCHSV_BTC",
#   "price" : "0.001366",
#   "time" : 1711920046871,
#   "dailyChange" : "-0.0284",
#   "ts" : 1711920046883
# }, {
#   "symbol" : "BCHSV_USDC",
#   "price" : "90.12",
#   "time" : 1711872211397,
#   "dailyChange" : "-0.0798",
#   "ts" : 1711872211407
# }, {
#   "symbol" : "XRP_USDC",
#   "price" : "0.6649",
#   "time" : 1711897600495,
#   "dailyChange" : "0.0427",
#   "ts" : 1711897600508
# }, {
#   "symbol" : "XMR_USDC",
#   "price" : "116",
#   "time" : 1711921091813,
#   "dailyChange" : "-0.0333",
#   "ts" : 1711921091825
# }, {
#   "symbol" : "XLM_USDC",
#   "price" : "0.1409",
#   "time" : 1711909678678,
#   "dailyChange" : "0.1077",
#   "ts" : 1711909678685
# }, {
#   "symbol" : "DOGE_USDC",
#   "price" : "0.2",
#   "time" : 1711835577172,
#   "dailyChange" : "0.00",
#   "ts" : 1711835577181
# }, {
#   "symbol" : "LTC_USDC",
#   "price" : "106.14",
#   "time" : 1711915967596,
#   "dailyChange" : "0.0016",
#   "ts" : 1711915967601
# }, {
#   "symbol" : "ZEC_USDC",
#   "price" : "30.18",
#   "time" : 1711921444067,
#   "dailyChange" : "0.1253",
#   "ts" : 1711921444078
# }, {
#   "symbol" : "NMR_BTC",
#   "price" : "0.000463",
#   "time" : 1711652065843,
#   "dailyChange" : "0.00",
#   "ts" : 1711652065850
# }, {
#   "symbol" : "POLY_BTC",
#   "price" : "0.000000792",
#   "time" : 1711912450451,
#   "dailyChange" : "0.0518",
#   "ts" : 1711912450466
# }, {
#   "symbol" : "LPT_BTC",
#   "price" : "0.0002682",
#   "time" : 1711911066431,
#   "dailyChange" : "-0.1151",
#   "ts" : 1711911066444
# }, {
#   "symbol" : "ATOM_BTC",
#   "price" : "0.0001724",
#   "time" : 1711917538513,
#   "dailyChange" : "-0.0243",
#   "ts" : 1711917538524
# }, {
#   "symbol" : "ATOM_USDC",
#   "price" : "10.97",
#   "time" : 1710788766030,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659248
# }, {
#   "symbol" : "ATOM_USDT",
#   "price" : "12.19",
#   "time" : 1711924245357,
#   "dailyChange" : "-0.0106",
#   "ts" : 1711924245365
# }, {
#   "symbol" : "DASH_USDC",
#   "price" : "39.74",
#   "time" : 1711907267023,
#   "dailyChange" : "0.0035",
#   "ts" : 1711907267031
# }, {
#   "symbol" : "EOS_USDC",
#   "price" : "1.5474",
#   "time" : 1711592989864,
#   "dailyChange" : "0.00",
#   "ts" : 1711592989875
# }, {
#   "symbol" : "ETC_USDC",
#   "price" : "38",
#   "time" : 1711893834260,
#   "dailyChange" : "0.5273",
#   "ts" : 1711893834274
# }, {
#   "symbol" : "BCHSV_USDT",
#   "price" : "95.28",
#   "time" : 1711920046857,
#   "dailyChange" : "-0.0229",
#   "ts" : 1711920046867
# }, {
#   "symbol" : "TRX_BTC",
#   "price" : "0.000001719",
#   "time" : 1711923516131,
#   "dailyChange" : "-0.0222",
#   "ts" : 1711923516139
# }, {
#   "symbol" : "TRX_USDC",
#   "price" : "0.12302",
#   "time" : 1711923868149,
#   "dailyChange" : "0.0992",
#   "ts" : 1711923868161
# }, {
#   "symbol" : "TRX_USDT",
#   "price" : "0.12281",
#   "time" : 1711924200293,
#   "dailyChange" : "0.0002",
#   "ts" : 1711924200310
# }, {
#   "symbol" : "ETH_TRX",
#   "price" : "29221.44",
#   "time" : 1711914318936,
#   "dailyChange" : "0.0253",
#   "ts" : 1711914318946
# }, {
#   "symbol" : "XRP_TRX",
#   "price" : "5.101",
#   "time" : 1711898178269,
#   "dailyChange" : "0.0085",
#   "ts" : 1711898178281
# }, {
#   "symbol" : "BTT_USDT",
#   "price" : "0.0000016122",
#   "time" : 1711924242232,
#   "dailyChange" : "0.0103",
#   "ts" : 1711924242246
# }, {
#   "symbol" : "BTT_TRX",
#   "price" : "0.0000129",
#   "time" : 1711919009475,
#   "dailyChange" : "-0.01",
#   "ts" : 1711919009485
# }, {
#   "symbol" : "WIN_USDT",
#   "price" : "0.00016801",
#   "time" : 1711924246182,
#   "dailyChange" : "-0.0332",
#   "ts" : 1711924246192
# }, {
#   "symbol" : "WIN_TRX",
#   "price" : "0.001294",
#   "time" : 1711918965193,
#   "dailyChange" : "0.0938",
#   "ts" : 1711918965209
# }, {
#   "symbol" : "STEEM_TRX",
#   "price" : "2.5",
#   "time" : 1711805118982,
#   "dailyChange" : "0.00",
#   "ts" : 1711805118990
# }, {
#   "symbol" : "LINK_BTC",
#   "price" : "0.0002673",
#   "time" : 1711826418197,
#   "dailyChange" : "0.00",
#   "ts" : 1711826418206
# }, {
#   "symbol" : "LINK_TRX",
#   "price" : "146.03",
#   "time" : 1711052964112,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659324
# }, {
#   "symbol" : "XTZ_BTC",
#   "price" : "0.00002082",
#   "time" : 1711865080561,
#   "dailyChange" : "0.1248",
#   "ts" : 1711865080566
# }, {
#   "symbol" : "XTZ_USDT",
#   "price" : "1.3894",
#   "time" : 1711874161789,
#   "dailyChange" : "0.0142",
#   "ts" : 1711874161803
# }, {
#   "symbol" : "XTZ_TRX",
#   "price" : "11.7",
#   "time" : 1711497774587,
#   "dailyChange" : "0.00",
#   "ts" : 1711497774596
# }, {
#   "symbol" : "USDJ_USDT",
#   "price" : "1.1197",
#   "time" : 1711782278433,
#   "dailyChange" : "0.00",
#   "ts" : 1711782278448
# }, {
#   "symbol" : "SNX_BTC",
#   "price" : "0.0000663",
#   "time" : 1711913479357,
#   "dailyChange" : "0.0408",
#   "ts" : 1711913479366
# }, {
#   "symbol" : "SNX_USDT",
#   "price" : "4.734",
#   "time" : 1711910413144,
#   "dailyChange" : "0.0361",
#   "ts" : 1711910413155
# }, {
#   "symbol" : "SNX_TRX",
#   "price" : "37.63",
#   "time" : 1711890150649,
#   "dailyChange" : "-0.0469",
#   "ts" : 1711890150659
# }, {
#   "symbol" : "MATIC_BTC",
#   "price" : "0.0000139",
#   "time" : 1711875611163,
#   "dailyChange" : "0.0191",
#   "ts" : 1711875611177
# }, {
#   "symbol" : "MATIC_USDT",
#   "price" : "0.99796",
#   "time" : 1711924245819,
#   "dailyChange" : "0.0161",
#   "ts" : 1711924245828
# }, {
#   "symbol" : "MATIC_TRX",
#   "price" : "8.41",
#   "time" : 1711568608242,
#   "dailyChange" : "0.00",
#   "ts" : 1711568608253
# }, {
#   "symbol" : "MKR_BTC",
#   "price" : "0.05312",
#   "time" : 1711844141442,
#   "dailyChange" : "-0.0054",
#   "ts" : 1711844141450
# }, {
#   "symbol" : "MKR_USDT",
#   "price" : "3949.97",
#   "time" : 1711924244255,
#   "dailyChange" : "0.0557",
#   "ts" : 1711924244261
# }, {
#   "symbol" : "DAI_USDT",
#   "price" : "0.994",
#   "time" : 1711913269678,
#   "dailyChange" : "0.0237",
#   "ts" : 1711913269693
# }, {
#   "symbol" : "NEO_BTC",
#   "price" : "0.0002317",
#   "time" : 1711922840159,
#   "dailyChange" : "0.0307",
#   "ts" : 1711922840174
# }, {
#   "symbol" : "NEO_USDT",
#   "price" : "16.48",
#   "time" : 1711922833356,
#   "dailyChange" : "0.00",
#   "ts" : 1711922833370
# }, {
#   "symbol" : "NEO_TRX",
#   "price" : "112",
#   "time" : 1711740026008,
#   "dailyChange" : "0.00",
#   "ts" : 1711740026017
# }, {
#   "symbol" : "SWFTC_BTC",
#   "price" : "0.0000000313",
#   "time" : 1711788211205,
#   "dailyChange" : "0.00",
#   "ts" : 1711788211210
# }, {
#   "symbol" : "SWFTC_USDT",
#   "price" : "0.002126",
#   "time" : 1711860448391,
#   "dailyChange" : "0.0066",
#   "ts" : 1711860448406
# }, {
#   "symbol" : "SWFTC_TRX",
#   "price" : "0.014",
#   "time" : 1711855628126,
#   "dailyChange" : "-0.4626",
#   "ts" : 1711855628134
# }, {
#   "symbol" : "JST_USDT",
#   "price" : "0.040367",
#   "time" : 1711924245279,
#   "dailyChange" : "-0.0025",
#   "ts" : 1711924245286
# }, {
#   "symbol" : "JST_TRX",
#   "price" : "0.3329",
#   "time" : 1711472105381,
#   "dailyChange" : "0.00",
#   "ts" : 1711472105388
# }, {
#   "symbol" : "STEEM_USDT",
#   "price" : "0.33453",
#   "time" : 1711919208919,
#   "dailyChange" : "-0.0203",
#   "ts" : 1711919208929
# }, {
#   "symbol" : "LINK_USDT",
#   "price" : "18.9814",
#   "time" : 1711924245842,
#   "dailyChange" : "0.0012",
#   "ts" : 1711924245848
# }, {
#   "symbol" : "AVA_BTC",
#   "price" : "0.00001241",
#   "time" : 1711922473303,
#   "dailyChange" : "0.0172",
#   "ts" : 1711922473313
# }, {
#   "symbol" : "AVA_USDT",
#   "price" : "0.8703",
#   "time" : 1711914320034,
#   "dailyChange" : "0.0116",
#   "ts" : 1711914320049
# }, {
#   "symbol" : "AVA_TRX",
#   "price" : "6.84",
#   "time" : 1711841009189,
#   "dailyChange" : "-0.05",
#   "ts" : 1711841009202
# }, {
#   "symbol" : "XRPBULL_USDT",
#   "price" : "0.00000323",
#   "time" : 1668730134574,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659496
# }, {
#   "symbol" : "CHR_BTC",
#   "price" : "0.00000708",
#   "time" : 1711826450286,
#   "dailyChange" : "0.00",
#   "ts" : 1711826450297
# }, {
#   "symbol" : "CHR_USDT",
#   "price" : "0.4696",
#   "time" : 1711905948023,
#   "dailyChange" : "0.0119",
#   "ts" : 1711905948036
# }, {
#   "symbol" : "CHR_TRX",
#   "price" : "3.3",
#   "time" : 1711902404569,
#   "dailyChange" : "-0.2667",
#   "ts" : 1711902404575
# }, {
#   "symbol" : "BTC_BNB",
#   "price" : "108.18",
#   "time" : 1711913861603,
#   "dailyChange" : "-0.0566",
#   "ts" : 1711913861614
# }, {
#   "symbol" : "BNB_USDT",
#   "price" : "606.84",
#   "time" : 1711924244694,
#   "dailyChange" : "0.0017",
#   "ts" : 1711924244704
# }, {
#   "symbol" : "BNB_TRX",
#   "price" : "4766.48",
#   "time" : 1711917588027,
#   "dailyChange" : "-0.0357",
#   "ts" : 1711917588036
# }, {
#   "symbol" : "MDT_BTC",
#   "price" : "0.000001551",
#   "time" : 1711729869394,
#   "dailyChange" : "0.00",
#   "ts" : 1711729869406
# }, {
#   "symbol" : "MDT_USDT",
#   "price" : "0.09009",
#   "time" : 1711801506493,
#   "dailyChange" : "0.00",
#   "ts" : 1711801506514
# }, {
#   "symbol" : "MDT_TRX",
#   "price" : "0.8",
#   "time" : 1711478146975,
#   "dailyChange" : "0.00",
#   "ts" : 1711478146987
# }, {
#   "symbol" : "COMP_USDT",
#   "price" : "79.98",
#   "time" : 1711771932061,
#   "dailyChange" : "0.00",
#   "ts" : 1711771932072
# }, {
#   "symbol" : "COMP_ETH",
#   "price" : "0.0229",
#   "time" : 1711725985008,
#   "dailyChange" : "0.00",
#   "ts" : 1711725985020
# }, {
#   "symbol" : "REN_BTC",
#   "price" : "0.0000015",
#   "time" : 1711442345684,
#   "dailyChange" : "0.00",
#   "ts" : 1711442345698
# }, {
#   "symbol" : "REN_USDT",
#   "price" : "0.0877",
#   "time" : 1711864017829,
#   "dailyChange" : "-0.1168",
#   "ts" : 1711864017842
# }, {
#   "symbol" : "LRC_BTC",
#   "price" : "0.0000054",
#   "time" : 1711863164885,
#   "dailyChange" : "0.00",
#   "ts" : 1711863164899
# }, {
#   "symbol" : "LRC_USDT",
#   "price" : "0.3731",
#   "time" : 1711787401311,
#   "dailyChange" : "0.00",
#   "ts" : 1711787401324
# }, {
#   "symbol" : "BAL_USDT",
#   "price" : "5.281",
#   "time" : 1711901907827,
#   "dailyChange" : "0.173",
#   "ts" : 1711901907835
# }, {
#   "symbol" : "WRX_BTC",
#   "price" : "0.00000231",
#   "time" : 1711826419691,
#   "dailyChange" : "0.00",
#   "ts" : 1711826419705
# }, {
#   "symbol" : "WRX_USDT",
#   "price" : "0.2271",
#   "time" : 1711909677903,
#   "dailyChange" : "-0.0287",
#   "ts" : 1711909677915
# }, {
#   "symbol" : "WRX_TRX",
#   "price" : "1.709",
#   "time" : 1711909677424,
#   "dailyChange" : "-0.4095",
#   "ts" : 1711909677438
# }, {
#   "symbol" : "SXP_BTC",
#   "price" : "0.00000762",
#   "time" : 1711826435083,
#   "dailyChange" : "0.00",
#   "ts" : 1711826435099
# }, {
#   "symbol" : "SXP_USDT",
#   "price" : "0.5",
#   "time" : 1711884785593,
#   "dailyChange" : "0.02",
#   "ts" : 1711884785602
# }, {
#   "symbol" : "SXP_TRX",
#   "price" : "3.3",
#   "time" : 1710690917239,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659090
# }, {
#   "symbol" : "YFI_USDT",
#   "price" : "8985.35",
#   "time" : 1711895282479,
#   "dailyChange" : "0.0213",
#   "ts" : 1711895282485
# }, {
#   "symbol" : "STPT_BTC",
#   "price" : "0.000001001",
#   "time" : 1711911144759,
#   "dailyChange" : "-0.1142",
#   "ts" : 1711911144767
# }, {
#   "symbol" : "STPT_USDT",
#   "price" : "0.06647",
#   "time" : 1711911144284,
#   "dailyChange" : "-0.1137",
#   "ts" : 1711911144297
# }, {
#   "symbol" : "UMA_USDT",
#   "price" : "4.27",
#   "time" : 1711761939347,
#   "dailyChange" : "0.00",
#   "ts" : 1711761939356
# }, {
#   "symbol" : "RING_USDT",
#   "price" : "0.00407",
#   "time" : 1711901015259,
#   "dailyChange" : "-0.0268",
#   "ts" : 1711901015269
# }, {
#   "symbol" : "SWAP_BTC",
#   "price" : "0.000001554",
#   "time" : 1711826420348,
#   "dailyChange" : "0.00",
#   "ts" : 1711826420355
# }, {
#   "symbol" : "SWAP_USDT",
#   "price" : "0.1107",
#   "time" : 1711825520981,
#   "dailyChange" : "0.00",
#   "ts" : 1711825520995
# }, {
#   "symbol" : "GEEQ_USDT",
#   "price" : "0.0902",
#   "time" : 1711842058757,
#   "dailyChange" : "-0.2953",
#   "ts" : 1711842058771
# }, {
#   "symbol" : "BAND_USDT",
#   "price" : "1.6822",
#   "time" : 1711815444010,
#   "dailyChange" : "0.00",
#   "ts" : 1711815444019
# }, {
#   "symbol" : "DOS_USDT",
#   "price" : "0.001011",
#   "time" : 1673517490627,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659164
# }, {
#   "symbol" : "DIA_USDT",
#   "price" : "0.607",
#   "time" : 1711807943627,
#   "dailyChange" : "0.00",
#   "ts" : 1711807943632
# }, {
#   "symbol" : "TRB_USDT",
#   "price" : "101.57",
#   "time" : 1711883668875,
#   "dailyChange" : "0.0658",
#   "ts" : 1711883668884
# }, {
#   "symbol" : "CRV_USDT",
#   "price" : "0.59",
#   "time" : 1711830262675,
#   "dailyChange" : "0.00",
#   "ts" : 1711830262682
# }, {
#   "symbol" : "OM_USDT",
#   "price" : "0.74749",
#   "time" : 1711908042301,
#   "dailyChange" : "0.0781",
#   "ts" : 1711908042311
# }, {
#   "symbol" : "OCEAN_USDT",
#   "price" : "1.2852",
#   "time" : 1711916094195,
#   "dailyChange" : "-0.0354",
#   "ts" : 1711916094203
# }, {
#   "symbol" : "BLY_USDT",
#   "price" : "0.004515",
#   "time" : 1711343898397,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659201
# }, {
#   "symbol" : "SWINGBY_BTC",
#   "price" : "0.00000001047",
#   "time" : 1711910087130,
#   "dailyChange" : "0.2554",
#   "ts" : 1711910087140
# }, {
#   "symbol" : "SWINGBY_USDT",
#   "price" : "0.000727",
#   "time" : 1711905331118,
#   "dailyChange" : "1.5964",
#   "ts" : 1711905331131
# }, {
#   "symbol" : "SWINGBY_TRX",
#   "price" : "0.02637",
#   "time" : 1710874883919,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659212
# }, {
#   "symbol" : "PRQ_USDT",
#   "price" : "0.1519",
#   "time" : 1711747801273,
#   "dailyChange" : "0.00",
#   "ts" : 1711747801288
# }, {
#   "symbol" : "DOT_USDT",
#   "price" : "9.566",
#   "time" : 1711924244611,
#   "dailyChange" : "0.0128",
#   "ts" : 1711924244617
# }, {
#   "symbol" : "RSR_USDT",
#   "price" : "0.010534",
#   "time" : 1711912890557,
#   "dailyChange" : "0.1276",
#   "ts" : 1711912890567
# }, {
#   "symbol" : "WNXM_USDT",
#   "price" : "72.81",
#   "time" : 1711689957801,
#   "dailyChange" : "0.00",
#   "ts" : 1711689957813
# }, {
#   "symbol" : "FCT2_USDT",
#   "price" : "0.08244",
#   "time" : 1711845245230,
#   "dailyChange" : "0.0305",
#   "ts" : 1711845245239
# }, {
#   "symbol" : "FCT2_BTC",
#   "price" : "0.000003849",
#   "time" : 1711826441957,
#   "dailyChange" : "0.00",
#   "ts" : 1711826441969
# }, {
#   "symbol" : "SUSHI_USDT",
#   "price" : "1.8958",
#   "time" : 1711917474306,
#   "dailyChange" : "0.0294",
#   "ts" : 1711917474316
# }, {
#   "symbol" : "YFII_USDT",
#   "price" : "699",
#   "time" : 1711811919677,
#   "dailyChange" : "0.00",
#   "ts" : 1711811919684
# }, {
#   "symbol" : "FUND_USDT",
#   "price" : "0.17035",
#   "time" : 1711917497083,
#   "dailyChange" : "-0.0694",
#   "ts" : 1711917497096
# }, {
#   "symbol" : "FUND_TRX",
#   "price" : "1.4741",
#   "time" : 1711909708554,
#   "dailyChange" : "-0.031",
#   "ts" : 1711909708562
# }, {
#   "symbol" : "FUND_BTC",
#   "price" : "0.000002564",
#   "time" : 1711899985138,
#   "dailyChange" : "-0.0165",
#   "ts" : 1711899985145
# }, {
#   "symbol" : "AKRO_USDT",
#   "price" : "0.011",
#   "time" : 1711898466303,
#   "dailyChange" : "-0.0832",
#   "ts" : 1711898466308
# }, {
#   "symbol" : "AKRO_BTC",
#   "price" : "0.0000001286",
#   "time" : 1711829984434,
#   "dailyChange" : "0.00",
#   "ts" : 1711829984447
# }, {
#   "symbol" : "UNI_USDT",
#   "price" : "12.8706",
#   "time" : 1711924246165,
#   "dailyChange" : "0.0217",
#   "ts" : 1711924246176
# }, {
#   "symbol" : "DHT_USDT",
#   "price" : "0.055",
#   "time" : 1711712769167,
#   "dailyChange" : "0.00",
#   "ts" : 1711712769177
# }, {
#   "symbol" : "CVP_USDT",
#   "price" : "0.3014",
#   "time" : 1711825267199,
#   "dailyChange" : "0.00",
#   "ts" : 1711825267208
# }, {
#   "symbol" : "GHST_USDT",
#   "price" : "2.0725",
#   "time" : 1711858416850,
#   "dailyChange" : "0.0363",
#   "ts" : 1711858416856
# }, {
#   "symbol" : "REPV2_BTC",
#   "price" : "0.0000121",
#   "time" : 1711786973491,
#   "dailyChange" : "0.00",
#   "ts" : 1711786973499
# }, {
#   "symbol" : "REPV2_USDT",
#   "price" : "1",
#   "time" : 1711886320908,
#   "dailyChange" : "0.1099",
#   "ts" : 1711886320918
# }, {
#   "symbol" : "RARI_USDT",
#   "price" : "1.601",
#   "time" : 1711846275130,
#   "dailyChange" : "-0.3329",
#   "ts" : 1711846275141
# }, {
#   "symbol" : "AMP_BTC",
#   "price" : "0.0000001405",
#   "time" : 1711732476615,
#   "dailyChange" : "0.00",
#   "ts" : 1711732476629
# }, {
#   "symbol" : "AMP_USDT",
#   "price" : "0.012014",
#   "time" : 1711868689571,
#   "dailyChange" : "0.132",
#   "ts" : 1711868689591
# }, {
#   "symbol" : "AMP_TRX",
#   "price" : "0.0628",
#   "time" : 1711419833152,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659335
# }, {
#   "symbol" : "SAND_BTC",
#   "price" : "0.00000895",
#   "time" : 1711826420804,
#   "dailyChange" : "0.00",
#   "ts" : 1711826420813
# }, {
#   "symbol" : "SAND_USDT",
#   "price" : "0.6942",
#   "time" : 1711924246343,
#   "dailyChange" : "-0.0039",
#   "ts" : 1711924246359
# }, {
#   "symbol" : "POLS_USDT",
#   "price" : "0.9383",
#   "time" : 1711917759000,
#   "dailyChange" : "0.0732",
#   "ts" : 1711917759009
# }, {
#   "symbol" : "AAVE_BTC",
#   "price" : "0.001791",
#   "time" : 1711919245410,
#   "dailyChange" : "0.0045",
#   "ts" : 1711919245416
# }, {
#   "symbol" : "AAVE_USDT",
#   "price" : "126.52",
#   "time" : 1711924244344,
#   "dailyChange" : "0.017",
#   "ts" : 1711924244352
# }, {
#   "symbol" : "CVT_BTC",
#   "price" : "0.00000004874",
#   "time" : 1673465404852,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659373
# }, {
#   "symbol" : "CVT_USDT",
#   "price" : "0.00125",
#   "time" : 1673499435734,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659378
# }, {
#   "symbol" : "INJ_BTC",
#   "price" : "0.00056354",
#   "time" : 1711658796746,
#   "dailyChange" : "0.00",
#   "ts" : 1711658796757
# }, {
#   "symbol" : "INJ_USDT",
#   "price" : "37.138",
#   "time" : 1711916099888,
#   "dailyChange" : "0.0424",
#   "ts" : 1711916099902
# }, {
#   "symbol" : "BCH_BTC",
#   "price" : "0.009659",
#   "time" : 1711921495417,
#   "dailyChange" : "0.1312",
#   "ts" : 1711921495431
# }, {
#   "symbol" : "BCH_USDT",
#   "price" : "677.68",
#   "time" : 1711924244109,
#   "dailyChange" : "0.1391",
#   "ts" : 1711924244115
# }, {
#   "symbol" : "BCH_USDC",
#   "price" : "666",
#   "time" : 1711915981601,
#   "dailyChange" : "0.0455",
#   "ts" : 1711915981618
# }, {
#   "symbol" : "SENSO_BTC",
#   "price" : "0.000000805",
#   "time" : 1711880885160,
#   "dailyChange" : "-0.0736",
#   "ts" : 1711880885165
# }, {
#   "symbol" : "SENSO_USDT",
#   "price" : "0.0605",
#   "time" : 1711880972006,
#   "dailyChange" : "0.00",
#   "ts" : 1711880972014
# }, {
#   "symbol" : "KP3R_USDT",
#   "price" : "123.1",
#   "time" : 1711841284114,
#   "dailyChange" : "0.2482",
#   "ts" : 1711841284128
# }, {
#   "symbol" : "GLM_BTC",
#   "price" : "0.00000367",
#   "time" : 1711906556838,
#   "dailyChange" : "0.0638",
#   "ts" : 1711906556850
# }, {
#   "symbol" : "GLM_USDT",
#   "price" : "0.34",
#   "time" : 1711912902282,
#   "dailyChange" : "0.3605",
#   "ts" : 1711912902296
# }, {
#   "symbol" : "ZLOT_USDT",
#   "price" : "4",
#   "time" : 1687336057442,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659423
# }, {
#   "symbol" : "WBTC_BTC",
#   "price" : "0.800151",
#   "time" : 1711826420902,
#   "dailyChange" : "0.00",
#   "ts" : 1711826420908
# }, {
#   "symbol" : "WBTC_USDT",
#   "price" : "59801.26",
#   "time" : 1711924245065,
#   "dailyChange" : "0.00",
#   "ts" : 1711924245075
# }, {
#   "symbol" : "FRONT_BTC",
#   "price" : "0.00001778",
#   "time" : 1711826453786,
#   "dailyChange" : "0.00",
#   "ts" : 1711826453805
# }, {
#   "symbol" : "FRONT_USDT",
#   "price" : "1.2722",
#   "time" : 1711915359313,
#   "dailyChange" : "0.0105",
#   "ts" : 1711915359319
# }, {
#   "symbol" : "API3_USDT",
#   "price" : "3.5432",
#   "time" : 1711896617170,
#   "dailyChange" : "-0.0495",
#   "ts" : 1711896617189
# }, {
#   "symbol" : "BADGER_USDT",
#   "price" : "6.945",
#   "time" : 1711885148875,
#   "dailyChange" : "0.1577",
#   "ts" : 1711885148890
# }, {
#   "symbol" : "FARM_BTC",
#   "price" : "0.000695",
#   "time" : 1711712161757,
#   "dailyChange" : "0.00",
#   "ts" : 1711712161769
# }, {
#   "symbol" : "FARM_USDT",
#   "price" : "50.29",
#   "time" : 1711914888952,
#   "dailyChange" : "0.2083",
#   "ts" : 1711914888960
# }, {
#   "symbol" : "DOT_BTC",
#   "price" : "0.0001346",
#   "time" : 1711921858286,
#   "dailyChange" : "-0.0044",
#   "ts" : 1711921858293
# }, {
#   "symbol" : "GRT_USDT",
#   "price" : "0.3877",
#   "time" : 1711924245104,
#   "dailyChange" : "-0.0018",
#   "ts" : 1711924245115
# }, {
#   "symbol" : "ESD_USDT",
#   "price" : "0.000702",
#   "time" : 1673213514627,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659474
# }, {
#   "symbol" : "ONEINCH_USDT",
#   "price" : "0.58",
#   "time" : 1711891622782,
#   "dailyChange" : "-0.0531",
#   "ts" : 1711891622792
# }, {
#   "symbol" : "REEF_USDT",
#   "price" : "0.00298",
#   "time" : 1711706573008,
#   "dailyChange" : "0.00",
#   "ts" : 1711706573015
# }, {
#   "symbol" : "LON_USDT",
#   "price" : "0.2001",
#   "time" : 1711308749881,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659489
# }, {
#   "symbol" : "ROOK_USDT",
#   "price" : "2.39",
#   "time" : 1711872657501,
#   "dailyChange" : "1.6264",
#   "ts" : 1711872657514
# }, {
#   "symbol" : "TRU_USDT",
#   "price" : "0.15422",
#   "time" : 1711924126535,
#   "dailyChange" : "0.0384",
#   "ts" : 1711924126550
# }, {
#   "symbol" : "CUDOS_USDT",
#   "price" : "0.019196",
#   "time" : 1711908494381,
#   "dailyChange" : "-0.0003",
#   "ts" : 1711908494389
# }, {
#   "symbol" : "BOND_USDT",
#   "price" : "5.12",
#   "time" : 1711656069435,
#   "dailyChange" : "0.00",
#   "ts" : 1711656069443
# }, {
#   "symbol" : "TUSD_USDT",
#   "price" : "1.00064",
#   "time" : 1711910382409,
#   "dailyChange" : "-0.0017",
#   "ts" : 1711910382420
# }, {
#   "symbol" : "TUSD_USDC",
#   "price" : "1.002",
#   "time" : 1711923283911,
#   "dailyChange" : "-0.0011",
#   "ts" : 1711923283917
# }, {
#   "symbol" : "WETH_USDT",
#   "price" : "1600",
#   "time" : 1711825521209,
#   "dailyChange" : "0.00",
#   "ts" : 1711825521224
# }, {
#   "symbol" : "TRU_BTC",
#   "price" : "0.000001652",
#   "time" : 1711347671749,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659545
# }, {
#   "symbol" : "FTT_USDT",
#   "price" : "1.921",
#   "time" : 1711887138833,
#   "dailyChange" : "-0.0332",
#   "ts" : 1711887138848
# }, {
#   "symbol" : "SRM_USDT",
#   "price" : "0.0703",
#   "time" : 1711912478748,
#   "dailyChange" : "0.2442",
#   "ts" : 1711912478757
# }, {
#   "symbol" : "LPT_USDT",
#   "price" : "19.06",
#   "time" : 1711911066414,
#   "dailyChange" : "0.0171",
#   "ts" : 1711911066429
# }, {
#   "symbol" : "BTC_TUSD",
#   "price" : "70007.32",
#   "time" : 1711694277310,
#   "dailyChange" : "0.00",
#   "ts" : 1711694277318
# }, {
#   "symbol" : "ETH_TUSD",
#   "price" : "3632.5",
#   "time" : 1711910382425,
#   "dailyChange" : "0.0408",
#   "ts" : 1711910382439
# }, {
#   "symbol" : "ALPHA_USDT",
#   "price" : "0.1446",
#   "time" : 1711778702240,
#   "dailyChange" : "0.00",
#   "ts" : 1711778702248
# }, {
#   "symbol" : "TORN_USDT",
#   "price" : "2.2",
#   "time" : 1711825521725,
#   "dailyChange" : "0.00",
#   "ts" : 1711825521731
# }, {
#   "symbol" : "ZKS_USDT",
#   "price" : "0.02505",
#   "time" : 1711825521261,
#   "dailyChange" : "0.00",
#   "ts" : 1711825521290
# }, {
#   "symbol" : "RNDR_USDT",
#   "price" : "10.1402",
#   "time" : 1711914149503,
#   "dailyChange" : "-0.0781",
#   "ts" : 1711914149510
# }, {
#   "symbol" : "KCS_USDT",
#   "price" : "10.85",
#   "time" : 1711888749533,
#   "dailyChange" : "0.1654",
#   "ts" : 1711888749541
# }, {
#   "symbol" : "FIL_BTC",
#   "price" : "0.0001408",
#   "time" : 1711921094482,
#   "dailyChange" : "0.0262",
#   "ts" : 1711921094509
# }, {
#   "symbol" : "FIL_USDT",
#   "price" : "9.839",
#   "time" : 1711924245957,
#   "dailyChange" : "0.0407",
#   "ts" : 1711924245967
# }, {
#   "symbol" : "XYM_BTC",
#   "price" : "0.00000028",
#   "time" : 1711826421525,
#   "dailyChange" : "0.00",
#   "ts" : 1711826421537
# }, {
#   "symbol" : "XYM_USDT",
#   "price" : "0.0262",
#   "time" : 1711920846808,
#   "dailyChange" : "0.0023",
#   "ts" : 1711920846820
# }, {
#   "symbol" : "LIVE_USDT",
#   "price" : "0.01281",
#   "time" : 1668079415742,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659105
# }, {
#   "symbol" : "SHIB_USDT",
#   "price" : "0.00003056",
#   "time" : 1711924241452,
#   "dailyChange" : "0.0273",
#   "ts" : 1711924241457
# }, {
#   "symbol" : "AKITA_USDT",
#   "price" : "0.0000001629",
#   "time" : 1711923803638,
#   "dailyChange" : "0.0062",
#   "ts" : 1711923803645
# }, {
#   "symbol" : "KLV_USDT",
#   "price" : "0.00526",
#   "time" : 1711669051150,
#   "dailyChange" : "0.00",
#   "ts" : 1711669051160
# }, {
#   "symbol" : "KLV_BTC",
#   "price" : "0.0000000989",
#   "time" : 1711784547274,
#   "dailyChange" : "0.00",
#   "ts" : 1711784547289
# }, {
#   "symbol" : "KLV_TRX",
#   "price" : "0.0497",
#   "time" : 1711648995356,
#   "dailyChange" : "0.00",
#   "ts" : 1711648995371
# }, {
#   "symbol" : "LQTY_USDT",
#   "price" : "1.55",
#   "time" : 1711888430857,
#   "dailyChange" : "0.0403",
#   "ts" : 1711888430864
# }, {
#   "symbol" : "DEGO_USDT",
#   "price" : "2.431",
#   "time" : 1710495838787,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659149
# }, {
#   "symbol" : "ELON_USDT",
#   "price" : "0.0000002063",
#   "time" : 1711924245611,
#   "dailyChange" : "0.0979",
#   "ts" : 1711924245631
# }, {
#   "symbol" : "QUICK_USDT",
#   "price" : "0.08452",
#   "time" : 1711889627871,
#   "dailyChange" : "-0.0336",
#   "ts" : 1711889627883
# }, {
#   "symbol" : "MVL_USDT",
#   "price" : "0.003224",
#   "time" : 1711855509198,
#   "dailyChange" : "-0.1034",
#   "ts" : 1711855509208
# }, {
#   "symbol" : "NFT_USDT",
#   "price" : "0.00000057308",
#   "time" : 1711924244702,
#   "dailyChange" : "-0.0189",
#   "ts" : 1711924244711
# }, {
#   "symbol" : "NFT_TRX",
#   "price" : "0.000004668",
#   "time" : 1711923502844,
#   "dailyChange" : "-0.0011",
#   "ts" : 1711923502858
# }, {
#   "symbol" : "HT_USDT",
#   "price" : "0.823",
#   "time" : 1711924241990,
#   "dailyChange" : "0.0135",
#   "ts" : 1711924242000
# }, {
#   "symbol" : "CTSI_USDT",
#   "price" : "0.3199",
#   "time" : 1711794772873,
#   "dailyChange" : "0.00",
#   "ts" : 1711794772886
# }, {
#   "symbol" : "RLC_USDT",
#   "price" : "3.7004",
#   "time" : 1711922780877,
#   "dailyChange" : "0.1529",
#   "ts" : 1711922780890
# }, {
#   "symbol" : "ERSDL_USDT",
#   "price" : "0.009895",
#   "time" : 1711894393996,
#   "dailyChange" : "1.8223",
#   "ts" : 1711894394006
# }, {
#   "symbol" : "RUNE_USDT",
#   "price" : "8.2838",
#   "time" : 1711875882305,
#   "dailyChange" : "-0.1156",
#   "ts" : 1711875882319
# }, {
#   "symbol" : "KISHU_TRX",
#   "price" : "0.000000001822",
#   "time" : 1711916883983,
#   "dailyChange" : "0.0094",
#   "ts" : 1711916883993
# }, {
#   "symbol" : "GTC_USDT",
#   "price" : "2.118",
#   "time" : 1711634105354,
#   "dailyChange" : "0.00",
#   "ts" : 1711634105362
# }, {
#   "symbol" : "OKB_USDT",
#   "price" : "39",
#   "time" : 1711609809504,
#   "dailyChange" : "0.00",
#   "ts" : 1711609809516
# }, {
#   "symbol" : "SUN_USDT",
#   "price" : "0.0158696",
#   "time" : 1711924244394,
#   "dailyChange" : "-0.0034",
#   "ts" : 1711924244401
# }, {
#   "symbol" : "SUN_TRX",
#   "price" : "0.07501",
#   "time" : 1711462049775,
#   "dailyChange" : "0.00",
#   "ts" : 1711462049788
# }, {
#   "symbol" : "XEC_USDT",
#   "price" : "0.00006642",
#   "time" : 1711923366402,
#   "dailyChange" : "0.0378",
#   "ts" : 1711923366409
# }, {
#   "symbol" : "CAKE_USDT",
#   "price" : "4.706",
#   "time" : 1711922277288,
#   "dailyChange" : "0.0313",
#   "ts" : 1711922277296
# }, {
#   "symbol" : "XVS_USDT",
#   "price" : "14.89",
#   "time" : 1711845457725,
#   "dailyChange" : "-0.0062",
#   "ts" : 1711845457739
# }, {
#   "symbol" : "BURGER_USDT",
#   "price" : "0.8998",
#   "time" : 1711820663433,
#   "dailyChange" : "0.00",
#   "ts" : 1711820663448
# }, {
#   "symbol" : "AXS_USDT",
#   "price" : "10.27",
#   "time" : 1711851517854,
#   "dailyChange" : "-0.1062",
#   "ts" : 1711851517861
# }, {
#   "symbol" : "ALPACA_USDT",
#   "price" : "0.2538",
#   "time" : 1711793489304,
#   "dailyChange" : "0.00",
#   "ts" : 1711793489319
# }, {
#   "symbol" : "C98_USDT",
#   "price" : "0.4155",
#   "time" : 1711891807284,
#   "dailyChange" : "-0.0375",
#   "ts" : 1711891807295
# }, {
#   "symbol" : "PERP_USDT",
#   "price" : "2.1943",
#   "time" : 1711713487192,
#   "dailyChange" : "0.00",
#   "ts" : 1711713487202
# }, {
#   "symbol" : "TRU_TUSD",
#   "price" : "0.08021",
#   "time" : 1710257681051,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659287
# }, {
#   "symbol" : "ACH1_USDT",
#   "price" : "0.02602",
#   "time" : 1711872836834,
#   "dailyChange" : "-0.2559",
#   "ts" : 1711872836841
# }, {
#   "symbol" : "CLV_USDT",
#   "price" : "0.1186",
#   "time" : 1711860498033,
#   "dailyChange" : "0.0331",
#   "ts" : 1711860498047
# }, {
#   "symbol" : "YGG_USDT",
#   "price" : "1.6692",
#   "time" : 1711922414709,
#   "dailyChange" : "0.1681",
#   "ts" : 1711922414718
# }, {
#   "symbol" : "ALICE_USDT",
#   "price" : "1.915",
#   "time" : 1711759632340,
#   "dailyChange" : "0.00",
#   "ts" : 1711759632347
# }, {
#   "symbol" : "AUDIO_USDT",
#   "price" : "0.2954",
#   "time" : 1711862769122,
#   "dailyChange" : "0.1816",
#   "ts" : 1711862769130
# }, {
#   "symbol" : "BIT_USDT",
#   "price" : "0.5961",
#   "time" : 1690216388216,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659314
# }, {
#   "symbol" : "BNB_USDC",
#   "price" : "585.68",
#   "time" : 1711752674587,
#   "dailyChange" : "0.00",
#   "ts" : 1711752674597
# }, {
#   "symbol" : "LINK_USDC",
#   "price" : "20",
#   "time" : 1711438106805,
#   "dailyChange" : "0.00",
#   "ts" : 1711438106822
# }, {
#   "symbol" : "MBOX_USDT",
#   "price" : "0.4865",
#   "time" : 1711875278552,
#   "dailyChange" : "0.0811",
#   "ts" : 1711875278559
# }, {
#   "symbol" : "MATTER_USDT",
#   "price" : "0.0499",
#   "time" : 1711894930654,
#   "dailyChange" : "0.1769",
#   "ts" : 1711894930667
# }, {
#   "symbol" : "MATTER_TRX",
#   "price" : "0.866",
#   "time" : 1710886598438,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659379
# }, {
#   "symbol" : "AGLD_USDT",
#   "price" : "1.0008",
#   "time" : 1711913064447,
#   "dailyChange" : "-0.3743",
#   "ts" : 1711913064452
# }, {
#   "symbol" : "MATIC_USDC",
#   "price" : "1.1999",
#   "time" : 1711664565237,
#   "dailyChange" : "0.00",
#   "ts" : 1711664565247
# }, {
#   "symbol" : "MANA_USDC",
#   "price" : "0.6817",
#   "time" : 1711592974739,
#   "dailyChange" : "0.00",
#   "ts" : 1711592974746
# }, {
#   "symbol" : "XEM_USDC",
#   "price" : "0.0474",
#   "time" : 1710979695213,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659395
# }, {
#   "symbol" : "BTT_USDC",
#   "price" : "0.0000013173",
#   "time" : 1711775302583,
#   "dailyChange" : "0.00",
#   "ts" : 1711775302592
# }, {
#   "symbol" : "SRM_USDC",
#   "price" : "0.2999",
#   "time" : 1710715638554,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659399
# }, {
#   "symbol" : "XEM_USDT",
#   "price" : "0.05134",
#   "time" : 1711923596873,
#   "dailyChange" : "0.0128",
#   "ts" : 1711923596880
# }, {
#   "symbol" : "SRM_BTC",
#   "price" : "0.0000009",
#   "time" : 1710352739158,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659404
# }, {
#   "symbol" : "DYDX_USDT",
#   "price" : "3.346",
#   "time" : 1711913788778,
#   "dailyChange" : "-0.0757",
#   "ts" : 1711913788789
# }, {
#   "symbol" : "XCAD_USDT",
#   "price" : "1.11",
#   "time" : 1711825521471,
#   "dailyChange" : "0.00",
#   "ts" : 1711825521486
# }, {
#   "symbol" : "GALA_USDT",
#   "price" : "0.06962",
#   "time" : 1711922445860,
#   "dailyChange" : "-0.0063",
#   "ts" : 1711922445874
# }, {
#   "symbol" : "LDO_USDT",
#   "price" : "2.941",
#   "time" : 1711924244458,
#   "dailyChange" : "0.0511",
#   "ts" : 1711924244467
# }, {
#   "symbol" : "BTRST_USDT",
#   "price" : "1.499",
#   "time" : 1711898588745,
#   "dailyChange" : "0.3816",
#   "ts" : 1711898588753
# }, {
#   "symbol" : "FLOKI_USDT",
#   "price" : "0.00025022",
#   "time" : 1711923714212,
#   "dailyChange" : "0.041",
#   "ts" : 1711923714220
# }, {
#   "symbol" : "TOKE_USDT",
#   "price" : "0.742",
#   "time" : 1711917925093,
#   "dailyChange" : "0.0192",
#   "ts" : 1711917925101
# }, {
#   "symbol" : "WNCG_USDT",
#   "price" : "0.0376",
#   "time" : 1711844794360,
#   "dailyChange" : "0.498",
#   "ts" : 1711844794368
# }, {
#   "symbol" : "MLN_USDT",
#   "price" : "27.23",
#   "time" : 1711554846463,
#   "dailyChange" : "0.00",
#   "ts" : 1711554846480
# }, {
#   "symbol" : "WOO_USDT",
#   "price" : "0.4227",
#   "time" : 1711909100007,
#   "dailyChange" : "-0.074",
#   "ts" : 1711909100017
# }, {
#   "symbol" : "ENJ_USDT",
#   "price" : "0.4998",
#   "time" : 1711800585661,
#   "dailyChange" : "0.00",
#   "ts" : 1711800585677
# }, {
#   "symbol" : "CHZ_USDT",
#   "price" : "0.13159",
#   "time" : 1711899924626,
#   "dailyChange" : "-0.1227",
#   "ts" : 1711899924633
# }, {
#   "symbol" : "SLP_USDT",
#   "price" : "0.005529",
#   "time" : 1711882821078,
#   "dailyChange" : "0.0578",
#   "ts" : 1711882821088
# }, {
#   "symbol" : "OGN_USDT",
#   "price" : "0.215",
#   "time" : 1711836074085,
#   "dailyChange" : "0.00",
#   "ts" : 1711836074095
# }, {
#   "symbol" : "PLA_USDT",
#   "price" : "0.15",
#   "time" : 1710868664072,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659477
# }, {
#   "symbol" : "TLM_USDT",
#   "price" : "0.02319",
#   "time" : 1711883391675,
#   "dailyChange" : "0.0004",
#   "ts" : 1711883391690
# }, {
#   "symbol" : "SUPER_USDT",
#   "price" : "1.317",
#   "time" : 1711850520988,
#   "dailyChange" : "0.0209",
#   "ts" : 1711850520997
# }, {
#   "symbol" : "ILV_USDT",
#   "price" : "172.17",
#   "time" : 1711689734360,
#   "dailyChange" : "0.00",
#   "ts" : 1711689734375
# }, {
#   "symbol" : "ERN_USDT",
#   "price" : "7.2829",
#   "time" : 1711456716154,
#   "dailyChange" : "0.00",
#   "ts" : 1711456716171
# }, {
#   "symbol" : "SPELL_USDT",
#   "price" : "0.001247",
#   "time" : 1711879775269,
#   "dailyChange" : "0.3856",
#   "ts" : 1711879775277
# }, {
#   "symbol" : "EFI_USDT",
#   "price" : "0.0467",
#   "time" : 1698133997452,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659512
# }, {
#   "symbol" : "RACA_USDT",
#   "price" : "0.0003416",
#   "time" : 1711921821776,
#   "dailyChange" : "-0.0519",
#   "ts" : 1711921821790
# }, {
#   "symbol" : "AVAX_USDT",
#   "price" : "53.837",
#   "time" : 1711924243380,
#   "dailyChange" : "0.0132",
#   "ts" : 1711924243388
# }, {
#   "symbol" : "GMEE_USDT",
#   "price" : "0.02222",
#   "time" : 1711812695868,
#   "dailyChange" : "0.00",
#   "ts" : 1711812695875
# }, {
#   "symbol" : "CVX_USDT",
#   "price" : "3.3",
#   "time" : 1711923611531,
#   "dailyChange" : "-0.3978",
#   "ts" : 1711923611539
# }, {
#   "symbol" : "SHIB_USDC",
#   "price" : "0.00003225",
#   "time" : 1711920506715,
#   "dailyChange" : "0.0258",
#   "ts" : 1711920506726
# }, {
#   "symbol" : "AVAX_USDC",
#   "price" : "47",
#   "time" : 1711384268089,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659543
# }, {
#   "symbol" : "AVAX_BTC",
#   "price" : "0.000756",
#   "time" : 1711897035561,
#   "dailyChange" : "-0.0013",
#   "ts" : 1711897035577
# }, {
#   "symbol" : "ENS_USDT",
#   "price" : "20.01",
#   "time" : 1711829422440,
#   "dailyChange" : "0.00",
#   "ts" : 1711829422447
# }, {
#   "symbol" : "IMX_USDT",
#   "price" : "3.0008",
#   "time" : 1711924245136,
#   "dailyChange" : "-0.0293",
#   "ts" : 1711924245147
# }, {
#   "symbol" : "KDOE_USDT",
#   "price" : "0.003389",
#   "time" : 1711924068415,
#   "dailyChange" : "0.3427",
#   "ts" : 1711924068425
# }, {
#   "symbol" : "GN_USDT",
#   "price" : "0.00000044",
#   "time" : 1653071099000,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659044
# }, {
#   "symbol" : "SAITAMA_USDT",
#   "price" : "0.0008185",
#   "time" : 1711924216668,
#   "dailyChange" : "0.0593",
#   "ts" : 1711924216686
# }, {
#   "symbol" : "BOBA_USDT",
#   "price" : "0.4692",
#   "time" : 1711822571934,
#   "dailyChange" : "0.00",
#   "ts" : 1711822571949
# }, {
#   "symbol" : "POLYDOGE_USDT",
#   "price" : "0.000000011612",
#   "time" : 1711922321913,
#   "dailyChange" : "-0.0171",
#   "ts" : 1711922321928
# }, {
#   "symbol" : "HEX_USDT",
#   "price" : "0.0031",
#   "time" : 1711824920312,
#   "dailyChange" : "0.00",
#   "ts" : 1711824920325
# }, {
#   "symbol" : "FXS_USDT",
#   "price" : "8.159",
#   "time" : 1711734231892,
#   "dailyChange" : "0.00",
#   "ts" : 1711734231904
# }, {
#   "symbol" : "DYP_USDT",
#   "price" : "0.4899",
#   "time" : 1711859623679,
#   "dailyChange" : "5.9986",
#   "ts" : 1711859623686
# }, {
#   "symbol" : "TRIBE_USDT",
#   "price" : "0.1616",
#   "time" : 1711825521586,
#   "dailyChange" : "0.00",
#   "ts" : 1711825521602
# }, {
#   "symbol" : "SOL_USDT",
#   "price" : "200.675",
#   "time" : 1711924246091,
#   "dailyChange" : "0.023",
#   "ts" : 1711924246099
# }, {
#   "symbol" : "SOL_BTC",
#   "price" : "0.002824",
#   "time" : 1711913269818,
#   "dailyChange" : "0.0075",
#   "ts" : 1711913269832
# }, {
#   "symbol" : "SOL_USDC",
#   "price" : "204.98",
#   "time" : 1711916087957,
#   "dailyChange" : "0.0458",
#   "ts" : 1711916087971
# }, {
#   "symbol" : "DORA_USDT",
#   "price" : "0.72",
#   "time" : 1710862713343,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659100
# }, {
#   "symbol" : "ORCA_USDT",
#   "price" : "4.117",
#   "time" : 1711893382820,
#   "dailyChange" : "0.0383",
#   "ts" : 1711893382835
# }, {
#   "symbol" : "PEOPLE_USDT",
#   "price" : "0.03955",
#   "time" : 1711872397529,
#   "dailyChange" : "0.0172",
#   "ts" : 1711872397543
# }, {
#   "symbol" : "PSP_USDT",
#   "price" : "0.03301",
#   "time" : 1711825521550,
#   "dailyChange" : "0.00",
#   "ts" : 1711825521556
# }, {
#   "symbol" : "NEXO_USDT",
#   "price" : "1.3742",
#   "time" : 1710625172310,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659138
# }, {
#   "symbol" : "FTM_USDT",
#   "price" : "0.9992",
#   "time" : 1711916096412,
#   "dailyChange" : "0.0402",
#   "ts" : 1711916096427
# }, {
#   "symbol" : "BNX_USDT",
#   "price" : "0.5264",
#   "time" : 1711915397815,
#   "dailyChange" : "-0.1445",
#   "ts" : 1711915397832
# }, {
#   "symbol" : "QI_USDT",
#   "price" : "0.02699",
#   "time" : 1711845133794,
#   "dailyChange" : "0.0762",
#   "ts" : 1711845133809
# }, {
#   "symbol" : "ADA_USDT",
#   "price" : "0.64764",
#   "time" : 1711924244294,
#   "dailyChange" : "0.0053",
#   "ts" : 1711924244318
# }, {
#   "symbol" : "REQ_USDT",
#   "price" : "0.09",
#   "time" : 1711825521597,
#   "dailyChange" : "0.00",
#   "ts" : 1711825521610
# }, {
#   "symbol" : "SAMO_USDT",
#   "price" : "0.01553",
#   "time" : 1711908642781,
#   "dailyChange" : "0.19",
#   "ts" : 1711908642794
# }, {
#   "symbol" : "ATLAS_USDT",
#   "price" : "0.008177",
#   "time" : 1711923917959,
#   "dailyChange" : "0.0221",
#   "ts" : 1711923917969
# }, {
#   "symbol" : "POLIS_USDT",
#   "price" : "0.4491",
#   "time" : 1711643532960,
#   "dailyChange" : "0.00",
#   "ts" : 1711643532966
# }, {
#   "symbol" : "FIDA_USDT",
#   "price" : "0.4314",
#   "time" : 1711912063956,
#   "dailyChange" : "-0.0332",
#   "ts" : 1711912063966
# }, {
#   "symbol" : "BICO_USDT",
#   "price" : "0.5051",
#   "time" : 1711705289514,
#   "dailyChange" : "0.00",
#   "ts" : 1711705289521
# }, {
#   "symbol" : "GODS_USDT",
#   "price" : "0.1",
#   "time" : 1711610329516,
#   "dailyChange" : "0.00",
#   "ts" : 1711610329526
# }, {
#   "symbol" : "RBN_USDT",
#   "price" : "1.6",
#   "time" : 1711896913346,
#   "dailyChange" : "1.6016",
#   "ts" : 1711896913351
# }, {
#   "symbol" : "PYR_USDT",
#   "price" : "5.103",
#   "time" : 1711867450112,
#   "dailyChange" : "-0.3076",
#   "ts" : 1711867450122
# }, {
#   "symbol" : "SOS_USDT",
#   "price" : "0.0000000324",
#   "time" : 1711863065841,
#   "dailyChange" : "0.0946",
#   "ts" : 1711863065856
# }, {
#   "symbol" : "HIGH_USDT",
#   "price" : "2.052",
#   "time" : 1711784008345,
#   "dailyChange" : "0.00",
#   "ts" : 1711784008360
# }, {
#   "symbol" : "VOXEL_USDT",
#   "price" : "0.4",
#   "time" : 1711812285184,
#   "dailyChange" : "0.00",
#   "ts" : 1711812285193
# }, {
#   "symbol" : "ADA_BTC",
#   "price" : "0.00000913",
#   "time" : 1711922027267,
#   "dailyChange" : "-0.0193",
#   "ts" : 1711922027279
# }, {
#   "symbol" : "ADA_USDC",
#   "price" : "0.818",
#   "time" : 1711787638094,
#   "dailyChange" : "0.00",
#   "ts" : 1711787638100
# }, {
#   "symbol" : "CTC_USDT",
#   "price" : "0.63",
#   "time" : 1711833492925,
#   "dailyChange" : "0.00",
#   "ts" : 1711833492934
# }, {
#   "symbol" : "METIS_USDT",
#   "price" : "100.83",
#   "time" : 1710698931776,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659257
# }, {
#   "symbol" : "OOKI_USDT",
#   "price" : "0.002802",
#   "time" : 1711918258466,
#   "dailyChange" : "-0.2791",
#   "ts" : 1711918258480
# }, {
#   "symbol" : "LOOKS_USDT",
#   "price" : "0.0401",
#   "time" : 1711825612418,
#   "dailyChange" : "0.00",
#   "ts" : 1711825612429
# }, {
#   "symbol" : "FTM_USDC",
#   "price" : "0.7001",
#   "time" : 1711507175458,
#   "dailyChange" : "0.00",
#   "ts" : 1711507175473
# }, {
#   "symbol" : "FTM_BTC",
#   "price" : "0.00001394",
#   "time" : 1711923692494,
#   "dailyChange" : "0.0288",
#   "ts" : 1711923692501
# }, {
#   "symbol" : "SHPING_USDT",
#   "price" : "0.00628",
#   "time" : 1711848696707,
#   "dailyChange" : "0.00",
#   "ts" : 1711848696716
# }, {
#   "symbol" : "LOKA_USDT",
#   "price" : "0.4772",
#   "time" : 1711832342669,
#   "dailyChange" : "0.00",
#   "ts" : 1711832342684
# }, {
#   "symbol" : "VRA_USDT",
#   "price" : "0.008",
#   "time" : 1711867338485,
#   "dailyChange" : "-0.0005",
#   "ts" : 1711867338494
# }, {
#   "symbol" : "SUKU_USDT",
#   "price" : "0.06635",
#   "time" : 1711923695909,
#   "dailyChange" : "2.9075",
#   "ts" : 1711923695917
# }, {
#   "symbol" : "NCT_USDT",
#   "price" : "0.01001",
#   "time" : 1711295502118,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659292
# }, {
#   "symbol" : "HUNT_USDT",
#   "price" : "0.52",
#   "time" : 1711800001015,
#   "dailyChange" : "0.00",
#   "ts" : 1711800001019
# }, {
#   "symbol" : "TITAN_USDT",
#   "price" : "0.0027",
#   "time" : 1711892360646,
#   "dailyChange" : "-0.2895",
#   "ts" : 1711892360660
# }, {
#   "symbol" : "UMEE_USDT",
#   "price" : "0.00443",
#   "time" : 1711446132245,
#   "dailyChange" : "0.00",
#   "ts" : 1711446132258
# }, {
#   "symbol" : "ALPINE_USDT",
#   "price" : "2.001",
#   "time" : 1711644640783,
#   "dailyChange" : "0.00",
#   "ts" : 1711644640789
# }, {
#   "symbol" : "GMT_USDT",
#   "price" : "0.365",
#   "time" : 1711841291109,
#   "dailyChange" : "-0.0595",
#   "ts" : 1711841291120
# }, {
#   "symbol" : "AERGO_USDT",
#   "price" : "0.0954",
#   "time" : 1673433959405,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659362
# }, {
#   "symbol" : "APE_USDT",
#   "price" : "1.945",
#   "time" : 1711911985429,
#   "dailyChange" : "0.0183",
#   "ts" : 1711911985435
# }, {
#   "symbol" : "NVIR_USDT",
#   "price" : "0.021",
#   "time" : 1711915936283,
#   "dailyChange" : "-0.4749",
#   "ts" : 1711915936293
# }, {
#   "symbol" : "STG_USDT",
#   "price" : "0.7655",
#   "time" : 1711694423865,
#   "dailyChange" : "0.00",
#   "ts" : 1711694423879
# }, {
#   "symbol" : "CULT_USDT",
#   "price" : "0.000002007",
#   "time" : 1711821447605,
#   "dailyChange" : "0.00",
#   "ts" : 1711821447615
# }, {
#   "symbol" : "KSM_USDT",
#   "price" : "48.73",
#   "time" : 1711835570776,
#   "dailyChange" : "0.00",
#   "ts" : 1711835570789
# }, {
#   "symbol" : "ZELIX_USDT",
#   "price" : "0.0006939",
#   "time" : 1711924229919,
#   "dailyChange" : "0.2365",
#   "ts" : 1711924229933
# }, {
#   "symbol" : "CEEK_USDT",
#   "price" : "0.0551",
#   "time" : 1711129646242,
#   "dailyChange" : "0.00",
#   "ts" : 1711423659388
# }, {
#   "symbol" : "NYM_USDT",
#   "price" : "0.2654",
#   "time" : 1711876210778,
#   "dailyChange" : "0.0004",
#   "ts" : 1711876210790
# }, {
#   "symbol" : "CAW_USDT",
#   "price" : "0.00000006009",
#   "time" : 1711874427124,
#   "dailyChange" : "0.00",
#   "ts" : 1711874427133
# }, {
# ...
#   "ts" : 1711919019172
# }, {
#   "symbol" : "PIXEL_USDT",
#   "price" : "0.59",
#   "time" : 1711890762181,
#   "dailyChange" : "-0.227",
#   "ts" : 1711890762197
# }, {
#   "symbol" : "STRK_USDT",
#   "price" : "2.336",
#   "time" : 1711852196060,
#   "dailyChange" : "0.057",
#   "ts" : 1711852196074
# }, {
#   "symbol" : "JIVA_USDT",
#   "price" : "0.00035",
#   "time" : 1711841761462,
#   "dailyChange" : "-0.527",
#   "ts" : 1711841761468
# }, {
#   "symbol" : "SORA_USDT",
#   "price" : "0.00662",
#   "time" : 1711889708713,
#   "dailyChange" : "-0.0543",
#   "ts" : 1711889708727
# }, {
#   "symbol" : "MAVIA_USDT",
#   "price" : "6.11",
#   "time" : 1711907605045,
#   "dailyChange" : "0.0235",
#   "ts" : 1711907605056
# }, {
#   "symbol" : "SPYRO_USDT",
#   "price" : "0.000000214",
#   "time" : 1711825523720,
#   "dailyChange" : "0.00",
#   "ts" : 1711825523731
# }, {
#   "symbol" : "NAVX_USDT",
#   "price" : "0.2999",
#   "time" : 1711676161459,
#   "dailyChange" : "0.00",
#   "ts" : 1711676161472
# }, {
#   "symbol" : "WHALES_USDT",
#   "price" : "1.2",
#   "time" : 1711825523767,
#   "dailyChange" : "0.00",
#   "ts" : 1711825523791
# }, {
#   "symbol" : "LMWR_USDT",
#   "price" : "1.076",
#   "time" : 1711876634925,
#   "dailyChange" : "-0.0793",
#   "ts" : 1711876634939
# }, {
#   "symbol" : "BFICGOLD_BFIC",
#   "price" : "0.2581",
#   "time" : 1710242522270,
#   "dailyChange" : "0.00",
#   "ts" : 1711423710177
# }, {
#   "symbol" : "YES_USDT",
#   "price" : "7.62",
#   "time" : 1711892735350,
#   "dailyChange" : "-0.0463",
#   "ts" : 1711892735359
# }, {
#   "symbol" : "GMEONETH_USDT",
#   "price" : "0.00002",
#   "time" : 1711892621731,
#   "dailyChange" : "-0.5556",
#   "ts" : 1711892621745
# }, {
#   "symbol" : "SQUIDSOL_USDT",
#   "price" : "0.0002196",
#   "time" : 1707404533992,
#   "dailyChange" : "0.00",
#   "ts" : 1711423710161
# }, {
#   "symbol" : "FART_USDT",
#   "price" : "0.00000021",
#   "time" : 1711757551362,
#   "dailyChange" : "0.00",
#   "ts" : 1711757551377
# }, {
#   "symbol" : "ZETA_USDT",
#   "price" : "1.6033",
#   "time" : 1711825523716,
#   "dailyChange" : "0.00",
#   "ts" : 1711825523731
# }, {
#   "symbol" : "PEBO_USDT",
#   "price" : "0.000289",
#   "time" : 1711730221454,
#   "dailyChange" : "0.00",
#   "ts" : 1711730221467
# }, {
#   "symbol" : "AC_USDT",
#   "price" : "0.1801",
#   "time" : 1711914364718,
#   "dailyChange" : "-0.2034",
#   "ts" : 1711914364731
# }, {
#   "symbol" : "DZHV_USDT",
#   "price" : "0.01357",
#   "time" : 1711918090239,
#   "dailyChange" : "-0.3201",
#   "ts" : 1711918090250
# }, {
#   "symbol" : "TREMP_USDT",
#   "price" : "0.68501",
#   "time" : 1711879974265,
#   "dailyChange" : "0.0015",
#   "ts" : 1711879974274
# }, {
#   "symbol" : "BIF_USDT",
#   "price" : "0.000824",
#   "time" : 1711919952719,
#   "dailyChange" : "-0.3017",
#   "ts" : 1711919952733
# }, {
#   "symbol" : "SHU_USDT",
#   "price" : "0.1068",
#   "time" : 1711904901504,
#   "dailyChange" : "-0.0291",
#   "ts" : 1711904901512
# }, {
#   "symbol" : "TBANK_USDT",
#   "price" : "0.8233",
#   "time" : 1711914518644,
#   "dailyChange" : "-0.1691",
#   "ts" : 1711914518654
# }, {
#   "symbol" : "ICENETWORK_USDT",
#   "price" : "0.00442",
#   "time" : 1711919867936,
#   "dailyChange" : "0.0029",
#   "ts" : 1711919867947
# }, {
#   "symbol" : "MOBY_USDT",
#   "price" : "1.069",
#   "time" : 1711884479793,
#   "dailyChange" : "0.0009",
#   "ts" : 1711884479802
# }, {
#   "symbol" : "CHAT_USDT",
#   "price" : "1.801",
#   "time" : 1711777135146,
#   "dailyChange" : "0.00",
#   "ts" : 1711777135163
# }, {
#   "symbol" : "ML_USDT",
#   "price" : "0.44896",
#   "time" : 1711924237713,
#   "dailyChange" : "0.0485",
#   "ts" : 1711924237725
# }, {
#   "symbol" : "BENDOG_USDT",
#   "price" : "0.011164",
#   "time" : 1711917602852,
#   "dailyChange" : "-0.0705",
#   "ts" : 1711917602867
# }, {
#   "symbol" : "BEOBLE_USDT",
#   "price" : "0.15051",
#   "time" : 1711774269435,
#   "dailyChange" : "0.00",
#   "ts" : 1711774269445
# }, {
#   "symbol" : "PORK_USDT",
#   "price" : "0.00000026",
#   "time" : 1711922550948,
#   "dailyChange" : "0.04",
#   "ts" : 1711922550963
# }, {
#   "symbol" : "NADA_USDT",
#   "price" : "0.00993",
#   "time" : 1711923323562,
#   "dailyChange" : "-0.2362",
#   "ts" : 1711923323571
# }, {
#   "symbol" : "XPET_USDT",
#   "price" : "0.488",
#   "time" : 1711901070336,
#   "dailyChange" : "0.1188",
#   "ts" : 1711901070345
# }, {
#   "symbol" : "KLIMA_USDT",
#   "price" : "2.9045",
#   "time" : 1711924200824,
#   "dailyChange" : "-0.1685",
#   "ts" : 1711924200831
# }, {
#   "symbol" : "CLOSEDAI_USDT",
#   "price" : "0.0001401",
#   "time" : 1711923602530,
#   "dailyChange" : "0.00",
#   "ts" : 1711923602540
# }, {
#   "symbol" : "BRETT_USDT",
#   "price" : "0.07599",
#   "time" : 1711924181418,
#   "dailyChange" : "-0.0845",
#   "ts" : 1711924181426
# }, {
#   "symbol" : "PENG_USDT",
#   "price" : "0.36",
#   "time" : 1711922962561,
#   "dailyChange" : "0.1502",
#   "ts" : 1711922962570
# }, {
#   "symbol" : "OPSEC_USDT",
#   "price" : "3.0799",
#   "time" : 1711924091972,
#   "dailyChange" : "0.0744",
#   "ts" : 1711924091990
# }, {
#   "symbol" : "UPDOG_USDT",
#   "price" : "0.001409",
#   "time" : 1711915609027,
#   "dailyChange" : "0.3909",
#   "ts" : 1711915609044
# }, {
#   "symbol" : "PORTAL_USDT",
#   "price" : "1.974",
#   "time" : 1711913858740,
#   "dailyChange" : "-0.0145",
#   "ts" : 1711913858750
# }, {
#   "symbol" : "ALVA_USDT",
#   "price" : "1.3123",
#   "time" : 1711924234089,
#   "dailyChange" : "0.2476",
#   "ts" : 1711924234101
# }, {
#   "symbol" : "HEMULE_USDT",
#   "price" : "0.024",
#   "time" : 1711924070368,
#   "dailyChange" : "-0.073",
#   "ts" : 1711924070380
# }, {
#   "symbol" : "CAF_USDT",
#   "price" : "0.4397",
#   "time" : 1711920494625,
#   "dailyChange" : "0.3236",
#   "ts" : 1711920494639
# }, {
#   "symbol" : "FORK_USDT",
#   "price" : "0.000001531",
#   "time" : 1711918718360,
#   "dailyChange" : "-0.0431",
#   "ts" : 1711918718377
# }, {
#   "symbol" : "SOLCHAT_USDT",
#   "price" : "5.619",
#   "time" : 1711919744319,
#   "dailyChange" : "-0.2629",
#   "ts" : 1711919744333
# }, {
#   "symbol" : "POPCAT_USDT",
#   "price" : "0.24995",
#   "time" : 1711911930213,
#   "dailyChange" : "0.0866",
#   "ts" : 1711911930231
# }, {
#   "symbol" : "RFKJ_USDT",
#   "price" : "0.0004214",
#   "time" : 1709578685696,
#   "dailyChange" : "0.00",
#   "ts" : 1711423710272
# }, {
#   "symbol" : "TYT_USDT",
#   "price" : "0.843",
#   "time" : 1711924237138,
#   "dailyChange" : "-0.0539",
#   "ts" : 1711924237148
# }, {
#   "symbol" : "NEVER_USDT",
#   "price" : "0.0002212",
#   "time" : 1711924212874,
#   "dailyChange" : "0.0346",
#   "ts" : 1711924212887
# }, {
#   "symbol" : "BOME_USDT",
#   "price" : "0.0144578",
#   "time" : 1711922373121,
#   "dailyChange" : "0.0263",
#   "ts" : 1711922373134
# }, {
#   "symbol" : "AEVO_USDT",
#   "price" : "2.96",
#   "time" : 1711846608707,
#   "dailyChange" : "0.0116",
#   "ts" : 1711846608717
# }, {
#   "symbol" : "MUMU_USDT",
#   "price" : "0.000011042",
#   "time" : 1711922692030,
#   "dailyChange" : "0.2485",
#   "ts" : 1711922692039
# }, {
#   "symbol" : "OETH_ETH",
#   "price" : "0.998203",
#   "time" : 1711924224239,
#   "dailyChange" : "0.00",
#   "ts" : 1711924224257
# }, {
#   "symbol" : "PRISMA_USDT",
#   "price" : "0.1474",
#   "time" : 1711899349985,
#   "dailyChange" : "0.0476",
#   "ts" : 1711899349998
# }, {
#   "symbol" : "BFICGOLD_USDT",
#   "price" : "2.294",
#   "time" : 1711922561235,
#   "dailyChange" : "0.0013",
#   "ts" : 1711922561243
# }, {
#   "symbol" : "SYNC_USDT",
#   "price" : "0.02592",
#   "time" : 1711912303371,
#   "dailyChange" : "0.2056",
#   "ts" : 1711912303377
# }, {
#   "symbol" : "FAIR_USDT",
#   "price" : "0.000903",
#   "time" : 1711780555676,
#   "dailyChange" : "0.00",
#   "ts" : 1711780555690
# }, {
#   "symbol" : "WTAO_USDT",
#   "price" : "0.00524",
#   "time" : 1711923158979,
#   "dailyChange" : "0.00",
#   "ts" : 1711923158989
# }, {
#   "symbol" : "CLD_USDT",
#   "price" : "0.26",
#   "time" : 1711773455953,
#   "dailyChange" : "0.00",
#   "ts" : 1711773455968
# }, {
#   "symbol" : "GPU_USDT",
#   "price" : "2.4194",
#   "time" : 1711923524888,
#   "dailyChange" : "0.1047",
#   "ts" : 1711923524895
# }, {
#   "symbol" : "DEPD_USDT",
#   "price" : "0.00128",
#   "time" : 1711884471740,
#   "dailyChange" : "0.00",
#   "ts" : 1711884471758
# }, {
#   "symbol" : "MOZ_USDT",
#   "price" : "0.0472",
#   "time" : 1711916946818,
#   "dailyChange" : "0.00",
#   "ts" : 1711916946830
# }, {
#   "symbol" : "BVM_USDT",
#   "price" : "2.24",
#   "time" : 1711883825761,
#   "dailyChange" : "-0.1843",
#   "ts" : 1711883825775
# }, {
#   "symbol" : "SCA_USDT",
#   "price" : "0.9111",
#   "time" : 1711887963887,
#   "dailyChange" : "0.023",
#   "ts" : 1711887963895
# }, {
#   "symbol" : "NOCHILL_USDT",
#   "price" : "0.02154",
#   "time" : 1711924211901,
#   "dailyChange" : "-0.0896",
#   "ts" : 1711924211915
# }, {
#   "symbol" : "NAP_USDT",
#   "price" : "0.0000102",
#   "time" : 1711924245077,
#   "dailyChange" : "-0.0803",
#   "ts" : 1711924245089
# }, {
#   "symbol" : "DUPE_USDT",
#   "price" : "0.001613",
#   "time" : 1711924245427,
#   "dailyChange" : "0.1061",
#   "ts" : 1711924245441
# }, {
#   "symbol" : "WEETH_ETH",
#   "price" : "1.017773",
#   "time" : 1711924245841,
#   "dailyChange" : "-0.0034",
#   "ts" : 1711924245849
# }, {
#   "symbol" : "SAFEMOON_USDT",
#   "price" : "0.000416",
#   "time" : 1711924240780,
#   "dailyChange" : "0.1253",
#   "ts" : 1711924240794
# }, {
#   "symbol" : "IDK_USDT",
#   "price" : "0.00037",
#   "time" : 1711896625502,
#   "dailyChange" : "-0.0263",
#   "ts" : 1711896625517
# }, {
#   "symbol" : "SLERF_USDT",
#   "price" : "0.6346",
#   "time" : 1711924245568,
#   "dailyChange" : "0.0175",
#   "ts" : 1711924245580
# }, {
#   "symbol" : "GTOP_USDT",
#   "price" : "0.00043",
#   "time" : 1711924240077,
#   "dailyChange" : "-0.1443",
#   "ts" : 1711924240092
# }, {
#   "symbol" : "ETHFI_USDT",
#   "price" : "6.427",
#   "time" : 1711924240692,
#   "dailyChange" : "-0.0527",
#   "ts" : 1711924240700
# }, {
#   "symbol" : "POGAISOL_USDT",
#   "price" : "0.0000129",
#   "time" : 1711924246258,
#   "dailyChange" : "0.0427",
#   "ts" : 1711924246271
# }, {
#   "symbol" : "BINU_USDT",
#   "price" : "0.00032",
#   "time" : 1711924241032,
#   "dailyChange" : "-0.0588",
#   "ts" : 1711924241043
# }, {
#   "symbol" : "ACRIA_USDT",
#   "price" : "0.03433",
#   "time" : 1711923001292,
#   "dailyChange" : "-0.0289",
#   "ts" : 1711923001300
# }, {
#   "symbol" : "MOROS_USDT",
#   "price" : "0.00878",
#   "time" : 1711923185395,
#   "dailyChange" : "-0.1646",
#   "ts" : 1711923185402
# }, {
#   "symbol" : "PORTNOY_USDT",
#   "price" : "0.00021",
#   "time" : 1711900957033,
#   "dailyChange" : "0.50",
#   "ts" : 1711900957046
# }, {
#   "symbol" : "ANDYSOL_USDT",
#   "price" : "0.01049",
#   "time" : 1711922665831,
#   "dailyChange" : "0.237",
#   "ts" : 1711922665839
# }, {
#   "symbol" : "PANDA_USDT",
#   "price" : "0.013336",
#   "time" : 1711924241601,
#   "dailyChange" : "-0.3259",
#   "ts" : 1711924241613
# }, {
#   "symbol" : "PIPI_USDT",
#   "price" : "0.00000000139",
#   "time" : 1711924236446,
#   "dailyChange" : "-0.2102",
#   "ts" : 1711924236453
# }, {
#   "symbol" : "COME_USDT",
#   "price" : "0.00001176",
#   "time" : 1711924243889,
#   "dailyChange" : "-0.0359",
#   "ts" : 1711924243900
# }, {
#   "symbol" : "SHROOM_USDT",
#   "price" : "0.00668",
#   "time" : 1711924243311,
#   "dailyChange" : "-0.4516",
#   "ts" : 1711924243324
# }, {
#   "symbol" : "FIRE_USDT",
#   "price" : "0.9403",
#   "time" : 1711924243045,
#   "dailyChange" : "-0.0146",
#   "ts" : 1711924243057
# }, {
#   "symbol" : "LOOMSOL_USDT",
#   "price" : "0.000072",
#   "time" : 1711924242790,
#   "dailyChange" : "0.0909",
#   "ts" : 1711924242798
# }, {
#   "symbol" : "NGL_USDT",
#   "price" : "1.911",
#   "time" : 1711924235090,
#   "dailyChange" : "0.0599",
#   "ts" : 1711924235100
# }, {
#   "symbol" : "DEGEN_USDT",
#   "price" : "0.056771",
#   "time" : 1711924240441,
#   "dailyChange" : "0.5172",
#   "ts" : 1711924240452
# }, {
#   "symbol" : "PNUT_USDT",
#   "price" : "0.00082",
#   "time" : 1711838161222,
#   "dailyChange" : "-0.59",
#   "ts" : 1711838161230
# }, {
#   "symbol" : "BRIUN_USDT",
#   "price" : "0.0129",
#   "time" : 1711924242225,
#   "dailyChange" : "0.1401",
#   "ts" : 1711924242237
# }, {
#   "symbol" : "NORMIEBASE_USDT",
#   "price" : "0.1435",
#   "time" : 1711924245497,
#   "dailyChange" : "0.3495",
#   "ts" : 1711924245509
# }, {
#   "symbol" : "PRIME_USDT",
#   "price" : "24.11",
#   "time" : 1711924242592,
#   "dailyChange" : "-0.0004",
#   "ts" : 1711924242610
# }, {
#   "symbol" : "GRIMACE_USDT",
#   "price" : "17.001",
#   "time" : 1711924233193,
#   "dailyChange" : "0.5784",
#   "ts" : 1711924233200
# }, {
#   "symbol" : "SMOLE_USDT",
#   "price" : "0.0000882",
#   "time" : 1711924241018,
#   "dailyChange" : "-0.0677",
#   "ts" : 1711924241025
# }, {
#   "symbol" : "KERMIT_USDT",
#   "price" : "0.00174",
#   "time" : 1711924238766,
#   "dailyChange" : "-0.1831",
#   "ts" : 1711924238780
# }, {
#   "symbol" : "MAIL_USDT",
#   "price" : "0.04693",
#   "time" : 1711924245801,
#   "dailyChange" : "-0.0466",
#   "ts" : 1711924245811
# }, {
#   "symbol" : "FINK_USDT",
#   "price" : "0.010107",
#   "time" : 1711924241824,
#   "dailyChange" : "-0.065",
#   "ts" : 1711924241833
# }, {
#   "symbol" : "FOMOBASE_USDT",
#   "price" : "0.000702",
#   "time" : 1711924236755,
#   "dailyChange" : "0.1359",
#   "ts" : 1711924236773
# }, {
#   "symbol" : "DOGINME_USDT",
#   "price" : "0.00103",
#   "time" : 1711924243330,
#   "dailyChange" : "0.2873",
#   "ts" : 1711924243339
# }, {
#   "symbol" : "SORABTC_USDT",
#   "price" : "0.1008",
#   "time" : 1711920456716,
#   "dailyChange" : "-0.002",
#   "ts" : 1711920456723
# }, {
#   "symbol" : "LIME_USDT",
#   "price" : "0.1066",
#   "time" : 1711924220428,
#   "dailyChange" : "-0.0524",
#   "ts" : 1711924220434
# }, {
#   "symbol" : "MEW_USDT",
#   "price" : "0.00647",
#   "time" : 1711924245961,
#   "dailyChange" : "-0.1732",
#   "ts" : 1711924245970
# }, {
#   "symbol" : "REX_USDT",
#   "price" : "0.0152",
#   "time" : 1711924238908,
#   "dailyChange" : "-0.0387",
#   "ts" : 1711924238915
# }, {
#   "symbol" : "PUNDU_USDT",
#   "price" : "0.0338",
#   "time" : 1711924242829,
#   "dailyChange" : "-0.0903",
#   "ts" : 1711924242844
# }, {
#   "symbol" : "BASEDAI_USDT",
#   "price" : "11.788",
#   "time" : 1711924236770,
#   "dailyChange" : "0.0938",
#   "ts" : 1711924236783
# }, {
#   "symbol" : "BODEN_USDT",
#   "price" : "0.4317",
#   "time" : 1711924241264,
#   "dailyChange" : "0.3647",
#   "ts" : 1711924241270
# }, {
#   "symbol" : "PUMP_USDT",
#   "price" : "0.000003546",
#   "time" : 1711924246266,
#   "dailyChange" : "-0.1469",
#   "ts" : 1711924246279
# }, {
#   "symbol" : "BENJI_USDT",
#   "price" : "0.02021",
#   "time" : 1711924243110,
#   "dailyChange" : "0.041",
#   "ts" : 1711924243119
# }, {
#   "symbol" : "DWIFC_USDT",
#   "price" : "0.00149",
#   "time" : 1711924242572,
#   "dailyChange" : "-0.0982",
#   "ts" : 1711924242583
# }, {
#   "symbol" : "CWIF_USDT",
#   "price" : "0.0000005025",
#   "time" : 1711924145926,
#   "dailyChange" : "0.0905",
#   "ts" : 1711924145945
# }, {
#   "symbol" : "VENOM_USDT",
#   "price" : "0.5754",
#   "time" : 1711923766136,
#   "dailyChange" : "0.0224",
#   "ts" : 1711923766145
# }, {
#   "symbol" : "DOG_USDT",
#   "price" : "0.01292",
#   "time" : 1711924243510,
#   "dailyChange" : "-0.0882",
#   "ts" : 1711924243520
# }, {
#   "symbol" : "SHOL_USDT",
#   "price" : "0.0000117",
#   "time" : 1711924029311,
#   "dailyChange" : "-0.2994",
#   "ts" : 1711924029323
# }, {
#   "symbol" : "SHIV_USDT",
#   "price" : "0.000000078",
#   "time" : 1711924244799,
#   "dailyChange" : "-0.4152",
#   "ts" : 1711924244818
# }, {
#   "symbol" : "SBFSOL_USDT",
#   "price" : "0.000236",
#   "time" : 1711923931760,
#   "dailyChange" : "-0.2027",
#   "ts" : 1711923931766
# }, {
#   "symbol" : "TPU_USDT",
#   "price" : "0.07446",
#   "time" : 1711924241052,
#   "dailyChange" : "0.0014",
#   "ts" : 1711924241061
# }, {
#   "symbol" : "NEURA_USDT",
#   "price" : "0.0426",
#   "time" : 1711924237049,
#   "dailyChange" : "-0.1621",
#   "ts" : 1711924237060
# }, {
#   "symbol" : "ARCX_USDT",
#   "price" : "10.68",
#   "time" : 1711924244736,
#   "dailyChange" : "-0.0808",
#   "ts" : 1711924244744
# }, {
#   "symbol" : "CSWAP_USDT",
#   "price" : "0.08177",
#   "time" : 1711924245277,
#   "dailyChange" : "0.0356",
#   "ts" : 1711924245286
# }, {
#   "symbol" : "ROOST_USDT",
#   "price" : "0.06983",
#   "time" : 1711924246168,
#   "dailyChange" : "-0.0699",
#   "ts" : 1711924246183
# }, {
#   "symbol" : "GRUMPY_USDT",
#   "price" : "0.00007",
#   "time" : 1711922494791,
#   "dailyChange" : "-0.186",
#   "ts" : 1711922494801
# }, {
#   "symbol" : "DAW_USDT",
#   "price" : "0.002194",
#   "time" : 1711924244981,
#   "dailyChange" : "0.3213",
#   "ts" : 1711924244992
# }, {
#   "symbol" : "ALU_USDT",
#   "price" : "0.06571",
#   "time" : 1711924203201,
#   "dailyChange" : "-0.0305",
#   "ts" : 1711924203212
# }, {
#   "symbol" : "SCALE_USDT",
#   "price" : "0.6633",
#   "time" : 1711924241264,
#   "dailyChange" : "0.2493",
#   "ts" : 1711924241272
# } ]

# %%
# ahora lo que se desea hacer es usar ese texto para estructurarlo como un json (texto estructurado para javascript)
# -----------------------------------------------------------------------------
# now, the best way to proceed is to make a json load of that text

if precios.status_code == 200:
    precios_json = json.loads(precios.text)
    print(precios_json)
# Out:
# [{'symbol': 'BTS_BTC', 'price': '0.0000000501', 'time': 1711915236847, 'dailyChange': '-0.0973', 'ts': 1711915236862}, {'symbol': 'DASH_BTC', 'price': '0.000567', 'time': 1711915688975, 'dailyChange': '0.0161', 'ts': 1711915688983}, {'symbol': 'DOGE_BTC', 'price': '0.000003088', 'time': 1711923923658, 'dailyChange': '0.0741', 'ts': 1711923923671}, {'symbol': 'LTC_BTC', 'price': '0.001485', 'time': 1711923892216, 'dailyChange': '0.0109', 'ts': 1711923892231}, {'symbol': 'XLM_BTC', 'price': '0.000001978', 'time': 1711917536747, 'dailyChange': '0.003', 'ts': 1711917536755}, {'symbol': 'XEM_BTC', 'price': '0.000000724', 'time': 1711923596896, 'dailyChange': '-0.0041', 'ts': 1711923596903}, {'symbol': 'XMR_BTC', 'price': '0.001637', 'time': 1711923036481, 'dailyChange': '-0.0291', 'ts': 1711923036492}, {'symbol': 'XRP_BTC', 'price': '0.00000889', 'time': 1711921082377, 'dailyChange': '-0.0011', 'ts': 1711921082389}, {'symbol': 'BTC_USDT', 'price': '70864.31', 'time': 1711924240389, 'dailyChange': '0.0158', 'ts': 1711924240401}, {'symbol': 'DASH_USDT', 'price': '39.78', 'time': 1711907267039, 'dailyChange': '0.02', 'ts': 1711907267051}, {'symbol': 'LTC_USDT', 'price': '105.001', 'time': 1711924246085, 'dailyChange': '0.0308', 'ts': 1711924246093}, {'symbol': 'XLM_USDT', 'price': '0.1395', 'time': 1711922004119, 'dailyChange': '0.0058', 'ts': 1711922004125}, {'symbol': 'XMR_USDT', 'price': '115.66', 'time': 1711924245749, 'dailyChange': '-0.0319', 'ts': 1711924245764}, {'symbol': 'XRP_USDT', 'price': '0.627', 'time': 1711924245543, 'dailyChange': '0.0084', 'ts': 1711924245551}, {'symbol': 'ETH_BTC', 'price': '0.05122', 'time': 1711923655520, 'dailyChange': '0.0145', 'ts': 1711923655532}, {'symbol': 'ETH_USDT', 'price': '3629.95', 'time': 1711924242729, 'dailyChange': '0.0344', 'ts': 1711924242739}, {'symbol': 'SC_BTC', 'price': '0.000000142', 'time': 1711893532848, 'dailyChange': '-0.0132', 'ts': 1711893532863}, {'symbol': 'DCR_BTC', 'price': '0.000387', 'time': 1711922942471, 'dailyChange': '-0.0102', 'ts': 1711922942479}, {'symbol': 'LSK_BTC', 'price': '0.00001313', 'time': 1711900481803, 'dailyChange': '-0.0008', 'ts': 1711900481814}, {'symbol': 'STEEM_BTC', 'price': '0.00000524', 'time': 1711719124087, 'dailyChange': '0.00', 'ts': 1711719124096}, {'symbol': 'ETC_BTC', 'price': '0.000484', 'time': 1711922723824, 'dailyChange': '0.0254', 'ts': 1711922723837}, {'symbol': 'ETC_ETH', 'price': '0.00953', 'time': 1711921276340, 'dailyChange': '0.0042', 'ts': 1711921276353}, {'symbol': 'ETC_USDT', 'price': '34.187', 'time': 1711924242277, 'dailyChange': '0.0379', 'ts': 1711924242287}, {'symbol': 'ARDR_BTC', 'price': '0.000001806', 'time': 1711907902913, 'dailyChange': '-0.0378', 'ts': 1711907902922}, {'symbol': 'ZEC_BTC', 'price': '0.00043', 'time': 1711916614392, 'dailyChange': '-0.0046', 'ts': 1711916614401}, {'symbol': 'ZEC_ETH', 'price': '0.00842', 'time': 1711909331328, 'dailyChange': '-0.0529', 'ts': 1711909331343}, {'symbol': 'ZEC_USDT', 'price': '30.25', 'time': 1711924244128, 'dailyChange': '0.0046', 'ts': 1711924244137}, {'symbol': 'ZRX_BTC', 'price': '0.00001101', 'time': 1711843430220, 'dailyChange': '0.0251', 'ts': 1711843430235}, {'symbol': 'ZRX_ETH', 'price': '0.000232', 'time': 1711804803474, 'dailyChange': '0.00', 'ts': 1711804803485}, {'symbol': 'CVC_BTC', 'price': '0.000003176', 'time': 1711756951382, 'dailyChange': '0.00', 'ts': 1711756951395}, {'symbol': 'OMG_BTC', 'price': '0.0000125', 'time': 1711916481240, 'dailyChange': '-0.0008', 'ts': 1711916481255}, {'symbol': 'GAS_BTC', 'price': '0.0000929', 'time': 1711908054810, 'dailyChange': '-0.071', 'ts': 1711908054817}, {'symbol': 'STORJ_BTC', 'price': '0.00001042', 'time': 1711916538884, 'dailyChange': '-0.0198', 'ts': 1711916538899}, {'symbol': 'EOS_BTC', 'price': '0.00001554', 'time': 1711921268882, 'dailyChange': '0.0052', 'ts': 1711921268891}, {'symbol': 'EOS_ETH', 'price': '0.000313', 'time': 1711921266462, 'dailyChange': '-0.0182', 'ts': 1711921266469}, {'symbol ...

# %%
# ahora acomodaremos la informacion en una lista donde solo se incluya la informacion de symbol como tipo y la informacio de price como precio, 
# desde la informacion tipo json
# -----------------------------------------------------------------------------
# now we can make our own list/array based on this information (json data), for example a list only with the symbols and prices

lista_precios = []
if precios.status_code == 200:
    precios_json = json.loads(precios.text)
    for p in precios_json:
        lista_precios.append({"tipo": p["symbol"], "precio": p["price"]})
print(lista_precios)
# Out:
# [{'tipo': 'BTS_BTC', 'precio': '0.0000000501'}, {'tipo': 'DASH_BTC', 'precio': '0.000567'}, {'tipo': 'DOGE_BTC', 'precio': '0.000003088'}, {'tipo': 'LTC_BTC', 'precio': '0.001485'}, {'tipo': 'XLM_BTC', 'precio': '0.000001978'}, {'tipo': 'XEM_BTC', 'precio': '0.000000724'}, {'tipo': 'XMR_BTC', 'precio': '0.001637'}, {'tipo': 'XRP_BTC', 'precio': '0.00000889'}, {'tipo': 'BTC_USDT', 'precio': '70864.31'}, {'tipo': 'DASH_USDT', 'precio': '39.78'}, {'tipo': 'LTC_USDT', 'precio': '105.001'}, {'tipo': 'XLM_USDT', 'precio': '0.1395'}, {'tipo': 'XMR_USDT', 'precio': '115.66'}, {'tipo': 'XRP_USDT', 'precio': '0.627'}, {'tipo': 'ETH_BTC', 'precio': '0.05122'}, {'tipo': 'ETH_USDT', 'precio': '3629.95'}, {'tipo': 'SC_BTC', 'precio': '0.000000142'}, {'tipo': 'DCR_BTC', 'precio': '0.000387'}, {'tipo': 'LSK_BTC', 'precio': '0.00001313'}, {'tipo': 'STEEM_BTC', 'precio': '0.00000524'}, {'tipo': 'ETC_BTC', 'precio': '0.000484'}, {'tipo': 'ETC_ETH', 'precio': '0.00953'}, {'tipo': 'ETC_USDT', 'precio': '34.187'}, {'tipo': 'ARDR_BTC', 'precio': '0.000001806'}, {'tipo': 'ZEC_BTC', 'precio': '0.00043'}, {'tipo': 'ZEC_ETH', 'precio': '0.00842'}, {'tipo': 'ZEC_USDT', 'precio': '30.25'}, {'tipo': 'ZRX_BTC', 'precio': '0.00001101'}, {'tipo': 'ZRX_ETH', 'precio': '0.000232'}, {'tipo': 'CVC_BTC', 'precio': '0.000003176'}, {'tipo': 'OMG_BTC', 'precio': '0.0000125'}, {'tipo': 'GAS_BTC', 'precio': '0.0000929'}, {'tipo': 'STORJ_BTC', 'precio': '0.00001042'}, {'tipo': 'EOS_BTC', 'precio': '0.00001554'}, {'tipo': 'EOS_ETH', 'precio': '0.000313'}, {'tipo': 'EOS_USDT', 'precio': '1.1014'}, {'tipo': 'SNT_BTC', 'precio': '0.000000574'}, {'tipo': 'KNC_BTC', 'precio': '0.00001243'}, {'tipo': 'BAT_BTC', 'precio': '0.00000431'}, {'tipo': 'BAT_USDT', 'precio': '0.3274'}, {'tipo': 'LOOM_BTC', 'precio': '0.000001506'}, {'tipo': 'DOGE_USDT', 'precio': '0.21769'}, {'tipo': 'LSK_USDT', 'precio': '0.9104'}, {'tipo': 'SC_USDT', 'precio': '0.010114'}, {'tipo': 'ZRX_USDT', 'precio': '0.7384'}, {'tipo': 'QTUM_BTC', 'precio': '0.0000673'}, {'tipo': 'QTUM_USDT', 'precio': '4.509'}, {'tipo': 'BTC_USDC', 'precio': '71547.84'}, {'tipo': 'ETH_USDC', 'precio': '3633.13'}, {'tipo': 'USDT_USDC', 'precio': '1.0016'}, {'tipo': 'MANA_BTC', 'precio': '0.00000951'}, {'tipo': 'MANA_USDT', 'precio': '0.6625'}, {'tipo': 'BNT_BTC', 'precio': '0.00001151'}, {'tipo': 'BCHSV_BTC', 'precio': '0.001366'}, {'tipo': 'BCHSV_USDC', 'precio': '90.12'}, {'tipo': 'XRP_USDC', 'precio': '0.6649'}, {'tipo': 'XMR_USDC', 'precio': '116'}, {'tipo': 'XLM_USDC', 'precio': '0.1409'}, {'tipo': 'DOGE_USDC', 'precio': '0.2'}, {'tipo': 'LTC_USDC', 'precio': '106.14'}, {'tipo': 'ZEC_USDC', 'precio': '30.18'}, {'tipo': 'NMR_BTC', 'precio': '0.000463'}, {'tipo': 'POLY_BTC', 'precio': '0.000000792'}, {'tipo': 'LPT_BTC', 'precio': '0.0002682'}, {'tipo': 'ATOM_BTC', 'precio': '0.0001724'}, {'tipo': 'ATOM_USDC', 'precio': '10.97'}, {'tipo': 'ATOM_USDT', 'precio': '12.19'}, {'tipo': 'DASH_USDC', 'precio': '39.74'}, {'tipo': 'EOS_USDC', 'precio': '1.5474'}, {'tipo': 'ETC_USDC', 'precio': '38'}, {'tipo': 'BCHSV_USDT', 'precio': '95.28'}, {'tipo': 'TRX_BTC', 'precio': '0.000001719'}, {'tipo': 'TRX_USDC', 'precio': '0.12302'}, {'tipo': 'TRX_USDT', 'precio': '0.12281'}, {'tipo': 'ETH_TRX', 'precio': '29221.44'}, {'tipo': 'XRP_TRX', 'precio': '5.101'}, {'tipo': 'BTT_USDT', 'precio': '0.0000016122'}, {'tipo': 'BTT_TRX', 'precio': '0.0000129'}, {'tipo': 'WIN_USDT', 'precio': '0.00016801'}, {'tipo': 'WIN_TRX', 'precio': '0.001294'}, {'tipo': 'STEEM_TRX', 'precio': '2.5'}, {'tipo': 'LINK_BTC', 'precio': '0.0002673'}, {'tipo': 'LINK_TRX', 'precio': '146.03'}, {'tipo': 'XTZ_BTC', 'precio': '0.00002082'}, {'tipo': 'XTZ_USDT', 'precio': '1.3894'}, {'tipo': 'XTZ_TRX', 'precio': '11.7'}, {'tipo': 'USDJ_USDT', 'precio': '1.1197'}, {'tipo': 'SNX_BTC', 'precio': '0.0000663'}, {'tipo': 'SNX_USDT', 'precio': '4.734'}, {'tipo': 'SNX_TRX', 'precio': '37.63'}, {'tipo': 'MATIC_BTC', 'precio': '0.0000139'}, {'tipo': 'MATIC_USDT', 'precio': '0.99796'}, {'ti ...

# %%
# ahora se trabajara para obtener la tabla de Orderbook
# -----------------------------------------------------------------------------
# now, we can do something similar to obtein something like the Orderbook (the records of the current orders)

tipo = "DASH_BTC"
limite = 20
ob = requests.get(f"https://api.poloniex.com/markets/{tipo}/orderBook?limit={limite}")
print(ob.text)
# Out:
# {
#   "time" : 1711924215562,
#   "scale" : "0.000001",
#   "asks" : [ "0.000571", "0.15", "0.000579", "0.03", "0.00058", "1.25", "0.000582", "0.02", "0.000588", "0.04", "0.000592", "0.03", "0.000593", "0.03", "0.000594", "0.02", "0.000599", "4.02", "0.0006", "300.02", "0.000602", "0.22", "0.000605", "0.02", "0.000606", "0.02", "0.000613", "0.22", "0.000623", "0.02", "0.000624", "0.22", "0.000625", "0.32", "0.00063", "0.02", "0.000632", "0.03", "0.000636", "0.02" ],
#   "bids" : [ "0.000567", "203.35", "0.000558", "33.69", "0.000555", "0.02", "0.00055", "1.25", "0.000549", "0.06", "0.000544", "0.02", "0.000539", "0.02", "0.00053", "0.15", "0.000529", "0.02", "0.000525", "0.38", "0.000524", "0.02", "0.000522", "0.03", "0.00052", "0.15", "0.000517", "0.03", "0.000513", "0.27", "0.000512", "0.03", "0.000507", "0.03", "0.000504", "1.9", "0.000502", "0.03", "0.0005", "0.4" ],
#   "ts" : 1711924215573
# }

# %%
# solo tomaremos lo contenido en asks y lo separaremos en precios y tamaños dependiendo si el indice es par o impar 
# -----------------------------------------------------------------------------
#  now, we can create a list of the orderbook response and evaluate the content for the asks and divide the data in prices and sizes

preguntar_precios = []
preguntar_tamanos = []
conteo = 0
ob_json = []

if ob.status_code == 200:
    ob_json = json.loads(ob.text)

    # usando un contador y dividiendolo entre %2 para saber si el indice is par o no (par es precio, impar es tamaño)
    # -----------------------------------------------------------------------------
    # we can use a counter and divide it %2 to evaluate if the index is even or not (even = prices, else = size)
    
    for a in ob_json["asks"]:
        if conteo % 2 == 0:
            preguntar_precios.append(a)
        else:
            preguntar_tamanos.append(a)
        conteo += 1
        
    print(preguntar_precios)
    print(preguntar_tamanos)
# Out:
# ['0.000571', '0.000579', '0.00058', '0.000582', '0.000588', '0.000592', '0.000593', '0.000594', '0.000599', '0.0006', '0.000602', '0.000605', '0.000606', '0.000613', '0.000623', '0.000624', '0.000625', '0.00063', '0.000632', '0.000636']
# ['0.15', '0.03', '1.25', '0.02', '0.04', '0.03', '0.03', '0.02', '4.02', '300.02', '0.22', '0.02', '0.02', '0.22', '0.02', '0.22', '0.32', '0.02', '0.03', '0.02']

# %%
# Basicamente asi funcionan todas las apis de este tipo curl/url
# -----------------------------------------------------------------------------
# this is basically how curls/url apis works
